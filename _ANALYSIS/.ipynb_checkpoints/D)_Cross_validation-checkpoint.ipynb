# %% [markdown]
# # Cross validation
#
# **To Do:**
# - Check order of operations where dataframes with MSE results are being saved (add some logical order; first new than classical method e.g.)
# - Name dataframes containing MSE results accordingly

# %% [markdown]
# ## Imports

# %%
# Scientific packages
import pandas as pd
import numpy as np
import xarray

# Principal component package
from sklearn.decomposition import PCA

# Train - test split package
from sklearn.model_selection import train_test_split

# Visualisation packages
import matplotlib.pyplot as plt
import seaborn as sns

# Operating system interaction package
import os

# Regular expressions package
import re

# %%
# Import local package
from compositional_data_kriging import pre_post_processing as ppp
from compositional_data_kriging import cross_validation as cv

# %%
# Load jupyter extension to reload packages before executing user code.
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload

# %%
# Reload all packages (except those excluded by %aimport) every 
# time before executing the Python code typed.
# %autoreload 2

# %%
# Functions to save and load Python instances (e.g. dictionary)
# as a binary file to or from disk
import pickle

def save_obj(obj, name):
    with open("../_DATA/obj/" + name + ".pkl", 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name):
    with open("../_DATA/obj/" + name + ".pkl", 'rb') as f:
        return pickle.load(f)

# %% [markdown]
# ___

# %% [markdown]
# ### Sample splitting (train/test 80/20)
# - Use one grain size class as example
# - For cross validation with 5 folds:
#     - For each method (classic and new method):
#         - For each quarry (Berg and MHZ):
#             - For each geological layer (TZ, IZ and GZ)

# %% [markdown]
# Classic method:
# - Only create grid file via Ordinary Kriging (OK) --> Grid file with GSD
#
# New method:
# - Pre-processing
# - Create grid file via OK
# - Post-processing --> Gridfile with GSD

# %% [markdown]
# ### Value lookup
# Lookup coordinates of requested test sample in kriged grid file:
# - Starting coordinates (lowerleft corner) are known from the grid file
# - Stepsize in x and y direction are also known from grid file (identital in both directions)
#
# Requested coordinates = (starting_coordinate_X + n * stepsize_X, starting_coordinate_Y + n * stepsize_Y)

# %% [markdown]
# If requested coordinate falls exactly on a grid point in the grid file:
# - this value can be taken for validation.
#
# Else:
# - Calculate mean of 4 closest grid points and take this value for validation

# %% [markdown]
# ### Applying clr-transformation on samples (for both methods)

# %%
# %%time
# Berg pre-processing
Berg_clr_df_dict = ppp.pre_pre_processing("../_DATA/Berg_usable_data.xlsx")
# Out:
# ['TZ', 'IZ', 'GZ']
# (39, 10)
# (39, 10)
# (36, 10)
# Wall time: 65.1 ms

# %%
# %%time
# MHZ pre-processing
MHZ_clr_df_dict = ppp.pre_pre_processing("../_DATA/MHZ_usable_data.xlsx")
# Out:
# ['TZ', 'IZ', 'GZ']
# (47, 10)
# (61, 10)
# (58, 10)
# Wall time: 43.1 ms

# %%
quarry_dict_clr = {"Berg": Berg_clr_df_dict,
                   "MHZ": MHZ_clr_df_dict,}

# %% [markdown]
# ### Creating files for cross validation

# %%
# Read in 'usable' data files
rootDir = "../_DATA/"

quarry_dict = {}
for item in os.listdir(rootDir):
    quarry = item.split("_")[0]
    dataframe_dict = {}
    if item.endswith(".xlsx"):
        for sheet in ["TZ", "IZ", "GZ"]:
            dataframe_dict[sheet] = pd.read_excel(rootDir + item, sheet_name=sheet)
        quarry_dict[quarry] = dataframe_dict

# %%
# TO DO: add list of random states to pick from in order to 
# obtain reproducibilty of cross vaildation in the exact same way
# DONE --> easy solution: use fold number [1, 2, 3, 4, 5] as random_state number

# Train-test split the data

train_test_data = {}

for quarry, data in quarry_dict_clr.items():
    for geol, item in data.items():
        for i in range(1, 6):
            train_test_data[quarry, geol, i] = train_test_split(item, test_size=0.2, random_state=i)

# %%
# Set save to True to save the train-test data to disk
save = False

if save == True:
    # Save the train-test data to disk
    for key, split in train_test_data.items():
            Dirname = "../_CROSS_VALIDATION_clr/" + key[0] + "/" + key[1] + "/"
            os.makedirs(os.path.dirname(Dirname), exist_ok=True)
            split[0].to_excel(Dirname + key[0] + "_" + key[1] + "_" + str(key[2]) + "_train.xlsx", sheet_name="train")
            split[1].to_excel(Dirname + key[0] + "_" + key[1] + "_" + str(key[2]) + "_test.xlsx", sheet_name="test")
            split[1].to_csv(Dirname + key[0] + "_" + key[1] + "_" + str(key[2]) + "_test.csv", sep=";")

# %% [markdown]
# ## In-house approach

# %% [markdown]
# ### Cross validation pre-processing

# %%
# %%time
# Cross validation pre-processing Berg clr
rootDir = "../_CROSS_VALIDATION_CLR/Berg/"

cross_validation_pre_processing_Berg = {}

for dirName, subdirList, fileList in os.walk(rootDir):
    
    if dirName.endswith("TZ"):
        code_geol = "TZ"
        print(code_geol)
    elif dirName.endswith("IZ"):
        code_geol = "IZ"
        print(code_geol)
    elif dirName.endswith("GZ"):
        code_geol="GZ"
        print(code_geol)
    else:
        code_geol = None
        
    i = 1
    
    layer_pre_processing = {}
    
    for file in fileList:
        if file.endswith("train.xlsx"):
            layer_pre_processing[f"train_{str(i)}"] =\
                ppp.pca_pre_processing(f"{rootDir}/{code_geol}/{file}", 
                                       save_data=False, 
                                       save_name=f"../_RESULTS/CROSS_VALIDATION_PREPROCESSED_clr/\
                                                 Berg/{code_geol}/{code_geol}_{str(i)}_train_pca")
            i += 1
            
    if code_geol != None:
        cross_validation_pre_processing_Berg[code_geol] = layer_pre_processing
# Out:
# GZ
# ['train']
# 4 PCA components with variance sum 0.965219965013 needed for obtaining sum of variance > 0.95
# Index(['BRG_16_07', 'BRG_16_03', 'BRG_16_04B', 'ECO_09_02', 'BRG_16_01',
#        'BRG_16_02', 'BRG_01_05', 'BRG_01_03', 'BRG_05_09', 'BRG_05_02',
#        'ECO_09_01', 'BRG_13_01', 'BRG_16_09', 'BRG_05_15', 'BRG_05_13',
#        'BRG_01_07', 'BRG_05_05', 'BRG_01_08', 'ECO_09_05', 'BRG_01_02',
#        'BRG_05_11', 'BRG_01_01', 'BRG_05_10', 'BRG_01_06', 'BRG_05_03',
#        'BRG_05_01', 'BRG_01_09', 'BRG_05_04'],
#       dtype='object', name='hole_id')
# ['train']
# 4 PCA components with variance sum 0
],
#       dtype='object', name='hole_id')
# ['train']
# 4 PCA components with variance sum 0.979244113414 needed for obtaining sum of variance > 0.95
# Index(['BRG_16_01', 'BRG_01_06', 'BRG_01_01', 'BRG_16_02', 'BRG_01_03',
#        'BRG_05_15', 'BRG_05_14', 'BRG_16_09', 'BRG_05_02', 'ECO_09_05',
#        'BRG_05_13', 'BRG_16_04B', 'BRG_01_02', 'BRG_05_03', 'BRG_05_05',
#        'BRG_16_05', 'BRG_16_07', 'BRG_16_08', 'BRG_08_01', 'BRG_05_12',
#        'BRG_05_10', 'BRG_05_04', 'BRG_01_08', 'ECO_09_03', 'BRG_16_06',
#        'BRG_16_04A', 'BRG_01_09', 'BRG_05_01', 'BRG_05_11', 'BRG_05_09',
#        'ECO_09_02'],
#       dtype='object', name='hole_id')
# Wall time: 153 ms

# %%
# %%time
# Cross validation pre-processing MHZ clr
rootDir = "../_CROSS_VALIDATION_CLR/MHZ/"

cross_validation_pre_processing_MHZ = {}

for dirName, subdirList, fileList in os.walk(rootDir):
    
    if dirName.endswith("TZ"):
        code_geol = "TZ"
        print(code_geol)
    elif dirName.endswith("IZ"):
        code_geol = "IZ"
        print(code_geol)
    elif dirName.endswith("GZ"):
        code_geol="GZ"
        print(code_geol)
    else:
        code_geol = None
        
    i = 1
    
    layer_pre_processing = {}
    
    for file in fileList:
        if file.endswith("train.xlsx"):
            layer_pre_processing[f"train_{str(i)}"] =\
            ppp.pca_pre_processing(f"{rootDir}/{code_geol}/{file}", 
                                   save_data=False, 
                                   save_name=f"../_RESULTS/CROSS_VALIDATION_PREPROCESSED_clr/\
                                             MHZ/{code_geol}/{code_geol}_{str(i)}_train_pca")
            i += 1
            
    if code_geol != None:
        cross_validation_pre_processing_MHZ[code_geol] = layer_pre_processing
# Out:
# GZ
# ['train']
# 4 PCA components with variance sum 0.954682252546 needed for obtaining sum of variance > 0.95
# Index(['LBU_87_1', 'LBU_87_5', 'LBU_05_22', 'LBU_05_08', 'MHZ_08_02',
#        'LBU_05_24', 'MHZ_12_01', 'LBU_05_28', 'LBU_87_6', 'LBU_98_4',
#        'LBU_05_25', 'LBU_96_4', 'MHZ_12_03', 'LBU_05_29', 'LBU_05_11',
#        'LBU_05_20', 'MHZ_08_01', 'LBU_05_30', 'LBU_05_15', 'MHZ_08_05',
#        'LBU_07_01', 'LBU_05_21', 'LBU_05_02', 'LBU_05_12', 'LBU_05_27',
#        'LBU_05_26', 'MHZ_08_04', 'LBU_96_1', 'LBU_05_16', 'MHZ_12_04',
#        'LBU_05_18', 'LBU_05_23', 'LBU_05_04', 'LBU_05_05', 'MHZ_12_02',
#        'LBU_02_3', 'LBU_05_14', 'LBU_01_1', 'LBU_05_13', 'LBU_05_03',
#        'LBU_05_09', 'LBU_05_07', 'LBU_05_06', 'LBU_05_10', 'LBU_96_2',
#        'LBU_87_2'],
#       dtype='object', name='hole_id')
# ['train']
# 4 PCA components with variance sum 0.957077722548 needed for obtaining sum of variance > 0.95
# Index(['LBU_05
# Index(['LBU_05_18', 'LBU_07_03', 'LBU_05_08', 'MHZ_08_05', 'LBU_05_22',
#        'LBU_05_21', 'MHZ_12_02', 'LBU_05_09', 'LBU_05_06', 'LBU_05_15',
#        'LBU_05_24', 'LBU_07_01', 'LBU_05_23', 'LBU_05_13', 'MHZ_08_04',
#        'LBU_05_29', 'LBU_05_10', 'LBU_01_3', 'LBU_05_20', 'LBU_05_27',
#        'LBU_05_25', 'LBU_05_02', 'MHZ_12_01', 'LBU_05_30', 'LBU_05_17',
#        'LBU_01_1', 'LBU_02_3', 'LBU_07_02', 'LBU_05_26', 'MHZ_08_02',
#        'LBU_05_05', 'LBU_05_04', 'LBU_05_19', 'MHZ_08_03', 'LBU_01_2',
#        'LBU_05_01', 'MHZ_12_04'],
#       dtype='object', name='hole_id')
# ['train']
# 3 PCA components with variance sum 0.958062373034 needed for obtaining sum of variance > 0.95
# Index(['LBU_02_4', 'LBU_07_03', 'LBU_01_1', 'LBU_05_17', 'LBU_05_01',
#        'MHZ_12_03', 'LBU_05_28', 'MHZ_12_04', 'LBU_05_27', 'LBU_05_21',
#        'LBU_05_20', 'LBU_05_06', 'MHZ_08_05', 'LBU_05_14', 'LBU_05_18',
#        'LBU_05_16', 'LBU_05_29', 'LBU_01_2', 'LBU_05_07', 'LBU_05_09',
#        'LBU_05_30', 'MHZ_12_02', 'MHZ_08_03', 'LBU_05_11', 'LBU_05_08',
#        'LBU_05_03', 'MHZ_12_01', 'LBU_05_26', 'LBU_05_23', 'MHZ_08_02',
#        'LBU_07_02', 'LBU_05_04', 'LBU_05_05', 'LBU_05_12', 'MHZ_08_01',
#        'LBU_05_10', 'LBU_07_01'],
#       dtype='object', name='hole_id')
# Wall time: 161 ms

# %% [markdown]
# ### Cross validation post-processing

# %%
# Dictionary with grid info data

dict_grid_info = {"Berg":     "ncols 100\n" +
                              "nrows 90\n" +
                              "xllcorner 5.6208707817415728\n" +
                              "yllcorner 50.959635321741573\n" +
                              "cellsize 0.00013419651685393446\n" +
                              "nodata_value 1.7014100000000001E+038\n",
                  
                 "MHZ_GZ":    "ncols 100\n" +
                              "nrows 74\n" +
                              "xllcorner 5.5967023332191781\n" +
                              "yllcorner 50.982320383219182\n" + 
                              "cellsize 0.00019249356164376555\n" +
                              "nodata_value 1.7014100000000001E+038\n",
                  
                 "MHZ_IZ_TZ": "ncols 100\n" +
                              "nrows 81\n" +
                              "xllcorner 5.5967107548124995\n" +
                              "yllcorner 50.982328804812504\n" + 
                              "cellsize 0.00017565037499993607\n" +
                              "nodata_value 1.7014100000000001E+038\n",}

# %%
# %%time
# Post-processing all

# Loop though quarries
for quarry in ["Berg", "MHZ"]:
    if quarry == "Berg":
        clr_data = cross_validation_pre_processing_Berg
        pca_model = cross_validation_pre_processing_Berg
        grid_info = dict_grid_info["Berg"]      
    elif quarry == "MHZ":
        clr_data = cross_validation_pre_processing_MHZ
        pca_model = cross_validation_pre_processing_MHZ 
    else:
        print("Error, not a correct quarry name")
        
    # Loop through geological layers
    for geol in ["TZ", "IZ", "GZ"]:
        if quarry == "MHZ":
            if geol in ["TZ", "IZ"]:
                grid_info = dict_grid_info["MHZ_IZ_TZ"]
            elif geol == "GZ":
                grid_info = dict_grid_info["MHZ_GZ"]
            else:
                print("Error, not a correct geological layer")
                
                
        for train in range(1, 6):
            for comp in range(1, 10):
                ppp.pca_post_processing(f"../_KRIGING/CROSS_VALIDATION_PREPROCESSED_CLR/"+
                                        f"data_{quarry}/{geol}/train_{str(train)}/", 
                                        clr_data[geol][f"train_{str(train)}"][0], 
                                        pca_model[geol][f"train_{str(train)}"][1],
                                        grid_info=grid_info,
                                        n_components=comp,
                                        save_data=False,
                                        verify=False);
# Out:
# Berg TZ
# TZ_1_train_pca_PC01.asc.xlsx (90, 100)
# TZ_1_train_pca_PC02.asc.xlsx (90, 100)
# TZ_1_train_pca_PC03.asc.xlsx (90, 100)
# TZ_1_train_pca_PC04.asc.xlsx (90, 100)
# TZ_1_train_pca_PC05.asc.xlsx (90, 100)
# TZ_1_train_pca_PC06.asc.xlsx (90, 100)
# TZ_1_train_pca_PC07.asc.xlsx (90, 100)
# TZ_1_train_pca_PC08.asc.xlsx (90, 100)
# TZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# C:\Users\u0108248\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\__main__.py:35: DeprecationWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
# gridpoints: 9000
# Berg TZ
# TZ_1_train_pca_PC01.asc.xlsx (90, 100)
# TZ_1_train_pca_PC02.asc.xlsx (90, 100)
# TZ_1_train_pca_PC03.asc.xlsx (90, 100)
# TZ_1_train_pca_PC04.asc.xlsx (90, 100)
# TZ_1_train_pca_PC05.asc.xlsx (90, 100)
# TZ_1_train_pca_PC06.asc.xlsx (90, 100)
# TZ_1_train_pca_PC07.asc.xlsx (90, 100)
# TZ_1_train_pca_PC08.asc.xlsx (90, 100)
# TZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_1_train_pca_PC01.asc.xlsx (90, 100)
# TZ_1_train_pca_PC02.asc.xlsx (90, 100)
# TZ_1_train_pca_PC03.asc.xlsx (90, 100)
# TZ_1_train_pca_PC04.asc.xlsx (90, 100)
# TZ_1_train_pca_PC05.asc.xlsx (90, 100)
# TZ_1_train_pca_PC06.asc.xlsx (90, 100)
# TZ_1_train_pca_PC07.asc.xlsx (90, 100)
# TZ_1_train_pca_PC08.asc.xlsx (90, 100)
# TZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_1_train_pca_PC01.asc.xlsx (90, 100)
# TZ_1_train_pca_PC02.asc.xlsx (90, 100)
# TZ_1_train_pca_PC03.asc.xlsx (90, 100)
# TZ_1_train_pca_PC04.asc.xlsx (90, 100)
# TZ_1_train_pca_PC05.asc.xlsx (90, 100)
# TZ_1_train_pca_PC06.asc.xlsx (90, 100)
# TZ_1_train_pca_PC07.asc.xlsx (90, 100)
# TZ_1_train_pca_PC08.asc.xlsx (90, 100)
# TZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_1_train_pca_PC01.asc.xlsx (90, 100)
# TZ_1_train_pca_PC02.asc.xlsx (90, 100)
# TZ_1_train_pca_PC03.asc.xlsx (90, 100)
# TZ_1_train_pca_PC04.asc.xlsx (90, 100)
# TZ_1_train_pca_PC05.asc.xlsx (90, 100)
# TZ_1_train_pca_PC06.asc.xlsx (90, 100)
# TZ_1_train_pca_PC07.asc.xlsx (90, 100)
# TZ_1_train_pca_PC08.asc.xlsx (90, 100)
# TZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_1_train_pca_PC01.asc.xlsx (90, 100)
# TZ_1_train_pca_PC02.asc.xlsx (90, 100)
# TZ_1_train_pca_PC03.asc.xlsx (90, 100)
# TZ_1_train_pca_PC04.asc.xlsx (90, 100)
# TZ_1_train_pca_PC05.asc.xlsx (90, 100)
# TZ_1_train_pca_PC06.asc.xlsx (90, 100)
# TZ_1_train_pca_PC07.asc.xlsx (90, 100)
# TZ_1_train_pca_PC08.asc.xlsx (90, 100)
# TZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_1_train_pca_PC01.asc.xlsx (90, 100)
# TZ_1_train_pca_PC02.asc.xlsx (90, 100)
# TZ_1_train_pca_PC03.asc.xlsx (90, 100)
# TZ_1_train_pca_PC04.asc.xlsx (90, 100)
# TZ_1_train_pca_PC05.asc.xlsx (90, 100)
# TZ_1_train_pca_PC06.asc.xlsx (90, 100)
# TZ_1_train_pca_PC07.asc.xlsx (90, 100)
# TZ_1_train_pca_PC08.asc.xlsx (90, 100)
# TZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_1_train_pca_PC01.asc.xlsx (90, 100)
# TZ_1_train_pca_PC02.asc.xlsx (90, 100)
# TZ_1_train_pca_PC03.asc.xlsx (90, 100)
# TZ_1_train_pca_PC04.asc.xlsx (90, 100)
# TZ_1_train_pca_PC05.asc.xlsx (90, 100)
# TZ_1_train_pca_PC06.asc.xlsx (90, 100)
# TZ_1_train_pca_PC07.asc.xlsx (90, 100)
# TZ_1_train_pca_PC08.asc.xlsx (90, 100)
# TZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_1_train_pca_PC01.asc.xlsx (90, 100)
# TZ_1_train_pca_PC02.asc.xlsx (90, 100)
# TZ_1_train_pca_PC03.asc.xlsx (90, 100)
# TZ_1_train_pca_PC04.asc.xlsx (90, 100)
# TZ_1_train_pca_PC05.asc.xlsx (90, 100)
# TZ_1_train_pca_PC06.asc.xlsx (90, 100)
# TZ_1_train_pca_PC07.asc.xlsx (90, 100)
# TZ_1_train_pca_PC08.asc.xlsx (90, 100)
# TZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_2_train_pca_PC01.asc.xlsx (90, 100)
# TZ_2_train_pca_PC02.asc.xlsx (90, 100)
# TZ_2_train_pca_PC03.asc.xlsx (90, 100)
# TZ_2_train_pca_PC04.asc.xlsx (90, 100)
# TZ_2_train_pca_PC05.asc.xlsx (90, 100)
# TZ_2_train_pca_PC06.asc.xlsx (90, 100)
# TZ_2_train_pca_PC07.asc.xlsx (90, 100)
# TZ_2_train_pca_PC08.asc.xlsx (90, 100)
# TZ_2_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_2_train_pca_PC01.asc.xlsx (90, 100)
# TZ_2_train_pca_PC02.asc.xlsx (90, 100)
# TZ_2_train_pca_PC03.asc.xlsx (90, 100)
# TZ_2_train_pca_PC04.asc.xlsx (90, 100)
# TZ_2_train_pca_PC05.asc.xlsx (90, 100)
# TZ_2_train_pca_PC06.asc.xlsx (90, 100)
# TZ_2_train_pca_PC07.asc.xlsx (90, 100)
# TZ_2_train_pca_PC08.asc.xlsx (90, 100)
# TZ_2_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_2_train_pca_PC01.asc.xlsx (90, 100)
# TZ_2_train_pca_PC02.asc.xlsx (90, 100)
# TZ_2_train_pca_PC03.asc.xlsx (90, 100)
# TZ_2_train_pca_PC04.asc.xlsx (90, 100)
# TZ_2_train_pca_PC05.asc.xlsx (90, 100)
# TZ_2_train_pca_PC06.asc.xlsx (90, 100)
# TZ_2_train_pca_PC07.asc.xlsx (90, 100)
# TZ_2_train_pca_PC08.asc.xlsx (90, 100)
# TZ_2_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_2_train_pca_PC01.asc.xlsx (90, 100)
# TZ_2_train_pca_PC02.asc.xlsx (90, 100)
# TZ_2_train_pca_PC03.asc.xlsx (90, 100)
# TZ_2_train_pca_PC04.asc.xlsx (90, 100)
# TZ_2_train_pca_PC05.asc.xlsx (90, 100)
# TZ_2_train_pca_PC06.asc.xlsx (90, 100)
# TZ_2_train_pca_PC07.asc.xlsx (90, 100)
# TZ_2_train_pca_PC08.asc.xlsx (90, 100)
# TZ_2_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_2_train_pca_PC01.asc.xlsx (90, 100)
# TZ_2_train_pca_PC02.asc.xlsx (90, 100)
# TZ_2_train_pca_PC03.asc.xlsx (90, 100)
# TZ_2_train_pca_PC04.asc.xlsx (90, 100)
# TZ_2_train_pca_PC05.asc.xlsx (90, 100)
# TZ_2_train_pca_PC06.asc.xlsx (90, 100)
# TZ_2_train_pca_PC07.asc.xlsx (90, 100)
# TZ_2_train_pca_PC08.asc.xlsx (90, 100)
# TZ_2_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_2_train_pca_PC01.asc.xlsx (90, 100)
# TZ_2_train_pca_PC02.asc.xlsx (90, 100)
# TZ_2_train_pca_PC03.asc.xlsx (90, 100)
# TZ_2_train_pca_PC04.asc.xlsx (90, 100)
# TZ_2_train_pca_PC05.asc.xlsx (90, 100)
# TZ_2_train_pca_PC06.asc.xlsx (90, 100)
# TZ_2_train_pca_PC07.asc.xlsx (90, 100)
# TZ_2_train_pca_PC08.asc.xlsx (90, 100)
# TZ_2_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_2_train_pca_PC01.asc.xlsx (90, 100)
# TZ_2_train_pca_PC02.asc.xlsx (90, 100)
# TZ_2_train_pca_PC03.asc.xlsx (90, 100)
# TZ_2_train_pca_PC04.asc.xlsx (90, 100)
# TZ_2_train_pca_PC05.asc.xlsx (90, 100)
# TZ_2_train_pca_PC06.asc.xlsx (90, 100)
# TZ_2_train_pca_PC07.asc.xlsx (90, 100)
# TZ_2_train_pca_PC08.asc.xlsx (90, 100)
# TZ_2_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_2_train_pca_PC01.asc.xlsx (90, 100)
# TZ_2_train_pca_PC02.asc.xlsx (90, 100)
# TZ_2_train_pca_PC03.asc.xlsx (90, 100)
# TZ_2_train_pca_PC04.asc.xlsx (90, 100)
# TZ_2_train_pca_PC05.asc.xlsx (90, 100)
# TZ_2_train_pca_PC06.asc.xlsx (90, 100)
# TZ_2_train_pca_PC07.asc.xlsx (90, 100)
# TZ_2_train_pca_PC08.asc.xlsx (90, 100)
# TZ_2_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_2_train_pca_PC01.asc.xlsx (90, 100)
# TZ_2_train_pca_PC02.asc.xlsx (90, 100)
# TZ_2_train_pca_PC03.asc.xlsx (90, 100)
# TZ_2_train_pca_PC04.asc.xlsx (90, 100)
# TZ_2_train_pca_PC05.asc.xlsx (90, 100)
# TZ_2_train_pca_PC06.asc.xlsx (90, 100)
# TZ_2_train_pca_PC07.asc.xlsx (90, 100)
# TZ_2_train_pca_PC08.asc.xlsx (90, 100)
# TZ_2_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_3_train_pca_PC01.asc.xlsx (90, 100)
# TZ_3_train_pca_PC02.asc.xlsx (90, 100)
# TZ_3_train_pca_PC03.asc.xlsx (90, 100)
# TZ_3_train_pca_PC04.asc.xlsx (90, 100)
# TZ_3_train_pca_PC05.asc.xlsx (90, 100)
# TZ_3_train_pca_PC06.asc.xlsx (90, 100)
# TZ_3_train_pca_PC07.asc.xlsx (90, 100)
# TZ_3_train_pca_PC08.asc.xlsx (90, 100)
# TZ_3_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_3_train_pca_PC01.asc.xlsx (90, 100)
# TZ_3_train_pca_PC02.asc.xlsx (90, 100)
# TZ_3_train_pca_PC03.asc.xlsx (90, 100)
# TZ_3_train_pca_PC04.asc.xlsx (90, 100)
# TZ_3_train_pca_PC05.asc.xlsx (90, 100)
# TZ_3_train_pca_PC06.asc.xlsx (90, 100)
# TZ_3_train_pca_PC07.asc.xlsx (90, 100)
# TZ_3_train_pca_PC08.asc.xlsx (90, 100)
# TZ_3_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_3_train_pca_PC01.asc.xlsx (90, 100)
# TZ_3_train_pca_PC02.asc.xlsx (90, 100)
# TZ_3_train_pca_PC03.asc.xlsx (90, 100)
# TZ_3_train_pca_PC04.asc.xlsx (90, 100)
# TZ_3_train_pca_PC05.asc.xlsx (90, 100)
# TZ_3_train_pca_PC06.asc.xlsx (90, 100)
# TZ_3_train_pca_PC07.asc.xlsx (90, 100)
# TZ_3_train_pca_PC08.asc.xlsx (90, 100)
# TZ_3_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_3_train_pca_PC01.asc.xlsx (90, 100)
# TZ_3_train_pca_PC02.asc.xlsx (90, 100)
# TZ_3_train_pca_PC03.asc.xlsx (90, 100)
# TZ_3_train_pca_PC04.asc.xlsx (90, 100)
# TZ_3_train_pca_PC05.asc.xlsx (90, 100)
# TZ_3_train_pca_PC06.asc.xlsx (90, 100)
# TZ_3_train_pca_PC07.asc.xlsx (90, 100)
# TZ_3_train_pca_PC08.asc.xlsx (90, 100)
# TZ_3_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_3_train_pca_PC01.asc.xlsx (90, 100)
# TZ_3_train_pca_PC02.asc.xlsx (90, 100)
# TZ_3_train_pca_PC03.asc.xlsx (90, 100)
# TZ_3_train_pca_PC04.asc.xlsx (90, 100)
# TZ_3_train_pca_PC05.asc.xlsx (90, 100)
# TZ_3_train_pca_PC06.asc.xlsx (90, 100)
# TZ_3_train_pca_PC07.asc.xlsx (90, 100)
# TZ_3_train_pca_PC08.asc.xlsx (90, 100)
# TZ_3_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_3_train_pca_PC01.asc.xlsx (90, 100)
# TZ_3_train_pca_PC02.asc.xlsx (90, 100)
# TZ_3_train_pca_PC03.asc.xlsx (90, 100)
# TZ_3_train_pca_PC04.asc.xlsx (90, 100)
# TZ_3_train_pca_PC05.asc.xlsx (90, 100)
# TZ_3_train_pca_PC06.asc.xlsx (90, 100)
# TZ_3_train_pca_PC07.asc.xlsx (90, 100)
# TZ_3_train_pca_PC08.asc.xlsx (90, 100)
# TZ_3_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_3_train_pca_PC01.asc.xlsx (90, 100)
# TZ_3_train_pca_PC02.asc.xlsx (90, 100)
# TZ_3_train_pca_PC03.asc.xlsx (90, 100)
# TZ_3_train_pca_PC04.asc.xlsx (90, 100)
# TZ_3_train_pca_PC05.asc.xlsx (90, 100)
# TZ_3_train_pca_PC06.asc.xlsx (90, 100)
# TZ_3_train_pca_PC07.asc.xlsx (90, 100)
# TZ_3_train_pca_PC08.asc.xlsx (90, 100)
# TZ_3_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_3_train_pca_PC01.asc.xlsx (90, 100)
# TZ_3_train_pca_PC02.asc.xlsx (90, 100)
# TZ_3_train_pca_PC03.asc.xlsx (90, 100)
# TZ_3_train_pca_PC04.asc.xlsx (90, 100)
# TZ_3_train_pca_PC05.asc.xlsx (90, 100)
# TZ_3_train_pca_PC06.asc.xlsx (90, 100)
# TZ_3_train_pca_PC07.asc.xlsx (90, 100)
# TZ_3_train_pca_PC08.asc.xlsx (90, 100)
# TZ_3_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_3_train_pca_PC01.asc.xlsx (90, 100)
# TZ_3_train_pca_PC02.asc.xlsx (90, 100)
# TZ_3_train_pca_PC03.asc.xlsx (90, 100)
# TZ_3_train_pca_PC04.asc.xlsx (90, 100)
# TZ_3_train_pca_PC05.asc.xlsx (90, 100)
# TZ_3_train_pca_PC06.asc.xlsx (90, 100)
# TZ_3_train_pca_PC07.asc.xlsx (90, 100)
# TZ_3_train_pca_PC08.asc.xlsx (90, 100)
# TZ_3_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_4_train_pca_PC01.asc.xlsx (90, 100)
# TZ_4_train_pca_PC02.asc.xlsx (90, 100)
# TZ_4_train_pca_PC03.asc.xlsx (90, 100)
# TZ_4_train_pca_PC04.asc.xlsx (90, 100)
# TZ_4_train_pca_PC05.asc.xlsx (90, 100)
# TZ_4_train_pca_PC06.asc.xlsx (90, 100)
# TZ_4_train_pca_PC07.asc.xlsx (90, 100)
# TZ_4_train_pca_PC08.asc.xlsx (90, 100)
# TZ_4_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_4_train_pca_PC01.asc.xlsx (90, 100)
# TZ_4_train_pca_PC02.asc.xlsx (90, 100)
# TZ_4_train_pca_PC03.asc.xlsx (90, 100)
# TZ_4_train_pca_PC04.asc.xlsx (90, 100)
# TZ_4_train_pca_PC05.asc.xlsx (90, 100)
# TZ_4_train_pca_PC06.asc.xlsx (90, 100)
# TZ_4_train_pca_PC07.asc.xlsx (90, 100)
# TZ_4_train_pca_PC08.asc.xlsx (90, 100)
# TZ_4_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_4_train_pca_PC01.asc.xlsx (90, 100)
# TZ_4_train_pca_PC02.asc.xlsx (90, 100)
# TZ_4_train_pca_PC03.asc.xlsx (90, 100)
# TZ_4_train_pca_PC04.asc.xlsx (90, 100)
# TZ_4_train_pca_PC05.asc.xlsx (90, 100)
# TZ_4_train_pca_PC06.asc.xlsx (90, 100)
# TZ_4_train_pca_PC07.asc.xlsx (90, 100)
# TZ_4_train_pca_PC08.asc.xlsx (90, 100)
# TZ_4_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_4_train_pca_PC01.asc.xlsx (90, 100)
# TZ_4_train_pca_PC02.asc.xlsx (90, 100)
# TZ_4_train_pca_PC03.asc.xlsx (90, 100)
# TZ_4_train_pca_PC04.asc.xlsx (90, 100)
# TZ_4_train_pca_PC05.asc.xlsx (90, 100)
# TZ_4_train_pca_PC06.asc.xlsx (90, 100)
# TZ_4_train_pca_PC07.asc.xlsx (90, 100)
# TZ_4_train_pca_PC08.asc.xlsx (90, 100)
# TZ_4_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_4_train_pca_PC01.asc.xlsx (90, 100)
# TZ_4_train_pca_PC02.asc.xlsx (90, 100)
# TZ_4_train_pca_PC03.asc.xlsx (90, 100)
# TZ_4_train_pca_PC04.asc.xlsx (90, 100)
# TZ_4_train_pca_PC05.asc.xlsx (90, 100)
# TZ_4_train_pca_PC06.asc.xlsx (90, 100)
# TZ_4_train_pca_PC07.asc.xlsx (90, 100)
# TZ_4_train_pca_PC08.asc.xlsx (90, 100)
# TZ_4_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_4_train_pca_PC01.asc.xlsx (90, 100)
# TZ_4_train_pca_PC02.asc.xlsx (90, 100)
# TZ_4_train_pca_PC03.asc.xlsx (90, 100)
# TZ_4_train_pca_PC04.asc.xlsx (90, 100)
# TZ_4_train_pca_PC05.asc.xlsx (90, 100)
# TZ_4_train_pca_PC06.asc.xlsx (90, 100)
# TZ_4_train_pca_PC07.asc.xlsx (90, 100)
# TZ_4_train_pca_PC08.asc.xlsx (90, 100)
# TZ_4_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_4_train_pca_PC01.asc.xlsx (90, 100)
# TZ_4_train_pca_PC02.asc.xlsx (90, 100)
# TZ_4_train_pca_PC03.asc.xlsx (90, 100)
# TZ_4_train_pca_PC04.asc.xlsx (90, 100)
# TZ_4_train_pca_PC05.asc.xlsx (90, 100)
# TZ_4_train_pca_PC06.asc.xlsx (90, 100)
# TZ_4_train_pca_PC07.asc.xlsx (90, 100)
# TZ_4_train_pca_PC08.asc.xlsx (90, 100)
# TZ_4_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_4_train_pca_PC01.asc.xlsx (90, 100)
# TZ_4_train_pca_PC02.asc.xlsx (90, 100)
# TZ_4_train_pca_PC03.asc.xlsx (90, 100)
# TZ_4_train_pca_PC04.asc.xlsx (90, 100)
# TZ_4_train_pca_PC05.asc.xlsx (90, 100)
# TZ_4_train_pca_PC06.asc.xlsx (90, 100)
# TZ_4_train_pca_PC07.asc.xlsx (90, 100)
# TZ_4_train_pca_PC08.asc.xlsx (90, 100)
# TZ_4_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_4_train_pca_PC01.asc.xlsx (90, 100)
# TZ_4_train_pca_PC02.asc.xlsx (90, 100)
# TZ_4_train_pca_PC03.asc.xlsx (90, 100)
# TZ_4_train_pca_PC04.asc.xlsx (90, 100)
# TZ_4_train_pca_PC05.asc.xlsx (90, 100)
# TZ_4_train_pca_PC06.asc.xlsx (90, 100)
# TZ_4_train_pca_PC07.asc.xlsx (90, 100)
# TZ_4_train_pca_PC08.asc.xlsx (90, 100)
# TZ_4_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_5_train_pca_PC01.asc.xlsx (90, 100)
# TZ_5_train_pca_PC02.asc.xlsx (90, 100)
# TZ_5_train_pca_PC03.asc.xlsx (90, 100)
# TZ_5_train_pca_PC04.asc.xlsx (90, 100)
# TZ_5_train_pca_PC05.asc.xlsx (90, 100)
# TZ_5_train_pca_PC06.asc.xlsx (90, 100)
# TZ_5_train_pca_PC07.asc.xlsx (90, 100)
# TZ_5_train_pca_PC08.asc.xlsx (90, 100)
# TZ_5_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_5_train_pca_PC01.asc.xlsx (90, 100)
# TZ_5_train_pca_PC02.asc.xlsx (90, 100)
# TZ_5_train_pca_PC03.asc.xlsx (90, 100)
# TZ_5_train_pca_PC04.asc.xlsx (90, 100)
# TZ_5_train_pca_PC05.asc.xlsx (90, 100)
# TZ_5_train_pca_PC06.asc.xlsx (90, 100)
# TZ_5_train_pca_PC07.asc.xlsx (90, 100)
# TZ_5_train_pca_PC08.asc.xlsx (90, 100)
# TZ_5_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_5_train_pca_PC01.asc.xlsx (90, 100)
# TZ_5_train_pca_PC02.asc.xlsx (90, 100)
# TZ_5_train_pca_PC03.asc.xlsx (90, 100)
# TZ_5_train_pca_PC04.asc.xlsx (90, 100)
# TZ_5_train_pca_PC05.asc.xlsx (90, 100)
# TZ_5_train_pca_PC06.asc.xlsx (90, 100)
# TZ_5_train_pca_PC07.asc.xlsx (90, 100)
# TZ_5_train_pca_PC08.asc.xlsx (90, 100)
# TZ_5_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_5_train_pca_PC01.asc.xlsx (90, 100)
# TZ_5_train_pca_PC02.asc.xlsx (90, 100)
# TZ_5_train_pca_PC03.asc.xlsx (90, 100)
# TZ_5_train_pca_PC04.asc.xlsx (90, 100)
# TZ_5_train_pca_PC05.asc.xlsx (90, 100)
# TZ_5_train_pca_PC06.asc.xlsx (90, 100)
# TZ_5_train_pca_PC07.asc.xlsx (90, 100)
# TZ_5_train_pca_PC08.asc.xlsx (90, 100)
# TZ_5_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_5_train_pca_PC01.asc.xlsx (90, 100)
# TZ_5_train_pca_PC02.asc.xlsx (90, 100)
# TZ_5_train_pca_PC03.asc.xlsx (90, 100)
# TZ_5_train_pca_PC04.asc.xlsx (90, 100)
# TZ_5_train_pca_PC05.asc.xlsx (90, 100)
# TZ_5_train_pca_PC06.asc.xlsx (90, 100)
# TZ_5_train_pca_PC07.asc.xlsx (90, 100)
# TZ_5_train_pca_PC08.asc.xlsx (90, 100)
# TZ_5_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_5_train_pca_PC01.asc.xlsx (90, 100)
# TZ_5_train_pca_PC02.asc.xlsx (90, 100)
# TZ_5_train_pca_PC03.asc.xlsx (90, 100)
# TZ_5_train_pca_PC04.asc.xlsx (90, 100)
# TZ_5_train_pca_PC05.asc.xlsx (90, 100)
# TZ_5_train_pca_PC06.asc.xlsx (90, 100)
# TZ_5_train_pca_PC07.asc.xlsx (90, 100)
# TZ_5_train_pca_PC08.asc.xlsx (90, 100)
# TZ_5_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_5_train_pca_PC01.asc.xlsx (90, 100)
# TZ_5_train_pca_PC02.asc.xlsx (90, 100)
# TZ_5_train_pca_PC03.asc.xlsx (90, 100)
# TZ_5_train_pca_PC04.asc.xlsx (90, 100)
# TZ_5_train_pca_PC05.asc.xlsx (90, 100)
# TZ_5_train_pca_PC06.asc.xlsx (90, 100)
# TZ_5_train_pca_PC07.asc.xlsx (90, 100)
# TZ_5_train_pca_PC08.asc.xlsx (90, 100)
# TZ_5_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_5_train_pca_PC01.asc.xlsx (90, 100)
# TZ_5_train_pca_PC02.asc.xlsx (90, 100)
# TZ_5_train_pca_PC03.asc.xlsx (90, 100)
# TZ_5_train_pca_PC04.asc.xlsx (90, 100)
# TZ_5_train_pca_PC05.asc.xlsx (90, 100)
# TZ_5_train_pca_PC06.asc.xlsx (90, 100)
# TZ_5_train_pca_PC07.asc.xlsx (90, 100)
# TZ_5_train_pca_PC08.asc.xlsx (90, 100)
# TZ_5_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg TZ
# TZ_5_train_pca_PC01.asc.xlsx (90, 100)
# TZ_5_train_pca_PC02.asc.xlsx (90, 100)
# TZ_5_train_pca_PC03.asc.xlsx (90, 100)
# TZ_5_train_pca_PC04.asc.xlsx (90, 100)
# TZ_5_train_pca_PC05.asc.xlsx (90, 100)
# TZ_5_train_pca_PC06.asc.xlsx (90, 100)
# TZ_5_train_pca_PC07.asc.xlsx (90, 100)
# TZ_5_train_pca_PC08.asc.xlsx (90, 100)
# TZ_5_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_1_train_pca_PC01.asc.xlsx (90, 100)
# IZ_1_train_pca_PC02.asc.xlsx (90, 100)
# IZ_1_train_pca_PC03.asc.xlsx (90, 100)
# IZ_1_train_pca_PC04.asc.xlsx (90, 100)
# IZ_1_train_pca_PC05.asc.xlsx (90, 100)
# IZ_1_train_pca_PC06.asc.xlsx (90, 100)
# IZ_1_train_pca_PC07.asc.xlsx (90, 100)
# IZ_1_train_pca_PC08.asc.xlsx (90, 100)
# IZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_1_train_pca_PC01.asc.xlsx (90, 100)
# IZ_1_train_pca_PC02.asc.xlsx (90, 100)
# IZ_1_train_pca_PC03.asc.xlsx (90, 100)
# IZ_1_train_pca_PC04.asc.xlsx (90, 100)
# IZ_1_train_pca_PC05.asc.xlsx (90, 100)
# IZ_1_train_pca_PC06.asc.xlsx (90, 100)
# IZ_1_train_pca_PC07.asc.xlsx (90, 100)
# IZ_1_train_pca_PC08.asc.xlsx (90, 100)
# IZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_1_train_pca_PC01.asc.xlsx (90, 100)
# IZ_1_train_pca_PC02.asc.xlsx (90, 100)
# IZ_1_train_pca_PC03.asc.xlsx (90, 100)
# IZ_1_train_pca_PC04.asc.xlsx (90, 100)
# IZ_1_train_pca_PC05.asc.xlsx (90, 100)
# IZ_1_train_pca_PC06.asc.xlsx (90, 100)
# IZ_1_train_pca_PC07.asc.xlsx (90, 100)
# IZ_1_train_pca_PC08.asc.xlsx (90, 100)
# IZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_1_train_pca_PC01.asc.xlsx (90, 100)
# IZ_1_train_pca_PC02.asc.xlsx (90, 100)
# IZ_1_train_pca_PC03.asc.xlsx (90, 100)
# IZ_1_train_pca_PC04.asc.xlsx (90, 100)
# IZ_1_train_pca_PC05.asc.xlsx (90, 100)
# IZ_1_train_pca_PC06.asc.xlsx (90, 100)
# IZ_1_train_pca_PC07.asc.xlsx (90, 100)
# IZ_1_train_pca_PC08.asc.xlsx (90, 100)
# IZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_1_train_pca_PC01.asc.xlsx (90, 100)
# IZ_1_train_pca_PC02.asc.xlsx (90, 100)
# IZ_1_train_pca_PC03.asc.xlsx (90, 100)
# IZ_1_train_pca_PC04.asc.xlsx (90, 100)
# IZ_1_train_pca_PC05.asc.xlsx (90, 100)
# IZ_1_train_pca_PC06.asc.xlsx (90, 100)
# IZ_1_train_pca_PC07.asc.xlsx (90, 100)
# IZ_1_train_pca_PC08.asc.xlsx (90, 100)
# IZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_1_train_pca_PC01.asc.xlsx (90, 100)
# IZ_1_train_pca_PC02.asc.xlsx (90, 100)
# IZ_1_train_pca_PC03.asc.xlsx (90, 100)
# IZ_1_train_pca_PC04.asc.xlsx (90, 100)
# IZ_1_train_pca_PC05.asc.xlsx (90, 100)
# IZ_1_train_pca_PC06.asc.xlsx (90, 100)
# IZ_1_train_pca_PC07.asc.xlsx (90, 100)
# IZ_1_train_pca_PC08.asc.xlsx (90, 100)
# IZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_1_train_pca_PC01.asc.xlsx (90, 100)
# IZ_1_train_pca_PC02.asc.xlsx (90, 100)
# IZ_1_train_pca_PC03.asc.xlsx (90, 100)
# IZ_1_train_pca_PC04.asc.xlsx (90, 100)
# IZ_1_train_pca_PC05.asc.xlsx (90, 100)
# IZ_1_train_pca_PC06.asc.xlsx (90, 100)
# IZ_1_train_pca_PC07.asc.xlsx (90, 100)
# IZ_1_train_pca_PC08.asc.xlsx (90, 100)
# IZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_1_train_pca_PC01.asc.xlsx (90, 100)
# IZ_1_train_pca_PC02.asc.xlsx (90, 100)
# IZ_1_train_pca_PC03.asc.xlsx (90, 100)
# IZ_1_train_pca_PC04.asc.xlsx (90, 100)
# IZ_1_train_pca_PC05.asc.xlsx (90, 100)
# IZ_1_train_pca_PC06.asc.xlsx (90, 100)
# IZ_1_train_pca_PC07.asc.xlsx (90, 100)
# IZ_1_train_pca_PC08.asc.xlsx (90, 100)
# IZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_1_train_pca_PC01.asc.xlsx (90, 100)
# IZ_1_train_pca_PC02.asc.xlsx (90, 100)
# IZ_1_train_pca_PC03.asc.xlsx (90, 100)
# IZ_1_train_pca_PC04.asc.xlsx (90, 100)
# IZ_1_train_pca_PC05.asc.xlsx (90, 100)
# IZ_1_train_pca_PC06.asc.xlsx (90, 100)
# IZ_1_train_pca_PC07.asc.xlsx (90, 100)
# IZ_1_train_pca_PC08.asc.xlsx (90, 100)
# IZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_2_train_pca_PC01.asc.xlsx (90, 100)
# IZ_2_train_pca_PC02.asc.xlsx (90, 100)
# IZ_2_train_pca_PC03.asc.xlsx (90, 100)
# IZ_2_train_pca_PC04.asc.xlsx (90, 100)
# IZ_2_train_pca_PC05.asc.xlsx (90, 100)
# IZ_2_train_pca_PC06.asc.xlsx (90, 100)
# IZ_2_train_pca_PC07.asc.xlsx (90, 100)
# IZ_2_train_pca_PC08.asc.xlsx (90, 100)
# IZ_2_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_2_train_pca_PC01.asc.xlsx (90, 100)
# IZ_2_train_pca_PC02.asc.xlsx (90, 100)
# IZ_2_train_pca_PC03.asc.xlsx (90, 100)
# IZ_2_train_pca_PC04.asc.xlsx (90, 100)
# IZ_2_train_pca_PC05.asc.xlsx (90, 100)
# IZ_2_train_pca_PC06.asc.xlsx (90, 100)
# IZ_2_train_pca_PC07.asc.xlsx (90, 100)
# IZ_2_train_pca_PC08.asc.xlsx (90, 100)
# IZ_2_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_2_train_pca_PC01.asc.xlsx (90, 100)
# IZ_2_train_pca_PC02.asc.xlsx (90, 100)
# IZ_2_train_pca_PC03.asc.xlsx (90, 100)
# IZ_2_train_pca_PC04.asc.xlsx (90, 100)
# IZ_2_train_pca_PC05.asc.xlsx (90, 100)
# IZ_2_train_pca_PC06.asc.xlsx (90, 100)
# IZ_2_train_pca_PC07.asc.xlsx (90, 100)
# IZ_2_train_pca_PC08.asc.xlsx (90, 100)
# IZ_2_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_2_train_pca_PC01.asc.xlsx (90, 100)
# IZ_2_train_pca_PC02.asc.xlsx (90, 100)
# IZ_2_train_pca_PC03.asc.xlsx (90, 100)
# IZ_2_train_pca_PC04.asc.xlsx (90, 100)
# IZ_2_train_pca_PC05.asc.xlsx (90, 100)
# IZ_2_train_pca_PC06.asc.xlsx (90, 100)
# IZ_2_train_pca_PC07.asc.xlsx (90, 100)
# IZ_2_train_pca_PC08.asc.xlsx (90, 100)
# IZ_2_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_2_train_pca_PC01.asc.xlsx (90, 100)
# IZ_2_train_pca_PC02.asc.xlsx (90, 100)
# IZ_2_train_pca_PC03.asc.xlsx (90, 100)
# IZ_2_train_pca_PC04.asc.xlsx (90, 100)
# IZ_2_train_pca_PC05.asc.xlsx (90, 100)
# IZ_2_train_pca_PC06.asc.xlsx (90, 100)
# IZ_2_train_pca_PC07.asc.xlsx (90, 100)
# IZ_2_train_pca_PC08.asc.xlsx (90, 100)
# IZ_2_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_2_train_pca_PC01.asc.xlsx (90, 100)
# IZ_2_train_pca_PC02.asc.xlsx (90, 100)
# IZ_2_train_pca_PC03.asc.xlsx (90, 100)
# IZ_2_train_pca_PC04.asc.xlsx (90, 100)
# IZ_2_train_pca_PC05.asc.xlsx (90, 100)
# IZ_2_train_pca_PC06.asc.xlsx (90, 100)
# IZ_2_train_pca_PC07.asc.xlsx (90, 100)
# IZ_2_train_pca_PC08.asc.xlsx (90, 100)
# IZ_2_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_2_train_pca_PC01.asc.xlsx (90, 100)
# IZ_2_train_pca_PC02.asc.xlsx (90, 100)
# IZ_2_train_pca_PC03.asc.xlsx (90, 100)
# IZ_2_train_pca_PC04.asc.xlsx (90, 100)
# IZ_2_train_pca_PC05.asc.xlsx (90, 100)
# IZ_2_train_pca_PC06.asc.xlsx (90, 100)
# IZ_2_train_pca_PC07.asc.xlsx (90, 100)
# IZ_2_train_pca_PC08.asc.xlsx (90, 100)
# IZ_2_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_2_train_pca_PC01.asc.xlsx (90, 100)
# IZ_2_train_pca_PC02.asc.xlsx (90, 100)
# IZ_2_train_pca_PC03.asc.xlsx (90, 100)
# IZ_2_train_pca_PC04.asc.xlsx (90, 100)
# IZ_2_train_pca_PC05.asc.xlsx (90, 100)
# IZ_2_train_pca_PC06.asc.xlsx (90, 100)
# IZ_2_train_pca_PC07.asc.xlsx (90, 100)
# IZ_2_train_pca_PC08.asc.xlsx (90, 100)
# IZ_2_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_2_train_pca_PC01.asc.xlsx (90, 100)
# IZ_2_train_pca_PC02.asc.xlsx (90, 100)
# IZ_2_train_pca_PC03.asc.xlsx (90, 100)
# IZ_2_train_pca_PC04.asc.xlsx (90, 100)
# IZ_2_train_pca_PC05.asc.xlsx (90, 100)
# IZ_2_train_pca_PC06.asc.xlsx (90, 100)
# IZ_2_train_pca_PC07.asc.xlsx (90, 100)
# IZ_2_train_pca_PC08.asc.xlsx (90, 100)
# IZ_2_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_3_train_pca_PC01.asc.xlsx (90, 100)
# IZ_3_train_pca_PC02.asc.xlsx (90, 100)
# IZ_3_train_pca_PC03.asc.xlsx (90, 100)
# IZ_3_train_pca_PC04.asc.xlsx (90, 100)
# IZ_3_train_pca_PC05.asc.xlsx (90, 100)
# IZ_3_train_pca_PC06.asc.xlsx (90, 100)
# IZ_3_train_pca_PC07.asc.xlsx (90, 100)
# IZ_3_train_pca_PC08.asc.xlsx (90, 100)
# IZ_3_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_3_train_pca_PC01.asc.xlsx (90, 100)
# IZ_3_train_pca_PC02.asc.xlsx (90, 100)
# IZ_3_train_pca_PC03.asc.xlsx (90, 100)
# IZ_3_train_pca_PC04.asc.xlsx (90, 100)
# IZ_3_train_pca_PC05.asc.xlsx (90, 100)
# IZ_3_train_pca_PC06.asc.xlsx (90, 100)
# IZ_3_train_pca_PC07.asc.xlsx (90, 100)
# IZ_3_train_pca_PC08.asc.xlsx (90, 100)
# IZ_3_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_3_train_pca_PC01.asc.xlsx (90, 100)
# IZ_3_train_pca_PC02.asc.xlsx (90, 100)
# IZ_3_train_pca_PC03.asc.xlsx (90, 100)
# IZ_3_train_pca_PC04.asc.xlsx (90, 100)
# IZ_3_train_pca_PC05.asc.xlsx (90, 100)
# IZ_3_train_pca_PC06.asc.xlsx (90, 100)
# IZ_3_train_pca_PC07.asc.xlsx (90, 100)
# IZ_3_train_pca_PC08.asc.xlsx (90, 100)
# IZ_3_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_3_train_pca_PC01.asc.xlsx (90, 100)
# IZ_3_train_pca_PC02.asc.xlsx (90, 100)
# IZ_3_train_pca_PC03.asc.xlsx (90, 100)
# IZ_3_train_pca_PC04.asc.xlsx (90, 100)
# IZ_3_train_pca_PC05.asc.xlsx (90, 100)
# IZ_3_train_pca_PC06.asc.xlsx (90, 100)
# IZ_3_train_pca_PC07.asc.xlsx (90, 100)
# IZ_3_train_pca_PC08.asc.xlsx (90, 100)
# IZ_3_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_3_train_pca_PC01.asc.xlsx (90, 100)
# IZ_3_train_pca_PC02.asc.xlsx (90, 100)
# IZ_3_train_pca_PC03.asc.xlsx (90, 100)
# IZ_3_train_pca_PC04.asc.xlsx (90, 100)
# IZ_3_train_pca_PC05.asc.xlsx (90, 100)
# IZ_3_train_pca_PC06.asc.xlsx (90, 100)
# IZ_3_train_pca_PC07.asc.xlsx (90, 100)
# IZ_3_train_pca_PC08.asc.xlsx (90, 100)
# IZ_3_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_3_train_pca_PC01.asc.xlsx (90, 100)
# IZ_3_train_pca_PC02.asc.xlsx (90, 100)
# IZ_3_train_pca_PC03.asc.xlsx (90, 100)
# IZ_3_train_pca_PC04.asc.xlsx (90, 100)
# IZ_3_train_pca_PC05.asc.xlsx (90, 100)
# IZ_3_train_pca_PC06.asc.xlsx (90, 100)
# IZ_3_train_pca_PC07.asc.xlsx (90, 100)
# IZ_3_train_pca_PC08.asc.xlsx (90, 100)
# IZ_3_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_3_train_pca_PC01.asc.xlsx (90, 100)
# IZ_3_train_pca_PC02.asc.xlsx (90, 100)
# IZ_3_train_pca_PC03.asc.xlsx (90, 100)
# IZ_3_train_pca_PC04.asc.xlsx (90, 100)
# IZ_3_train_pca_PC05.asc.xlsx (90, 100)
# IZ_3_train_pca_PC06.asc.xlsx (90, 100)
# IZ_3_train_pca_PC07.asc.xlsx (90, 100)
# IZ_3_train_pca_PC08.asc.xlsx (90, 100)
# IZ_3_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_3_train_pca_PC01.asc.xlsx (90, 100)
# IZ_3_train_pca_PC02.asc.xlsx (90, 100)
# IZ_3_train_pca_PC03.asc.xlsx (90, 100)
# IZ_3_train_pca_PC04.asc.xlsx (90, 100)
# IZ_3_train_pca_PC05.asc.xlsx (90, 100)
# IZ_3_train_pca_PC06.asc.xlsx (90, 100)
# IZ_3_train_pca_PC07.asc.xlsx (90, 100)
# IZ_3_train_pca_PC08.asc.xlsx (90, 100)
# IZ_3_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_3_train_pca_PC01.asc.xlsx (90, 100)
# IZ_3_train_pca_PC02.asc.xlsx (90, 100)
# IZ_3_train_pca_PC03.asc.xlsx (90, 100)
# IZ_3_train_pca_PC04.asc.xlsx (90, 100)
# IZ_3_train_pca_PC05.asc.xlsx (90, 100)
# IZ_3_train_pca_PC06.asc.xlsx (90, 100)
# IZ_3_train_pca_PC07.asc.xlsx (90, 100)
# IZ_3_train_pca_PC08.asc.xlsx (90, 100)
# IZ_3_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_4_train_pca_PC01.asc.xlsx (90, 100)
# IZ_4_train_pca_PC02.asc.xlsx (90, 100)
# IZ_4_train_pca_PC03.asc.xlsx (90, 100)
# IZ_4_train_pca_PC04.asc.xlsx (90, 100)
# IZ_4_train_pca_PC05.asc.xlsx (90, 100)
# IZ_4_train_pca_PC06.asc.xlsx (90, 100)
# IZ_4_train_pca_PC07.asc.xlsx (90, 100)
# IZ_4_train_pca_PC08.asc.xlsx (90, 100)
# IZ_4_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_4_train_pca_PC01.asc.xlsx (90, 100)
# IZ_4_train_pca_PC02.asc.xlsx (90, 100)
# IZ_4_train_pca_PC03.asc.xlsx (90, 100)
# IZ_4_train_pca_PC04.asc.xlsx (90, 100)
# IZ_4_train_pca_PC05.asc.xlsx (90, 100)
# IZ_4_train_pca_PC06.asc.xlsx (90, 100)
# IZ_4_train_pca_PC07.asc.xlsx (90, 100)
# IZ_4_train_pca_PC08.asc.xlsx (90, 100)
# IZ_4_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_4_train_pca_PC01.asc.xlsx (90, 100)
# IZ_4_train_pca_PC02.asc.xlsx (90, 100)
# IZ_4_train_pca_PC03.asc.xlsx (90, 100)
# IZ_4_train_pca_PC04.asc.xlsx (90, 100)
# IZ_4_train_pca_PC05.asc.xlsx (90, 100)
# IZ_4_train_pca_PC06.asc.xlsx (90, 100)
# IZ_4_train_pca_PC07.asc.xlsx (90, 100)
# IZ_4_train_pca_PC08.asc.xlsx (90, 100)
# IZ_4_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_4_train_pca_PC01.asc.xlsx (90, 100)
# IZ_4_train_pca_PC02.asc.xlsx (90, 100)
# IZ_4_train_pca_PC03.asc.xlsx (90, 100)
# IZ_4_train_pca_PC04.asc.xlsx (90, 100)
# IZ_4_train_pca_PC05.asc.xlsx (90, 100)
# IZ_4_train_pca_PC06.asc.xlsx (90, 100)
# IZ_4_train_pca_PC07.asc.xlsx (90, 100)
# IZ_4_train_pca_PC08.asc.xlsx (90, 100)
# IZ_4_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_4_train_pca_PC01.asc.xlsx (90, 100)
# IZ_4_train_pca_PC02.asc.xlsx (90, 100)
# IZ_4_train_pca_PC03.asc.xlsx (90, 100)
# IZ_4_train_pca_PC04.asc.xlsx (90, 100)
# IZ_4_train_pca_PC05.asc.xlsx (90, 100)
# IZ_4_train_pca_PC06.asc.xlsx (90, 100)
# IZ_4_train_pca_PC07.asc.xlsx (90, 100)
# IZ_4_train_pca_PC08.asc.xlsx (90, 100)
# IZ_4_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_4_train_pca_PC01.asc.xlsx (90, 100)
# IZ_4_train_pca_PC02.asc.xlsx (90, 100)
# IZ_4_train_pca_PC03.asc.xlsx (90, 100)
# IZ_4_train_pca_PC04.asc.xlsx (90, 100)
# IZ_4_train_pca_PC05.asc.xlsx (90, 100)
# IZ_4_train_pca_PC06.asc.xlsx (90, 100)
# IZ_4_train_pca_PC07.asc.xlsx (90, 100)
# IZ_4_train_pca_PC08.asc.xlsx (90, 100)
# IZ_4_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_4_train_pca_PC01.asc.xlsx (90, 100)
# IZ_4_train_pca_PC02.asc.xlsx (90, 100)
# IZ_4_train_pca_PC03.asc.xlsx (90, 100)
# IZ_4_train_pca_PC04.asc.xlsx (90, 100)
# IZ_4_train_pca_PC05.asc.xlsx (90, 100)
# IZ_4_train_pca_PC06.asc.xlsx (90, 100)
# IZ_4_train_pca_PC07.asc.xlsx (90, 100)
# IZ_4_train_pca_PC08.asc.xlsx (90, 100)
# IZ_4_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_4_train_pca_PC01.asc.xlsx (90, 100)
# IZ_4_train_pca_PC02.asc.xlsx (90, 100)
# IZ_4_train_pca_PC03.asc.xlsx (90, 100)
# IZ_4_train_pca_PC04.asc.xlsx (90, 100)
# IZ_4_train_pca_PC05.asc.xlsx (90, 100)
# IZ_4_train_pca_PC06.asc.xlsx (90, 100)
# IZ_4_train_pca_PC07.asc.xlsx (90, 100)
# IZ_4_train_pca_PC08.asc.xlsx (90, 100)
# IZ_4_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_4_train_pca_PC01.asc.xlsx (90, 100)
# IZ_4_train_pca_PC02.asc.xlsx (90, 100)
# IZ_4_train_pca_PC03.asc.xlsx (90, 100)
# IZ_4_train_pca_PC04.asc.xlsx (90, 100)
# IZ_4_train_pca_PC05.asc.xlsx (90, 100)
# IZ_4_train_pca_PC06.asc.xlsx (90, 100)
# IZ_4_train_pca_PC07.asc.xlsx (90, 100)
# IZ_4_train_pca_PC08.asc.xlsx (90, 100)
# IZ_4_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_5_train_pca_PC01.asc.xlsx (90, 100)
# IZ_5_train_pca_PC02.asc.xlsx (90, 100)
# IZ_5_train_pca_PC03.asc.xlsx (90, 100)
# IZ_5_train_pca_PC04.asc.xlsx (90, 100)
# IZ_5_train_pca_PC05.asc.xlsx (90, 100)
# IZ_5_train_pca_PC06.asc.xlsx (90, 100)
# IZ_5_train_pca_PC07.asc.xlsx (90, 100)
# IZ_5_train_pca_PC08.asc.xlsx (90, 100)
# IZ_5_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_5_train_pca_PC01.asc.xlsx (90, 100)
# IZ_5_train_pca_PC02.asc.xlsx (90, 100)
# IZ_5_train_pca_PC03.asc.xlsx (90, 100)
# IZ_5_train_pca_PC04.asc.xlsx (90, 100)
# IZ_5_train_pca_PC05.asc.xlsx (90, 100)
# IZ_5_train_pca_PC06.asc.xlsx (90, 100)
# IZ_5_train_pca_PC07.asc.xlsx (90, 100)
# IZ_5_train_pca_PC08.asc.xlsx (90, 100)
# IZ_5_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_5_train_pca_PC01.asc.xlsx (90, 100)
# IZ_5_train_pca_PC02.asc.xlsx (90, 100)
# IZ_5_train_pca_PC03.asc.xlsx (90, 100)
# IZ_5_train_pca_PC04.asc.xlsx (90, 100)
# IZ_5_train_pca_PC05.asc.xlsx (90, 100)
# IZ_5_train_pca_PC06.asc.xlsx (90, 100)
# IZ_5_train_pca_PC07.asc.xlsx (90, 100)
# IZ_5_train_pca_PC08.asc.xlsx (90, 100)
# IZ_5_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_5_train_pca_PC01.asc.xlsx (90, 100)
# IZ_5_train_pca_PC02.asc.xlsx (90, 100)
# IZ_5_train_pca_PC03.asc.xlsx (90, 100)
# IZ_5_train_pca_PC04.asc.xlsx (90, 100)
# IZ_5_train_pca_PC05.asc.xlsx (90, 100)
# IZ_5_train_pca_PC06.asc.xlsx (90, 100)
# IZ_5_train_pca_PC07.asc.xlsx (90, 100)
# IZ_5_train_pca_PC08.asc.xlsx (90, 100)
# IZ_5_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_5_train_pca_PC01.asc.xlsx (90, 100)
# IZ_5_train_pca_PC02.asc.xlsx (90, 100)
# IZ_5_train_pca_PC03.asc.xlsx (90, 100)
# IZ_5_train_pca_PC04.asc.xlsx (90, 100)
# IZ_5_train_pca_PC05.asc.xlsx (90, 100)
# IZ_5_train_pca_PC06.asc.xlsx (90, 100)
# IZ_5_train_pca_PC07.asc.xlsx (90, 100)
# IZ_5_train_pca_PC08.asc.xlsx (90, 100)
# IZ_5_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_5_train_pca_PC01.asc.xlsx (90, 100)
# IZ_5_train_pca_PC02.asc.xlsx (90, 100)
# IZ_5_train_pca_PC03.asc.xlsx (90, 100)
# IZ_5_train_pca_PC04.asc.xlsx (90, 100)
# IZ_5_train_pca_PC05.asc.xlsx (90, 100)
# IZ_5_train_pca_PC06.asc.xlsx (90, 100)
# IZ_5_train_pca_PC07.asc.xlsx (90, 100)
# IZ_5_train_pca_PC08.asc.xlsx (90, 100)
# IZ_5_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_5_train_pca_PC01.asc.xlsx (90, 100)
# IZ_5_train_pca_PC02.asc.xlsx (90, 100)
# IZ_5_train_pca_PC03.asc.xlsx (90, 100)
# IZ_5_train_pca_PC04.asc.xlsx (90, 100)
# IZ_5_train_pca_PC05.asc.xlsx (90, 100)
# IZ_5_train_pca_PC06.asc.xlsx (90, 100)
# IZ_5_train_pca_PC07.asc.xlsx (90, 100)
# IZ_5_train_pca_PC08.asc.xlsx (90, 100)
# IZ_5_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_5_train_pca_PC01.asc.xlsx (90, 100)
# IZ_5_train_pca_PC02.asc.xlsx (90, 100)
# IZ_5_train_pca_PC03.asc.xlsx (90, 100)
# IZ_5_train_pca_PC04.asc.xlsx (90, 100)
# IZ_5_train_pca_PC05.asc.xlsx (90, 100)
# IZ_5_train_pca_PC06.asc.xlsx (90, 100)
# IZ_5_train_pca_PC07.asc.xlsx (90, 100)
# IZ_5_train_pca_PC08.asc.xlsx (90, 100)
# IZ_5_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg IZ
# IZ_5_train_pca_PC01.asc.xlsx (90, 100)
# IZ_5_train_pca_PC02.asc.xlsx (90, 100)
# IZ_5_train_pca_PC03.asc.xlsx (90, 100)
# IZ_5_train_pca_PC04.asc.xlsx (90, 100)
# IZ_5_train_pca_PC05.asc.xlsx (90, 100)
# IZ_5_train_pca_PC06.asc.xlsx (90, 100)
# IZ_5_train_pca_PC07.asc.xlsx (90, 100)
# IZ_5_train_pca_PC08.asc.xlsx (90, 100)
# IZ_5_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg GZ
# GZ_1_train_pca_PC01.asc.xlsx (90, 100)
# GZ_1_train_pca_PC02.asc.xlsx (90, 100)
# GZ_1_train_pca_PC03.asc.xlsx (90, 100)
# GZ_1_train_pca_PC04.asc.xlsx (90, 100)
# GZ_1_train_pca_PC05.asc.xlsx (90, 100)
# GZ_1_train_pca_PC06.asc.xlsx (90, 100)
# GZ_1_train_pca_PC07.asc.xlsx (90, 100)
# GZ_1_train_pca_PC08.asc.xlsx (90, 100)
# GZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg GZ
# GZ_1_train_pca_PC01.asc.xlsx (90, 100)
# GZ_1_train_pca_PC02.asc.xlsx (90, 100)
# GZ_1_train_pca_PC03.asc.xlsx (90, 100)
# GZ_1_train_pca_PC04.asc.xlsx (90, 100)
# GZ_1_train_pca_PC05.asc.xlsx (90, 100)
# GZ_1_train_pca_PC06.asc.xlsx (90, 100)
# GZ_1_train_pca_PC07.asc.xlsx (90, 100)
# GZ_1_train_pca_PC08.asc.xlsx (90, 100)
# GZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg GZ
# GZ_1_train_pca_PC01.asc.xlsx (90, 100)
# GZ_1_train_pca_PC02.asc.xlsx (90, 100)
# GZ_1_train_pca_PC03.asc.xlsx (90, 100)
# GZ_1_train_pca_PC04.asc.xlsx (90, 100)
# GZ_1_train_pca_PC05.asc.xlsx (90, 100)
# GZ_1_train_pca_PC06.asc.xlsx (90, 100)
# GZ_1_train_pca_PC07.asc.xlsx (90, 100)
# GZ_1_train_pca_PC08.asc.xlsx (90, 100)
# GZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg GZ
# GZ_1_train_pca_PC01.asc.xlsx (90, 100)
# GZ_1_train_pca_PC02.asc.xlsx (90, 100)
# GZ_1_train_pca_PC03.asc.xlsx (90, 100)
# GZ_1_train_pca_PC04.asc.xlsx (90, 100)
# GZ_1_train_pca_PC05.asc.xlsx (90, 100)
# GZ_1_train_pca_PC06.asc.xlsx (90, 100)
# GZ_1_train_pca_PC07.asc.xlsx (90, 100)
# GZ_1_train_pca_PC08.asc.xlsx (90, 100)
# GZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg GZ
# GZ_1_train_pca_PC01.asc.xlsx (90, 100)
# GZ_1_train_pca_PC02.asc.xlsx (90, 100)
# GZ_1_train_pca_PC03.asc.xlsx (90, 100)
# GZ_1_train_pca_PC04.asc.xlsx (90, 100)
# GZ_1_train_pca_PC05.asc.xlsx (90, 100)
# GZ_1_train_pca_PC06.asc.xlsx (90, 100)
# GZ_1_train_pca_PC07.asc.xlsx (90, 100)
# GZ_1_train_pca_PC08.asc.xlsx (90, 100)
# GZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg GZ
# GZ_1_train_pca_PC01.asc.xlsx (90, 100)
# GZ_1_train_pca_PC02.asc.xlsx (90, 100)
# GZ_1_train_pca_PC03.asc.xlsx (90, 100)
# GZ_1_train_pca_PC04.asc.xlsx (90, 100)
# GZ_1_train_pca_PC05.asc.xlsx (90, 100)
# GZ_1_train_pca_PC06.asc.xlsx (90, 100)
# GZ_1_train_pca_PC07.asc.xlsx (90, 100)
# GZ_1_train_pca_PC08.asc.xlsx (90, 100)
# GZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg GZ
# GZ_1_train_pca_PC01.asc.xlsx (90, 100)
# GZ_1_train_pca_PC02.asc.xlsx (90, 100)
# GZ_1_train_pca_PC03.asc.xlsx (90, 100)
# GZ_1_train_pca_PC04.asc.xlsx (90, 100)
# GZ_1_train_pca_PC05.asc.xlsx (90, 100)
# GZ_1_train_pca_PC06.asc.xlsx (90, 100)
# GZ_1_train_pca_PC07.asc.xlsx (90, 100)
# GZ_1_train_pca_PC08.asc.xlsx (90, 100)
# GZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg GZ
# GZ_1_train_pca_PC01.asc.xlsx (90, 100)
# GZ_1_train_pca_PC02.asc.xlsx (90, 100)
# GZ_1_train_pca_PC03.asc.xlsx (90, 100)
# GZ_1_train_pca_PC04.asc.xlsx (90, 100)
# GZ_1_train_pca_PC05.asc.xlsx (90, 100)
# GZ_1_train_pca_PC06.asc.xlsx (90, 100)
# GZ_1_train_pca_PC07.asc.xlsx (90, 100)
# GZ_1_train_pca_PC08.asc.xlsx (90, 100)
# GZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg GZ
# GZ_1_train_pca_PC01.asc.xlsx (90, 100)
# GZ_1_train_pca_PC02.asc.xlsx (90, 100)
# GZ_1_train_pca_PC03.asc.xlsx (90, 100)
# GZ_1_train_pca_PC04.asc.xlsx (90, 100)
# GZ_1_train_pca_PC05.asc.xlsx (90, 100)
# GZ_1_train_pca_PC06.asc.xlsx (90, 100)
# GZ_1_train_pca_PC07.asc.xlsx (90, 100)
# GZ_1_train_pca_PC08.asc.xlsx (90, 100)
# GZ_1_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg GZ
# GZ_2_train_pca_PC01.asc.xlsx (90, 100)
# GZ_2_train_pca_PC02.asc.xlsx (90, 100)
# GZ_2_train_pca_PC03.asc.xlsx (90, 100)
# GZ_2_train_pca_PC04.asc.xlsx (90, 100)
# GZ_2_train_pca_PC05.asc.xlsx (90, 100)
# GZ_2_train_pca_PC06.asc.xlsx (90, 100)
# GZ_2_train_pca_PC07.asc.xlsx (90, 100)
# GZ_2_train_pca_PC08.asc.xlsx (90, 100)
# GZ_2_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg GZ
# GZ_2_train_pca_PC01.asc.xlsx (90, 100)
# GZ_2_train_pca_PC02.asc.xlsx (90, 100)
# GZ_2_train_pca_PC03.asc.xlsx (90, 100)
# GZ_2_train_pca_PC04.asc.xlsx (90, 100)
# GZ_2_train_pca_PC05.asc.xlsx (90, 100)
# GZ_2_train_pca_PC06.asc.xlsx (90, 100)
# GZ_2_train_pca_PC07.asc.xlsx (90, 100)
# GZ_2_train_pca_PC08.asc.xlsx (90, 100)
# GZ_2_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg GZ
# GZ_2_train_pca_PC01.asc.xlsx (90, 100)
# GZ_2_train_pca_PC02.asc.xlsx (90, 100)
# GZ_2_train_pca_PC03.asc.xlsx (90, 100)
# GZ_2_train_pca_PC04.asc.xlsx (90, 100)
# GZ_2_train_pca_PC05.asc.xlsx (90, 100)
# GZ_2_train_pca_PC06.asc.xlsx (90, 100)
# GZ_2_train_pca_PC07.asc.xlsx (90, 100)
# GZ_2_train_pca_PC08.asc.xlsx (90, 100)
# GZ_2_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg GZ
# GZ_2_train_pca_PC01.asc.xlsx (90, 100)
# GZ_2_train_pca_PC02.asc.xlsx (90, 100)
# GZ_2_train_pca_PC03.asc.xlsx (90, 100)
# GZ_2_train_pca_PC04.asc.xlsx (90, 100)
# GZ_2_train_pca_PC05.asc.xlsx (90, 100)
# GZ_2_train_pca_PC06.asc.xlsx (90, 100)
# GZ_2_train_pca_PC07.asc.xlsx (90, 100)
# GZ_2_train_pca_PC08.asc.xlsx (90, 100)
# GZ_2_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg GZ
# GZ_2_train_pca_PC01.asc.xlsx (90, 100)
# GZ_2_train_pca_PC02.asc.xlsx (90, 100)
# GZ_2_train_pca_PC03.asc.xlsx (90, 100)
# GZ_2_train_pca_PC04.asc.xlsx (90, 100)
# GZ_2_train_pca_PC05.asc.xlsx (90, 100)
# GZ_2_train_pca_PC06.asc.xlsx (90, 100)
# GZ_2_train_pca_PC07.asc.xlsx (90, 100)
# GZ_2_train_pca_PC08.asc.xlsx (90, 100)
# GZ_2_train_pca_PC09.asc.xlsx (90, 100)
# Number of grid points per file : 9000.0
# Number of grid points in total: 81000
# gridpoints: 9000
# Berg GZ
# GZ_2_train_pca_PC01.asc.xlsx (90, 100)
# GZ_2_train_pca_PC02.asc.xlsx (90, 100)
# GZ_2_train_pca_PC03.asc.xlsx (90, 100)
# GZ_2_train_pca_PC04.asc.xlsx (90, 100)
# GZ_2_train_pca_PC05.asc.xlsx (90, 100)
# GZ_2_train_pca_PC06.asc.xlsx (90, 100)
# GZ_2_train_pca_PC07.asc.xlsx (90, 100)
# ...
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_2_train_pca_PC01.asc.xlsx (74, 100)
# GZ_2_train_pca_PC02.asc.xlsx (74, 100)
# GZ_2_train_pca_PC03.asc.xlsx (74, 100)
# GZ_2_train_pca_PC04.asc.xlsx (74, 100)
# GZ_2_train_pca_PC05.asc.xlsx (74, 100)
# GZ_2_train_pca_PC06.asc.xlsx (74, 100)
# GZ_2_train_pca_PC07.asc.xlsx (74, 100)
# GZ_2_train_pca_PC08.asc.xlsx (74, 100)
# GZ_2_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_2_train_pca_PC01.asc.xlsx (74, 100)
# GZ_2_train_pca_PC02.asc.xlsx (74, 100)
# GZ_2_train_pca_PC03.asc.xlsx (74, 100)
# GZ_2_train_pca_PC04.asc.xlsx (74, 100)
# GZ_2_train_pca_PC05.asc.xlsx (74, 100)
# GZ_2_train_pca_PC06.asc.xlsx (74, 100)
# GZ_2_train_pca_PC07.asc.xlsx (74, 100)
# GZ_2_train_pca_PC08.asc.xlsx (74, 100)
# GZ_2_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_2_train_pca_PC01.asc.xlsx (74, 100)
# GZ_2_train_pca_PC02.asc.xlsx (74, 100)
# GZ_2_train_pca_PC03.asc.xlsx (74, 100)
# GZ_2_train_pca_PC04.asc.xlsx (74, 100)
# GZ_2_train_pca_PC05.asc.xlsx (74, 100)
# GZ_2_train_pca_PC06.asc.xlsx (74, 100)
# GZ_2_train_pca_PC07.asc.xlsx (74, 100)
# GZ_2_train_pca_PC08.asc.xlsx (74, 100)
# GZ_2_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_2_train_pca_PC01.asc.xlsx (74, 100)
# GZ_2_train_pca_PC02.asc.xlsx (74, 100)
# GZ_2_train_pca_PC03.asc.xlsx (74, 100)
# GZ_2_train_pca_PC04.asc.xlsx (74, 100)
# GZ_2_train_pca_PC05.asc.xlsx (74, 100)
# GZ_2_train_pca_PC06.asc.xlsx (74, 100)
# GZ_2_train_pca_PC07.asc.xlsx (74, 100)
# GZ_2_train_pca_PC08.asc.xlsx (74, 100)
# GZ_2_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_2_train_pca_PC01.asc.xlsx (74, 100)
# GZ_2_train_pca_PC02.asc.xlsx (74, 100)
# GZ_2_train_pca_PC03.asc.xlsx (74, 100)
# GZ_2_train_pca_PC04.asc.xlsx (74, 100)
# GZ_2_train_pca_PC05.asc.xlsx (74, 100)
# GZ_2_train_pca_PC06.asc.xlsx (74, 100)
# GZ_2_train_pca_PC07.asc.xlsx (74, 100)
# GZ_2_train_pca_PC08.asc.xlsx (74, 100)
# GZ_2_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_2_train_pca_PC01.asc.xlsx (74, 100)
# GZ_2_train_pca_PC02.asc.xlsx (74, 100)
# GZ_2_train_pca_PC03.asc.xlsx (74, 100)
# GZ_2_train_pca_PC04.asc.xlsx (74, 100)
# GZ_2_train_pca_PC05.asc.xlsx (74, 100)
# GZ_2_train_pca_PC06.asc.xlsx (74, 100)
# GZ_2_train_pca_PC07.asc.xlsx (74, 100)
# GZ_2_train_pca_PC08.asc.xlsx (74, 100)
# GZ_2_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_2_train_pca_PC01.asc.xlsx (74, 100)
# GZ_2_train_pca_PC02.asc.xlsx (74, 100)
# GZ_2_train_pca_PC03.asc.xlsx (74, 100)
# GZ_2_train_pca_PC04.asc.xlsx (74, 100)
# GZ_2_train_pca_PC05.asc.xlsx (74, 100)
# GZ_2_train_pca_PC06.asc.xlsx (74, 100)
# GZ_2_train_pca_PC07.asc.xlsx (74, 100)
# GZ_2_train_pca_PC08.asc.xlsx (74, 100)
# GZ_2_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_2_train_pca_PC01.asc.xlsx (74, 100)
# GZ_2_train_pca_PC02.asc.xlsx (74, 100)
# GZ_2_train_pca_PC03.asc.xlsx (74, 100)
# GZ_2_train_pca_PC04.asc.xlsx (74, 100)
# GZ_2_train_pca_PC05.asc.xlsx (74, 100)
# GZ_2_train_pca_PC06.asc.xlsx (74, 100)
# GZ_2_train_pca_PC07.asc.xlsx (74, 100)
# GZ_2_train_pca_PC08.asc.xlsx (74, 100)
# GZ_2_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_3_train_pca_PC01.asc.xlsx (74, 100)
# GZ_3_train_pca_PC02.asc.xlsx (74, 100)
# GZ_3_train_pca_PC03.asc.xlsx (74, 100)
# GZ_3_train_pca_PC04.asc.xlsx (74, 100)
# GZ_3_train_pca_PC05.asc.xlsx (74, 100)
# GZ_3_train_pca_PC06.asc.xlsx (74, 100)
# GZ_3_train_pca_PC07.asc.xlsx (74, 100)
# GZ_3_train_pca_PC08.asc.xlsx (74, 100)
# GZ_3_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_3_train_pca_PC01.asc.xlsx (74, 100)
# GZ_3_train_pca_PC02.asc.xlsx (74, 100)
# GZ_3_train_pca_PC03.asc.xlsx (74, 100)
# GZ_3_train_pca_PC04.asc.xlsx (74, 100)
# GZ_3_train_pca_PC05.asc.xlsx (74, 100)
# GZ_3_train_pca_PC06.asc.xlsx (74, 100)
# GZ_3_train_pca_PC07.asc.xlsx (74, 100)
# GZ_3_train_pca_PC08.asc.xlsx (74, 100)
# GZ_3_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_3_train_pca_PC01.asc.xlsx (74, 100)
# GZ_3_train_pca_PC02.asc.xlsx (74, 100)
# GZ_3_train_pca_PC03.asc.xlsx (74, 100)
# GZ_3_train_pca_PC04.asc.xlsx (74, 100)
# GZ_3_train_pca_PC05.asc.xlsx (74, 100)
# GZ_3_train_pca_PC06.asc.xlsx (74, 100)
# GZ_3_train_pca_PC07.asc.xlsx (74, 100)
# GZ_3_train_pca_PC08.asc.xlsx (74, 100)
# GZ_3_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_3_train_pca_PC01.asc.xlsx (74, 100)
# GZ_3_train_pca_PC02.asc.xlsx (74, 100)
# GZ_3_train_pca_PC03.asc.xlsx (74, 100)
# GZ_3_train_pca_PC04.asc.xlsx (74, 100)
# GZ_3_train_pca_PC05.asc.xlsx (74, 100)
# GZ_3_train_pca_PC06.asc.xlsx (74, 100)
# GZ_3_train_pca_PC07.asc.xlsx (74, 100)
# GZ_3_train_pca_PC08.asc.xlsx (74, 100)
# GZ_3_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_3_train_pca_PC01.asc.xlsx (74, 100)
# GZ_3_train_pca_PC02.asc.xlsx (74, 100)
# GZ_3_train_pca_PC03.asc.xlsx (74, 100)
# GZ_3_train_pca_PC04.asc.xlsx (74, 100)
# GZ_3_train_pca_PC05.asc.xlsx (74, 100)
# GZ_3_train_pca_PC06.asc.xlsx (74, 100)
# GZ_3_train_pca_PC07.asc.xlsx (74, 100)
# GZ_3_train_pca_PC08.asc.xlsx (74, 100)
# GZ_3_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_3_train_pca_PC01.asc.xlsx (74, 100)
# GZ_3_train_pca_PC02.asc.xlsx (74, 100)
# GZ_3_train_pca_PC03.asc.xlsx (74, 100)
# GZ_3_train_pca_PC04.asc.xlsx (74, 100)
# GZ_3_train_pca_PC05.asc.xlsx (74, 100)
# GZ_3_train_pca_PC06.asc.xlsx (74, 100)
# GZ_3_train_pca_PC07.asc.xlsx (74, 100)
# GZ_3_train_pca_PC08.asc.xlsx (74, 100)
# GZ_3_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_3_train_pca_PC01.asc.xlsx (74, 100)
# GZ_3_train_pca_PC02.asc.xlsx (74, 100)
# GZ_3_train_pca_PC03.asc.xlsx (74, 100)
# GZ_3_train_pca_PC04.asc.xlsx (74, 100)
# GZ_3_train_pca_PC05.asc.xlsx (74, 100)
# GZ_3_train_pca_PC06.asc.xlsx (74, 100)
# GZ_3_train_pca_PC07.asc.xlsx (74, 100)
# GZ_3_train_pca_PC08.asc.xlsx (74, 100)
# GZ_3_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_3_train_pca_PC01.asc.xlsx (74, 100)
# GZ_3_train_pca_PC02.asc.xlsx (74, 100)
# GZ_3_train_pca_PC03.asc.xlsx (74, 100)
# GZ_3_train_pca_PC04.asc.xlsx (74, 100)
# GZ_3_train_pca_PC05.asc.xlsx (74, 100)
# GZ_3_train_pca_PC06.asc.xlsx (74, 100)
# GZ_3_train_pca_PC07.asc.xlsx (74, 100)
# GZ_3_train_pca_PC08.asc.xlsx (74, 100)
# GZ_3_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_3_train_pca_PC01.asc.xlsx (74, 100)
# GZ_3_train_pca_PC02.asc.xlsx (74, 100)
# GZ_3_train_pca_PC03.asc.xlsx (74, 100)
# GZ_3_train_pca_PC04.asc.xlsx (74, 100)
# GZ_3_train_pca_PC05.asc.xlsx (74, 100)
# GZ_3_train_pca_PC06.asc.xlsx (74, 100)
# GZ_3_train_pca_PC07.asc.xlsx (74, 100)
# GZ_3_train_pca_PC08.asc.xlsx (74, 100)
# GZ_3_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_4_train_pca_PC01.asc.xlsx (74, 100)
# GZ_4_train_pca_PC02.asc.xlsx (74, 100)
# GZ_4_train_pca_PC03.asc.xlsx (74, 100)
# GZ_4_train_pca_PC04.asc.xlsx (74, 100)
# GZ_4_train_pca_PC05.asc.xlsx (74, 100)
# GZ_4_train_pca_PC06.asc.xlsx (74, 100)
# GZ_4_train_pca_PC07.asc.xlsx (74, 100)
# GZ_4_train_pca_PC08.asc.xlsx (74, 100)
# GZ_4_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_4_train_pca_PC01.asc.xlsx (74, 100)
# GZ_4_train_pca_PC02.asc.xlsx (74, 100)
# GZ_4_train_pca_PC03.asc.xlsx (74, 100)
# GZ_4_train_pca_PC04.asc.xlsx (74, 100)
# GZ_4_train_pca_PC05.asc.xlsx (74, 100)
# GZ_4_train_pca_PC06.asc.xlsx (74, 100)
# GZ_4_train_pca_PC07.asc.xlsx (74, 100)
# GZ_4_train_pca_PC08.asc.xlsx (74, 100)
# GZ_4_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_4_train_pca_PC01.asc.xlsx (74, 100)
# GZ_4_train_pca_PC02.asc.xlsx (74, 100)
# GZ_4_train_pca_PC03.asc.xlsx (74, 100)
# GZ_4_train_pca_PC04.asc.xlsx (74, 100)
# GZ_4_train_pca_PC05.asc.xlsx (74, 100)
# GZ_4_train_pca_PC06.asc.xlsx (74, 100)
# GZ_4_train_pca_PC07.asc.xlsx (74, 100)
# GZ_4_train_pca_PC08.asc.xlsx (74, 100)
# GZ_4_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_4_train_pca_PC01.asc.xlsx (74, 100)
# GZ_4_train_pca_PC02.asc.xlsx (74, 100)
# GZ_4_train_pca_PC03.asc.xlsx (74, 100)
# GZ_4_train_pca_PC04.asc.xlsx (74, 100)
# GZ_4_train_pca_PC05.asc.xlsx (74, 100)
# GZ_4_train_pca_PC06.asc.xlsx (74, 100)
# GZ_4_train_pca_PC07.asc.xlsx (74, 100)
# GZ_4_train_pca_PC08.asc.xlsx (74, 100)
# GZ_4_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_4_train_pca_PC01.asc.xlsx (74, 100)
# GZ_4_train_pca_PC02.asc.xlsx (74, 100)
# GZ_4_train_pca_PC03.asc.xlsx (74, 100)
# GZ_4_train_pca_PC04.asc.xlsx (74, 100)
# GZ_4_train_pca_PC05.asc.xlsx (74, 100)
# GZ_4_train_pca_PC06.asc.xlsx (74, 100)
# GZ_4_train_pca_PC07.asc.xlsx (74, 100)
# GZ_4_train_pca_PC08.asc.xlsx (74, 100)
# GZ_4_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_4_train_pca_PC01.asc.xlsx (74, 100)
# GZ_4_train_pca_PC02.asc.xlsx (74, 100)
# GZ_4_train_pca_PC03.asc.xlsx (74, 100)
# GZ_4_train_pca_PC04.asc.xlsx (74, 100)
# GZ_4_train_pca_PC05.asc.xlsx (74, 100)
# GZ_4_train_pca_PC06.asc.xlsx (74, 100)
# GZ_4_train_pca_PC07.asc.xlsx (74, 100)
# GZ_4_train_pca_PC08.asc.xlsx (74, 100)
# GZ_4_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_4_train_pca_PC01.asc.xlsx (74, 100)
# GZ_4_train_pca_PC02.asc.xlsx (74, 100)
# GZ_4_train_pca_PC03.asc.xlsx (74, 100)
# GZ_4_train_pca_PC04.asc.xlsx (74, 100)
# GZ_4_train_pca_PC05.asc.xlsx (74, 100)
# GZ_4_train_pca_PC06.asc.xlsx (74, 100)
# GZ_4_train_pca_PC07.asc.xlsx (74, 100)
# GZ_4_train_pca_PC08.asc.xlsx (74, 100)
# GZ_4_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_4_train_pca_PC01.asc.xlsx (74, 100)
# GZ_4_train_pca_PC02.asc.xlsx (74, 100)
# GZ_4_train_pca_PC03.asc.xlsx (74, 100)
# GZ_4_train_pca_PC04.asc.xlsx (74, 100)
# GZ_4_train_pca_PC05.asc.xlsx (74, 100)
# GZ_4_train_pca_PC06.asc.xlsx (74, 100)
# GZ_4_train_pca_PC07.asc.xlsx (74, 100)
# GZ_4_train_pca_PC08.asc.xlsx (74, 100)
# GZ_4_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_4_train_pca_PC01.asc.xlsx (74, 100)
# GZ_4_train_pca_PC02.asc.xlsx (74, 100)
# GZ_4_train_pca_PC03.asc.xlsx (74, 100)
# GZ_4_train_pca_PC04.asc.xlsx (74, 100)
# GZ_4_train_pca_PC05.asc.xlsx (74, 100)
# GZ_4_train_pca_PC06.asc.xlsx (74, 100)
# GZ_4_train_pca_PC07.asc.xlsx (74, 100)
# GZ_4_train_pca_PC08.asc.xlsx (74, 100)
# GZ_4_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_5_train_pca_PC01.asc.xlsx (74, 100)
# GZ_5_train_pca_PC02.asc.xlsx (74, 100)
# GZ_5_train_pca_PC03.asc.xlsx (74, 100)
# GZ_5_train_pca_PC04.asc.xlsx (74, 100)
# GZ_5_train_pca_PC05.asc.xlsx (74, 100)
# GZ_5_train_pca_PC06.asc.xlsx (74, 100)
# GZ_5_train_pca_PC07.asc.xlsx (74, 100)
# GZ_5_train_pca_PC08.asc.xlsx (74, 100)
# GZ_5_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_5_train_pca_PC01.asc.xlsx (74, 100)
# GZ_5_train_pca_PC02.asc.xlsx (74, 100)
# GZ_5_train_pca_PC03.asc.xlsx (74, 100)
# GZ_5_train_pca_PC04.asc.xlsx (74, 100)
# GZ_5_train_pca_PC05.asc.xlsx (74, 100)
# GZ_5_train_pca_PC06.asc.xlsx (74, 100)
# GZ_5_train_pca_PC07.asc.xlsx (74, 100)
# GZ_5_train_pca_PC08.asc.xlsx (74, 100)
# GZ_5_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_5_train_pca_PC01.asc.xlsx (74, 100)
# GZ_5_train_pca_PC02.asc.xlsx (74, 100)
# GZ_5_train_pca_PC03.asc.xlsx (74, 100)
# GZ_5_train_pca_PC04.asc.xlsx (74, 100)
# GZ_5_train_pca_PC05.asc.xlsx (74, 100)
# GZ_5_train_pca_PC06.asc.xlsx (74, 100)
# GZ_5_train_pca_PC07.asc.xlsx (74, 100)
# GZ_5_train_pca_PC08.asc.xlsx (74, 100)
# GZ_5_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_5_train_pca_PC01.asc.xlsx (74, 100)
# GZ_5_train_pca_PC02.asc.xlsx (74, 100)
# GZ_5_train_pca_PC03.asc.xlsx (74, 100)
# GZ_5_train_pca_PC04.asc.xlsx (74, 100)
# GZ_5_train_pca_PC05.asc.xlsx (74, 100)
# GZ_5_train_pca_PC06.asc.xlsx (74, 100)
# GZ_5_train_pca_PC07.asc.xlsx (74, 100)
# GZ_5_train_pca_PC08.asc.xlsx (74, 100)
# GZ_5_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_5_train_pca_PC01.asc.xlsx (74, 100)
# GZ_5_train_pca_PC02.asc.xlsx (74, 100)
# GZ_5_train_pca_PC03.asc.xlsx (74, 100)
# GZ_5_train_pca_PC04.asc.xlsx (74, 100)
# GZ_5_train_pca_PC05.asc.xlsx (74, 100)
# GZ_5_train_pca_PC06.asc.xlsx (74, 100)
# GZ_5_train_pca_PC07.asc.xlsx (74, 100)
# GZ_5_train_pca_PC08.asc.xlsx (74, 100)
# GZ_5_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_5_train_pca_PC01.asc.xlsx (74, 100)
# GZ_5_train_pca_PC02.asc.xlsx (74, 100)
# GZ_5_train_pca_PC03.asc.xlsx (74, 100)
# GZ_5_train_pca_PC04.asc.xlsx (74, 100)
# GZ_5_train_pca_PC05.asc.xlsx (74, 100)
# GZ_5_train_pca_PC06.asc.xlsx (74, 100)
# GZ_5_train_pca_PC07.asc.xlsx (74, 100)
# GZ_5_train_pca_PC08.asc.xlsx (74, 100)
# GZ_5_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_5_train_pca_PC01.asc.xlsx (74, 100)
# GZ_5_train_pca_PC02.asc.xlsx (74, 100)
# GZ_5_train_pca_PC03.asc.xlsx (74, 100)
# GZ_5_train_pca_PC04.asc.xlsx (74, 100)
# GZ_5_train_pca_PC05.asc.xlsx (74, 100)
# GZ_5_train_pca_PC06.asc.xlsx (74, 100)
# GZ_5_train_pca_PC07.asc.xlsx (74, 100)
# GZ_5_train_pca_PC08.asc.xlsx (74, 100)
# GZ_5_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_5_train_pca_PC01.asc.xlsx (74, 100)
# GZ_5_train_pca_PC02.asc.xlsx (74, 100)
# GZ_5_train_pca_PC03.asc.xlsx (74, 100)
# GZ_5_train_pca_PC04.asc.xlsx (74, 100)
# GZ_5_train_pca_PC05.asc.xlsx (74, 100)
# GZ_5_train_pca_PC06.asc.xlsx (74, 100)
# GZ_5_train_pca_PC07.asc.xlsx (74, 100)
# GZ_5_train_pca_PC08.asc.xlsx (74, 100)
# GZ_5_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# MHZ GZ
# GZ_5_train_pca_PC01.asc.xlsx (74, 100)
# GZ_5_train_pca_PC02.asc.xlsx (74, 100)
# GZ_5_train_pca_PC03.asc.xlsx (74, 100)
# GZ_5_train_pca_PC04.asc.xlsx (74, 100)
# GZ_5_train_pca_PC05.asc.xlsx (74, 100)
# GZ_5_train_pca_PC06.asc.xlsx (74, 100)
# GZ_5_train_pca_PC07.asc.xlsx (74, 100)
# GZ_5_train_pca_PC08.asc.xlsx (74, 100)
# GZ_5_train_pca_PC09.asc.xlsx (74, 100)
# Number of grid points per file : 7400.0
# Number of grid points in total: 66600
# gridpoints: 7400
# Wall time: 6min 32s

# %%
# %%time
# Post-processing per geological layer per quarry

# Post_processing cross-validation: CHANGE PARAMETERS IN FUNCTION FOR DIFFERENT QUARRIES/LAYERS!
for j in range(1, 6):
    for comp in range(1, 10):
        ppp.pca_post_processing(f"../_KRIGING/CROSS_VALIDATION_PREPROCESSED_CLR/data_MHZ/TZ/train_{str(j)}/", 
                        cross_validation_pre_processing_MHZ["TZ"][f"train_{str(j)}"][0], 
                        cross_validation_pre_processing_MHZ["TZ"][f"train_{str(j)}"][1],
                        grid_data=dict_grid_info["MHZ_IZ_TZ"],
                        n_components=comp,
                        save_data=False);
    
# TO DO: create folder structure to save files in and change code in post-processing script

# %% [markdown]
# ### Cross validation

# %%
# %%time
# In-house approach - lookup values + cross validation
results_quarry = {}

for quarry in ["Berg", "MHZ"]:
    print(quarry)
    results_geol = {}
    
    for code_geol in ["GZ", "IZ", "TZ"]:
        print("\t", code_geol)
        results_n_comp = {}

        for i in range(1,10):
            print(f"\t\t{i}comp")
            results_n_comp[f"{i}comp"] =\
                cv.cross_validation(f"../_RESULTS/CROSS_VALIDATION_POSTPROCESSED_CLR/"+\
                                    f"{quarry}/{code_geol}/{str(i)}comp")
            
        results_geol[code_geol] = results_n_comp
        
    results_quarry[quarry] = results_geol
# Out:
# Berg
# 	 GZ
# 		1comp
# GZ
# GZ
# Berg_GZ_z_0_kriged_reverse_1comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_1000_kriged_reverse_1comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_125_kriged_reverse_1comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_180_kriged_reverse_1comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_250_kriged_reverse_1comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_355_kriged_reverse_1comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_500_kriged_reverse_1comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_63_kriged_reverse_1comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_710_kriged_reverse_1comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_90_kriged_reverse_1comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# GZ
# Berg_GZ_z_0_kriged_reverse_1comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_1000_kriged_reverse_1comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_125_kriged_reverse_1comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_180_kriged_reverse_1comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_250_kriged_reverse_1comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_355_kriged_reverse_1comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_500_kriged_reverse_1comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_63_kriged_reverse_1comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_710_kriged_reverse_1comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_90_kriged_reverse_1comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# GZ
# Berg_GZ_z_0_kriged_reverse_1comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_1000_kriged_reverse_1comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_125_kriged_reverse_1comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_180_kriged_reverse_1comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_250_kriged_reverse_1comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_355_kriged_reverse_1comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_500_kriged_reverse_1comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_63_kriged_reverse_1comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_710_kriged_reverse_1comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_90_kriged_reverse_1comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# GZ
# Berg_GZ_z_0_kriged_reverse_1comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_1000_kriged_reverse_1comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_125_kriged_reverse_1comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_180_kriged_reverse_1comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_250_kriged_reverse_1comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_355_kriged_reverse_1comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_500_kriged_reverse_1comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_63_kriged_reverse_1comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_710_kriged_reverse_1comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_90_kriged_reverse_1comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# GZ
# Berg_GZ_z_0_kriged_reverse_1comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_1000_kriged_reverse_1comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_125_kriged_reverse_1comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_180_kriged_reverse_1comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_250_kriged_reverse_1comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_355_kriged_reverse_1comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_500_kriged_reverse_1comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_63_kriged_reverse_1comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_710_kriged_reverse_1comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_90_kriged_reverse_1comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Number of files processed: 50
# 		2comp
# GZ
# GZ
# Berg_GZ_z_0_kriged_reverse_2comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_1000_kriged_reverse_2comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_125_kriged_reverse_2comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_180_kriged_reverse_2comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_250_kriged_reverse_2comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_355_kriged_reverse_2comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_500_kriged_reverse_2comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_63_kriged_reverse_2comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_710_kriged_reverse_2comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_90_kriged_reverse_2comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# GZ
# Berg_GZ_z_0_kriged_reverse_2comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_1000_kriged_reverse_2comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_125_kriged_reverse_2comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_180_kriged_reverse_2comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_250_kriged_reverse_2comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_355_kriged_reverse_2comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_500_kriged_reverse_2comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_63_kriged_reverse_2comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_710_kriged_reverse_2comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_90_kriged_reverse_2comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# GZ
# Berg_GZ_z_0_kriged_reverse_2comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_1000_kriged_reverse_2comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_125_kriged_reverse_2comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_180_kriged_reverse_2comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_250_kriged_reverse_2comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_355_kriged_reverse_2comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_500_kriged_reverse_2comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_63_kriged_reverse_2comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_710_kriged_reverse_2comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_90_kriged_reverse_2comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# GZ
# Berg_GZ_z_0_kriged_reverse_2comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_1000_kriged_reverse_2comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_125_kriged_reverse_2comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_180_kriged_reverse_2comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_250_kriged_reverse_2comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_355_kriged_reverse_2comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_500_kriged_reverse_2comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_63_kriged_reverse_2comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_710_kriged_reverse_2comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_90_kriged_reverse_2comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# GZ
# Berg_GZ_z_0_kriged_reverse_2comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_1000_kriged_reverse_2comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_125_kriged_reverse_2comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_180_kriged_reverse_2comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_250_kriged_reverse_2comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_355_kriged_reverse_2comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_500_kriged_reverse_2comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_63_kriged_reverse_2comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_710_kriged_reverse_2comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_90_kriged_reverse_2comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Number of files processed: 50
# 		3comp
# GZ
# GZ
# Berg_GZ_z_0_kriged_reverse_3comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_1000_kriged_reverse_3comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_125_kriged_reverse_3comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_180_kriged_reverse_3comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_250_kriged_reverse_3comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_355_kriged_reverse_3comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_500_kriged_reverse_3comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_63_kriged_reverse_3comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_710_kriged_reverse_3comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_90_kriged_reverse_3comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# GZ
# Berg_GZ_z_0_kriged_reverse_3comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_1000_kriged_reverse_3comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_125_kriged_reverse_3comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_180_kriged_reverse_3comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_250_kriged_reverse_3comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_355_kriged_reverse_3comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_500_kriged_reverse_3comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_63_kriged_reverse_3comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_710_kriged_reverse_3comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_90_kriged_reverse_3comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# GZ
# Berg_GZ_z_0_kriged_reverse_3comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_1000_kriged_reverse_3comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_125_kriged_reverse_3comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_180_kriged_reverse_3comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_250_kriged_reverse_3comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_355_kriged_reverse_3comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_500_kriged_reverse_3comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_63_kriged_reverse_3comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_710_kriged_reverse_3comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_90_kriged_reverse_3comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# GZ
# Berg_GZ_z_0_kriged_reverse_3comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_1000_kriged_reverse_3comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_125_kriged_reverse_3comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_180_kriged_reverse_3comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_250_kriged_reverse_3comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_355_kriged_reverse_3comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_500_kriged_reverse_3comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_63_kriged_reverse_3comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_710_kriged_reverse_3comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_90_kriged_reverse_3comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# GZ
# Berg_GZ_z_0_kriged_reverse_3comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_1000_kriged_reverse_3comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_125_kriged_reverse_3comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_180_kriged_reverse_3comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_250_kriged_reverse_3comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_355_kriged_reverse_3comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_500_kriged_reverse_3comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_63_kriged_reverse_3comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_710_kriged_reverse_3comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_90_kriged_reverse_3comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Number of files processed: 50
# 		4comp
# GZ
# GZ
# Berg_GZ_z_0_kriged_reverse_4comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_1000_kriged_reverse_4comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_125_kriged_reverse_4comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_180_kriged_reverse_4comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_250_kriged_reverse_4comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_355_kriged_reverse_4comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_500_kriged_reverse_4comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_63_kriged_reverse_4comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_710_kriged_reverse_4comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_90_kriged_reverse_4comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# GZ
# Berg_GZ_z_0_kriged_reverse_4comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_1000_kriged_reverse_4comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_125_kriged_reverse_4comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_180_kriged_reverse_4comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_250_kriged_reverse_4comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_355_kriged_reverse_4comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_500_kriged_reverse_4comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_63_kriged_reverse_4comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_710_kriged_reverse_4comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_90_kriged_reverse_4comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# GZ
# Berg_GZ_z_0_kriged_reverse_4comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_1000_kriged_reverse_4comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_125_kriged_reverse_4comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_180_kriged_reverse_4comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_250_kriged_reverse_4comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_355_kriged_reverse_4comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_500_kriged_reverse_4comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_63_kriged_reverse_4comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_710_kriged_reverse_4comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_90_kriged_reverse_4comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# GZ
# Berg_GZ_z_0_kriged_reverse_4comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_1000_kriged_reverse_4comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_125_kriged_reverse_4comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_180_kriged_reverse_4comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_250_kriged_reverse_4comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_355_kriged_reverse_4comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_500_kriged_reverse_4comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_63_kriged_reverse_4comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_710_kriged_reverse_4comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_90_kriged_reverse_4comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# GZ
# Berg_GZ_z_0_kriged_reverse_4comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_1000_kriged_reverse_4comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_125_kriged_reverse_4comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_180_kriged_reverse_4comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_250_kriged_reverse_4comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_355_kriged_reverse_4comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_500_kriged_reverse_4comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_63_kriged_reverse_4comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_710_kriged_reverse_4comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_90_kriged_reverse_4comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Number of files processed: 50
# 		5comp
# GZ
# GZ
# Berg_GZ_z_0_kriged_reverse_5comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_1000_kriged_reverse_5comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_125_kriged_reverse_5comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_180_kriged_reverse_5comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_250_kriged_reverse_5comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_355_kriged_reverse_5comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_500_kriged_reverse_5comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_63_kriged_reverse_5comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_710_kriged_reverse_5comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_90_kriged_reverse_5comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# GZ
# Berg_GZ_z_0_kriged_reverse_5comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_1000_kriged_reverse_5comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_125_kriged_reverse_5comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_180_kriged_reverse_5comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_250_kriged_reverse_5comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_355_kriged_reverse_5comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_500_kriged_reverse_5comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_63_kriged_reverse_5comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_710_kriged_reverse_5comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_90_kriged_reverse_5comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# GZ
# Berg_GZ_z_0_kriged_reverse_5comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_1000_kriged_reverse_5comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_125_kriged_reverse_5comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_180_kriged_reverse_5comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_250_kriged_reverse_5comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_355_kriged_reverse_5comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_500_kriged_reverse_5comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_63_kriged_reverse_5comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_710_kriged_reverse_5comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_90_kriged_reverse_5comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# GZ
# Berg_GZ_z_0_kriged_reverse_5comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_1000_kriged_reverse_5comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_125_kriged_reverse_5comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_180_kriged_reverse_5comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_250_kriged_reverse_5comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_355_kriged_reverse_5comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_500_kriged_reverse_5comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_63_kriged_reverse_5comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_710_kriged_reverse_5comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_90_kriged_reverse_5comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# GZ
# Berg_GZ_z_0_kriged_reverse_5comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_1000_kriged_reverse_5comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_125_kriged_reverse_5comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_180_kriged_reverse_5comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_250_kriged_reverse_5comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_355_kriged_reverse_5comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_500_kriged_reverse_5comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_63_kriged_reverse_5comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_710_kriged_reverse_5comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_90_kriged_reverse_5comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Number of files processed: 50
# 		6comp
# GZ
# GZ
# Berg_GZ_z_0_kriged_reverse_6comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_1000_kriged_reverse_6comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_125_kriged_reverse_6comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_180_kriged_reverse_6comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_250_kriged_reverse_6comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_355_kriged_reverse_6comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_500_kriged_reverse_6comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_63_kriged_reverse_6comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_710_kriged_reverse_6comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_90_kriged_reverse_6comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# GZ
# Berg_GZ_z_0_kriged_reverse_6comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_1000_kriged_reverse_6comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_125_kriged_reverse_6comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_180_kriged_reverse_6comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_250_kriged_reverse_6comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_355_kriged_reverse_6comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_500_kriged_reverse_6comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_63_kriged_reverse_6comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_710_kriged_reverse_6comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_90_kriged_reverse_6comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# GZ
# Berg_GZ_z_0_kriged_reverse_6comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_1000_kriged_reverse_6comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_125_kriged_reverse_6comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_180_kriged_reverse_6comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_250_kriged_reverse_6comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_355_kriged_reverse_6comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_500_kriged_reverse_6comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_63_kriged_reverse_6comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_710_kriged_reverse_6comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_90_kriged_reverse_6comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# GZ
# Berg_GZ_z_0_kriged_reverse_6comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_1000_kriged_reverse_6comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_125_kriged_reverse_6comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_180_kriged_reverse_6comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_250_kriged_reverse_6comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_355_kriged_reverse_6comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_500_kriged_reverse_6comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_63_kriged_reverse_6comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_710_kriged_reverse_6comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_90_kriged_reverse_6comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# GZ
# Berg_GZ_z_0_kriged_reverse_6comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_1000_kriged_reverse_6comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_125_kriged_reverse_6comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_180_kriged_reverse_6comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_250_kriged_reverse_6comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_355_kriged_reverse_6comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_500_kriged_reverse_6comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_63_kriged_reverse_6comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_710_kriged_reverse_6comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_90_kriged_reverse_6comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Number of files processed: 50
# 		7comp
# GZ
# GZ
# Berg_GZ_z_0_kriged_reverse_7comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_1000_kriged_reverse_7comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_125_kriged_reverse_7comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_180_kriged_reverse_7comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_250_kriged_reverse_7comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_355_kriged_reverse_7comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_500_kriged_reverse_7comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_63_kriged_reverse_7comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_710_kriged_reverse_7comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_90_kriged_reverse_7comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# GZ
# Berg_GZ_z_0_kriged_reverse_7comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_1000_kriged_reverse_7comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_125_kriged_reverse_7comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_180_kriged_reverse_7comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_250_kriged_reverse_7comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_355_kriged_reverse_7comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_500_kriged_reverse_7comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# ...
# 		8comp
# TZ
# TZ
# MHZ_TZ_z_0_kriged_reverse_8comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_1000_kriged_reverse_8comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_125_kriged_reverse_8comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_180_kriged_reverse_8comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_250_kriged_reverse_8comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_355_kriged_reverse_8comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_500_kriged_reverse_8comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_63_kriged_reverse_8comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_710_kriged_reverse_8comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_90_kriged_reverse_8comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# TZ
# MHZ_TZ_z_0_kriged_reverse_8comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_1000_kriged_reverse_8comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_125_kriged_reverse_8comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_180_kriged_reverse_8comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_250_kriged_reverse_8comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_355_kriged_reverse_8comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_500_kriged_reverse_8comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_63_kriged_reverse_8comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_710_kriged_reverse_8comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_90_kriged_reverse_8comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# TZ
# MHZ_TZ_z_0_kriged_reverse_8comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_1000_kriged_reverse_8comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_125_kriged_reverse_8comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_180_kriged_reverse_8comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_250_kriged_reverse_8comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_355_kriged_reverse_8comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_500_kriged_reverse_8comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_63_kriged_reverse_8comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_710_kriged_reverse_8comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_90_kriged_reverse_8comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# TZ
# MHZ_TZ_z_0_kriged_reverse_8comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_1000_kriged_reverse_8comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_125_kriged_reverse_8comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_180_kriged_reverse_8comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_250_kriged_reverse_8comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_355_kriged_reverse_8comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_500_kriged_reverse_8comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_63_kriged_reverse_8comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_710_kriged_reverse_8comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_90_kriged_reverse_8comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# TZ
# MHZ_TZ_z_0_kriged_reverse_8comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_1000_kriged_reverse_8comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_125_kriged_reverse_8comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_180_kriged_reverse_8comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_250_kriged_reverse_8comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_355_kriged_reverse_8comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_500_kriged_reverse_8comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_63_kriged_reverse_8comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_710_kriged_reverse_8comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_90_kriged_reverse_8comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# Number of files processed: 50
# 		9comp
# TZ
# TZ
# MHZ_TZ_z_0_kriged_reverse_9comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_1000_kriged_reverse_9comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_125_kriged_reverse_9comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_180_kriged_reverse_9comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_250_kriged_reverse_9comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_355_kriged_reverse_9comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_500_kriged_reverse_9comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_63_kriged_reverse_9comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_710_kriged_reverse_9comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_90_kriged_reverse_9comp_spherical_1.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# TZ
# MHZ_TZ_z_0_kriged_reverse_9comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_1000_kriged_reverse_9comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_125_kriged_reverse_9comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_180_kriged_reverse_9comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_250_kriged_reverse_9comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_355_kriged_reverse_9comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_500_kriged_reverse_9comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_63_kriged_reverse_9comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_710_kriged_reverse_9comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_90_kriged_reverse_9comp_spherical_2.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# TZ
# MHZ_TZ_z_0_kriged_reverse_9comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_1000_kriged_reverse_9comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_125_kriged_reverse_9comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_180_kriged_reverse_9comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_250_kriged_reverse_9comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_355_kriged_reverse_9comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_500_kriged_reverse_9comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_63_kriged_reverse_9comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_710_kriged_reverse_9comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_90_kriged_reverse_9comp_spherical_3.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# TZ
# MHZ_TZ_z_0_kriged_reverse_9comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_1000_kriged_reverse_9comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_125_kriged_reverse_9comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_180_kriged_reverse_9comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_250_kriged_reverse_9comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_355_kriged_reverse_9comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_500_kriged_reverse_9comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_63_kriged_reverse_9comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_710_kriged_reverse_9comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_90_kriged_reverse_9comp_spherical_4.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# TZ
# MHZ_TZ_z_0_kriged_reverse_9comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_1000_kriged_reverse_9comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_125_kriged_reverse_9comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_180_kriged_reverse_9comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_250_kriged_reverse_9comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_355_kriged_reverse_9comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_500_kriged_reverse_9comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_63_kriged_reverse_9comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_710_kriged_reverse_9comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_90_kriged_reverse_9comp_spherical_5.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# Number of files processed: 50
# Wall time: 3min 11s

# %% [markdown]
# ### MSE (Mean Squared Error) calculation

# %% [markdown]
# - Create dataframe with requested looked up values of test samples
# - Validate these values with the observed values from the database by calculating the Mean Squared Error (MSE); this is done for all 5 folds
# - Average the MSE from these 5 folds and keep this value as a cross validation measure for the method in question

# %%
# Calculate MSE results for in-house approach
mse_results_new = cv.calculate_mse_new(results_quarry)

# %%
# Average the in-house approach MSE results over the cross validation folds
averaged_mse_quarry = {}

for quarry in ["Berg", "MHZ"]:
    averaged_mse_geol = {}
    
    for geol in ["GZ", "IZ", "TZ"]:
        averaged_mse_n_comp = {}
        
        for n_comp in ["5comp", "9comp"]:
            averaged_mse_n_comp[n_comp] = cv.average_mse_results_CVfolds_new(mse_results_new, 
                                                                             quarry, 
                                                                             geol, 
                                                                             n_comp)
            
        averaged_mse_geol[geol] = averaged_mse_n_comp
        
    averaged_mse_quarry[quarry] = averaged_mse_geol

# %%
# Average the in-house CV fold averaged MSE results over the principal components
averaged_mse_quarry_n_comp = {}

for quarry, geol_data in averaged_mse_quarry.items():
    for geol, n_comp_data in geol_data.items():
        for n_comp, data in n_comp_data.items():
            averaged_mse_quarry_n_comp[quarry, geol, n_comp] = cv.average_mse_results_n_comp(data)

# %%
# Save the finally averaged MSE results
MSE_results_new = averaged_mse_quarry_n_comp
MSE_results_new = pd.DataFrame.from_dict(MSE_results_new, orient='index')
index_multi = pd.MultiIndex.from_tuples(MSE_results_new.index)
MSE_results_new = MSE_results_new.reindex(index_multi)
MSE_results_new.columns = ["MSE new"]
MSE_results_new = MSE_results_new.unstack()
# Uncomment following line to save dataframe
#MSE_results_new.to_excel("../_RESULTS/MSE_new_clr.xlsx")
MSE_results_new
# Out:
#           MSE new
#             5comp     9comp
# Berg GZ  7.230002  7.277285
#      IZ  5.231253  5.205556
#      TZ  6.876185  6.878397
# MHZ  GZ  7.005152  7.002740
#      IZ  9.918919  9.911656
#      TZ  2.030974  2.029802

# %%
# Average MSE results of inhouse approach per grain size class
gsd_info_quarry = {}

for quarry, geol_data in mse_results_new.items():
    gsd_info_geol = {}
    
    for geol, comp_data in geol_data.items():
        gsd_info_comp = {}
        
        for comp, train_data in comp_data.items():
            gsd_info = {}
            if comp in ["5comp", "9comp"]:
            
                for train, grain_size_data in train_data.items():

                    for grain_size, data in grain_size_data.items():
                        if grain_size not in gsd_info:
                            gsd_info[grain_size] = [data]
                        else:
                            gsd_info[grain_size].append(data)

                gsd_info_comp[comp] = gsd_info
            
        gsd_info_geol[geol] = gsd_info_comp
        
    gsd_info_quarry[quarry] = gsd_info_geol

# %%
gsd_info_quarry_mean = {}

for quarry, geol_data in gsd_info_quarry.items():
    for geol, comp_data in geol_data.items():
        for comp, train_data in comp_data.items():
            for grain_size, data in train_data.items():
                gsd_info_quarry_mean[quarry, geol, comp, grain_size] = np.mean(data)

# %%
MSE_results_new_gsd = pd.DataFrame.from_dict(gsd_info_quarry_mean, orient='index')
index_multi2 = pd.MultiIndex.from_tuples(MSE_results_new_gsd.index)
MSE_results_new_gsd = MSE_results_new_gsd.reindex(index_multi2)
MSE_results_new_gsd.columns = ["MSE new"]
MSE_results_new_gsd = MSE_results_new_gsd.unstack(-2)
# Uncomment following line to save dataframe
#MSE_results_new_gsd.to_excel("../_RESULTS/MSE_new_gsd_clr.xlsx")
MSE_results_new_gsd
# Out:
#                   MSE new
#                     5comp      9comp
# Berg GZ z_0     13.218192  13.250099
#         z_1000  11.618273  11.672076
#         z_125    3.506285   3.503372
#         z_180    3.723830   3.643164
#         z_250    3.280172   3.391783
#         z_355    2.663398   2.900195
#         z_500    8.442973   8.458016
#         z_63    13.487910  13.473829
#         z_710   10.043936  10.154676
#         z_90     2.315050   2.325638
#      IZ z_0      6.384298   6.362809
#         z_1000  17.418370  17.386845
#         z_125    2.045380   2.029499
#         z_180    2.933854   2.710805
#         z_250    2.815550   2.776408
#         z_355    2.247052   2.248898
#         z_500    2.397687   2.366119
#         z_63     7.438025   7.481974
#         z_710    7.103188   7.100892
#         z_90     1.529121   1.591310
#      TZ z_0     17.679437  17.792653
#         z_1000  13.467704  13.489556
#         z_125    4.112940   4.347985
#         z_180    3.718588   3.630119
#         z_250    2.616512   2.473535
#         z_355    5.445320   5.424556
#         z_500    7.046219   6.834716
#         z_63     4.979081   4.933057
#         z_710    6.483969   6.469413
#         z_90     3.212076   3.388375
# MHZ  GZ z_0     15.279899  15.326899
#         z_1000  21.114730  21.109297
#         z_125    1.720751   1.669274
#         z_180    1.931440   1.892601
#         z_250    1.980757   2.052522
#         z_355    1.659660   1.762635
#         z_500    1.486463   1.481389
#         z_63     7.861383   7.779341
#         z_710   15.295694  15.301468
#         z_90     1.720743   1.651978
#      IZ z_0     34.204546  34.192760
#         z_1000  23.808537  23.802076
#         z_125    2.208659   2.125233
#         z_180    2.259813   2.272531
#         z_250    2.260773   2.343469
#         z_355    2.201549   2.226088
#         z_500    2.136098   2.010906
#         z_63     4.840328   4.811064
#         z_710   22.609690  22.617319
#         z_90     2.659197   2.715114
#      TZ z_0      3.780806   3.781728
#         z_1000   6.484182   6.489949
#         z_125    0.484257   0.479806
#         z_180    0.891048   0.884553
#         z_250    0.696492   0.688735
#         z_355    0.422479   0.424873
#         z_500    0.388298   0.391895
#         z_63     1.751651   1.764018
#         z_710    4.538024   4.528788
#         z_90     0.872503   0.863674

# %% [markdown]
# ___

# %% [markdown]
# ## Classical approach

# %% [markdown]
# ### Cross validation

# %%
# %%time
# Classical approach - cross validation
results_quarry_classic = {}

for quarry in ["Berg", "MHZ"]:
    print(quarry)
    results_geol_classic = {}
    
    for code_geol in ["GZ", "IZ", "TZ"]:
        print("\t", code_geol)

        results_geol_classic[code_geol] =\
        cv.cross_validation(f"../_KRIGING/CROSS_VALIDATION_CLASSIC_CLR/"+\
                            f"{quarry}/{code_geol}")
        
    results_quarry_classic[quarry] = results_geol_classic
# Out:
# Berg
# 	 GZ
# GZ
# GZ
# Berg_GZ_1_train_z_0.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_1_train_z_1000.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_1_train_z_125.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_1_train_z_180.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_1_train_z_250.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_1_train_z_355.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_1_train_z_500.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_1_train_z_63.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_1_train_z_710.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_1_train_z_90.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# GZ
# Berg_GZ_2_train_z_0.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_2_train_z_1000.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_2_train_z_125.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_2_train_z_180.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_2_train_z_250.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_2_train_z_355.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_2_train_z_500.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_2_train_z_63.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_2_train_z_710.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_2_train_z_90.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# GZ
# Berg_GZ_3_train_z_0.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_3_train_z_1000.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_3_train_z_125.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_3_train_z_180.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_3_train_z_250.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_3_train_z_355.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_3_train_z_500.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_3_train_z_63.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_3_train_z_710.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_3_train_z_90.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# GZ
# Berg_GZ_4_train_z_0.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_4_train_z_1000.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_4_train_z_125.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_4_train_z_180.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_4_train_z_250.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_4_train_z_355.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_4_train_z_500.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_4_train_z_63.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_4_train_z_710.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_4_train_z_90.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# GZ
# Berg_GZ_5_train_z_0.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_5_train_z_1000.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_5_train_z_125.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_5_train_z_180.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_5_train_z_250.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_5_train_z_355.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_5_train_z_500.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_5_train_z_63.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_5_train_z_710.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_5_train_z_90.asc ../_CROSS_VALIDATION_CLR/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Number of files processed: 50
# 	 IZ
# IZ
# IZ
# Berg_IZ_1_train_z_0.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_1_test.csv
# 57 53
# 81 42
# 51 57
# 90 49
# 58 9
# 45 27
# 59 99
# 12 28
# Berg_IZ_1_train_z_1000.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_1_test.csv
# 57 53
# 81 42
# 51 57
# 90 49
# 58 9
# 45 27
# 59 99
# 12 28
# Berg_IZ_1_train_z_125.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_1_test.csv
# 57 53
# 81 42
# 51 57
# 90 49
# 58 9
# 45 27
# 59 99
# 12 28
# Berg_IZ_1_train_z_180.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_1_test.csv
# 57 53
# 81 42
# 51 57
# 90 49
# 58 9
# 45 27
# 59 99
# 12 28
# Berg_IZ_1_train_z_250.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_1_test.csv
# 57 53
# 81 42
# 51 57
# 90 49
# 58 9
# 45 27
# 59 99
# 12 28
# Berg_IZ_1_train_z_355.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_1_test.csv
# 57 53
# 81 42
# 51 57
# 90 49
# 58 9
# 45 27
# 59 99
# 12 28
# Berg_IZ_1_train_z_500.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_1_test.csv
# 57 53
# 81 42
# 51 57
# 90 49
# 58 9
# 45 27
# 59 99
# 12 28
# Berg_IZ_1_train_z_63.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_1_test.csv
# 57 53
# 81 42
# 51 57
# 90 49
# 58 9
# 45 27
# 59 99
# 12 28
# Berg_IZ_1_train_z_710.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_1_test.csv
# 57 53
# 81 42
# 51 57
# 90 49
# 58 9
# 45 27
# 59 99
# 12 28
# Berg_IZ_1_train_z_90.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_1_test.csv
# 57 53
# 81 42
# 51 57
# 90 49
# 58 9
# 45 27
# 59 99
# 12 28
# IZ
# Berg_IZ_2_train_z_0.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_2_test.csv
# 36 32
# 45 41
# 64 46
# 69 65
# 57 53
# 64 15
# 62 91
# 14 11
# Berg_IZ_2_train_z_1000.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_2_test.csv
# 36 32
# 45 41
# 64 46
# 69 65
# 57 53
# 64 15
# 62 91
# 14 11
# Berg_IZ_2_train_z_125.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_2_test.csv
# 36 32
# 45 41
# 64 46
# 69 65
# 57 53
# 64 15
# 62 91
# 14 11
# Berg_IZ_2_train_z_180.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_2_test.csv
# 36 32
# 45 41
# 64 46
# 69 65
# 57 53
# 64 15
# 62 91
# 14 11
# Berg_IZ_2_train_z_250.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_2_test.csv
# 36 32
# 45 41
# 64 46
# 69 65
# 57 53
# 64 15
# 62 91
# 14 11
# Berg_IZ_2_train_z_355.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_2_test.csv
# 36 32
# 45 41
# 64 46
# 69 65
# 57 53
# 64 15
# 62 91
# 14 11
# Berg_IZ_2_train_z_500.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_2_test.csv
# 36 32
# 45 41
# 64 46
# 69 65
# 57 53
# 64 15
# 62 91
# 14 11
# Berg_IZ_2_train_z_63.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_2_test.csv
# 36 32
# 45 41
# 64 46
# 69 65
# 57 53
# 64 15
# 62 91
# 14 11
# Berg_IZ_2_train_z_710.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_2_test.csv
# 36 32
# 45 41
# 64 46
# 69 65
# 57 53
# 64 15
# 62 91
# 14 11
# Berg_IZ_2_train_z_90.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_2_test.csv
# 36 32
# 45 41
# 64 46
# 69 65
# 57 53
# 64 15
# 62 91
# 14 11
# IZ
# Berg_IZ_3_train_z_0.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_3_test.csv
# 60 40
# 62 91
# 64 15
# 46 54
# 81 42
# 74 42
# 73 36
# 28 14
# Berg_IZ_3_train_z_1000.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_3_test.csv
# 60 40
# 62 91
# 64 15
# 46 54
# 81 42
# 74 42
# 73 36
# 28 14
# Berg_IZ_3_train_z_125.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_3_test.csv
# 60 40
# 62 91
# 64 15
# 46 54
# 81 42
# 74 42
# 73 36
# 28 14
# Berg_IZ_3_train_z_180.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_3_test.csv
# 60 40
# 62 91
# 64 15
# 46 54
# 81 42
# 74 42
# 73 36
# 28 14
# Berg_IZ_3_train_z_250.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_3_test.csv
# 60 40
# 62 91
# 64 15
# 46 54
# 81 42
# 74 42
# 73 36
# 28 14
# Berg_IZ_3_train_z_355.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_3_test.csv
# 60 40
# 62 91
# 64 15
# 46 54
# 81 42
# 74 42
# 73 36
# 28 14
# Berg_IZ_3_train_z_500.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_3_test.csv
# 60 40
# 62 91
# 64 15
# 46 54
# 81 42
# 74 42
# 73 36
# 28 14
# Berg_IZ_3_train_z_63.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_3_test.csv
# 60 40
# 62 91
# 64 15
# 46 54
# 81 42
# 74 42
# 73 36
# 28 14
# Berg_IZ_3_train_z_710.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_3_test.csv
# 60 40
# 62 91
# 64 15
# 46 54
# 81 42
# 74 42
# 73 36
# 28 14
# Berg_IZ_3_train_z_90.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_3_test.csv
# 60 40
# 62 91
# 64 15
# 46 54
# 81 42
# 74 42
# 73 36
# 28 14
# IZ
# Berg_IZ_4_train_z_0.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_4_test.csv
# 46 54
# 84 44
# 36 60
# 28 14
# 46 8
# 33 67
# 52 23
# 47 74
# Berg_IZ_4_train_z_1000.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_4_test.csv
# 46 54
# 84 44
# 36 60
# 28 14
# 46 8
# 33 67
# 52 23
# 47 74
# Berg_IZ_4_train_z_125.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_4_test.csv
# 46 54
# 84 44
# 36 60
# 28 14
# 46 8
# 33 67
# 52 23
# 47 74
# Berg_IZ_4_train_z_180.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_4_test.csv
# 46 54
# 84 44
# 36 60
# 28 14
# 46 8
# 33 67
# 52 23
# 47 74
# Berg_IZ_4_train_z_250.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_4_test.csv
# 46 54
# 84 44
# 36 60
# 28 14
# 46 8
# 33 67
# 52 23
# 47 74
# Berg_IZ_4_train_z_355.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_4_test.csv
# 46 54
# 84 44
# 36 60
# 28 14
# 46 8
# 33 67
# 52 23
# 47 74
# Berg_IZ_4_train_z_500.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_4_test.csv
# 46 54
# 84 44
# 36 60
# 28 14
# 46 8
# 33 67
# 52 23
# 47 74
# Berg_IZ_4_train_z_63.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_4_test.csv
# 46 54
# 84 44
# 36 60
# 28 14
# 46 8
# 33 67
# 52 23
# 47 74
# Berg_IZ_4_train_z_710.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_4_test.csv
# 46 54
# 84 44
# 36 60
# 28 14
# 46 8
# 33 67
# 52 23
# 47 74
# Berg_IZ_4_train_z_90.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_4_test.csv
# 46 54
# 84 44
# 36 60
# 28 14
# 46 8
# 33 67
# 52 23
# 47 74
# IZ
# Berg_IZ_5_train_z_0.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_5_test.csv
# 10 44
# 58 9
# 49 81
# 51 57
# 59 99
# 44 61
# 46 54
# 1 27
# Berg_IZ_5_train_z_1000.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_5_test.csv
# 10 44
# 58 9
# 49 81
# 51 57
# 59 99
# 44 61
# 46 54
# 1 27
# Berg_IZ_5_train_z_125.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_5_test.csv
# 10 44
# 58 9
# 49 81
# 51 57
# 59 99
# 44 61
# 46 54
# 1 27
# Berg_IZ_5_train_z_180.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_5_test.csv
# 10 44
# 58 9
# 49 81
# 51 57
# 59 99
# 44 61
# 46 54
# 1 27
# Berg_IZ_5_train_z_250.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_5_test.csv
# 10 44
# 58 9
# 49 81
# 51 57
# 59 99
# 44 61
# 46 54
# 1 27
# Berg_IZ_5_train_z_355.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_5_test.csv
# 10 44
# 58 9
# 49 81
# 51 57
# 59 99
# 44 61
# 46 54
# 1 27
# Berg_IZ_5_train_z_500.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_5_test.csv
# 10 44
# 58 9
# 49 81
# 51 57
# 59 99
# 44 61
# 46 54
# 1 27
# Berg_IZ_5_train_z_63.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_5_test.csv
# 10 44
# 58 9
# 49 81
# 51 57
# 59 99
# 44 61
# 46 54
# 1 27
# Berg_IZ_5_train_z_710.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_5_test.csv
# 10 44
# 58 9
# 49 81
# 51 57
# 59 99
# 44 61
# 46 54
# 1 27
# Berg_IZ_5_train_z_90.asc ../_CROSS_VALIDATION_CLR/Berg/IZ/Berg_IZ_5_test.csv
# 10 44
# 58 9
# 49 81
# 51 57
# 59 99
# 44 61
# 46 54
# 1 27
# Number of files processed: 50
# 	 TZ
# TZ
# TZ
# Berg_TZ_1_train_z_0.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_1_test.csv
# 57 53
# 81 42
# 51 57
# 90 49
# 58 9
# 45 27
# 59 99
# 12 28
# Berg_TZ_1_train_z_1000.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_1_test.csv
# 57 53
# 81 42
# 51 57
# 90 49
# 58 9
# 45 27
# 59 99
# 12 28
# Berg_TZ_1_train_z_125.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_1_test.csv
# 57 53
# 81 42
# 51 57
# 90 49
# 58 9
# 45 27
# 59 99
# 12 28
# Berg_TZ_1_train_z_180.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_1_test.csv
# 57 53
# 81 42
# 51 57
# 90 49
# 58 9
# 45 27
# 59 99
# 12 28
# Berg_TZ_1_train_z_250.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_1_test.csv
# 57 53
# 81 42
# 51 57
# 90 49
# 58 9
# 45 27
# 59 99
# 12 28
# Berg_TZ_1_train_z_355.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_1_test.csv
# 57 53
# 81 42
# 51 57
# 90 49
# 58 9
# 45 27
# 59 99
# 12 28
# Berg_TZ_1_train_z_500.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_1_test.csv
# 57 53
# 81 42
# 51 57
# 90 49
# 58 9
# 45 27
# 59 99
# 12 28
# Berg_TZ_1_train_z_63.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_1_test.csv
# 57 53
# 81 42
# 51 57
# 90 49
# 58 9
# 45 27
# 59 99
# 12 28
# Berg_TZ_1_train_z_710.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_1_test.csv
# 57 53
# 81 42
# 51 57
# 90 49
# 58 9
# 45 27
# 59 99
# 12 28
# Berg_TZ_1_train_z_90.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_1_test.csv
# 57 53
# 81 42
# 51 57
# 90 49
# 58 9
# 45 27
# 59 99
# 12 28
# TZ
# Berg_TZ_2_train_z_0.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_2_test.csv
# 36 32
# 45 41
# 64 46
# 69 65
# 57 53
# 64 15
# 62 91
# 14 11
# Berg_TZ_2_train_z_1000.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_2_test.csv
# 36 32
# 45 41
# 64 46
# 69 65
# 57 53
# 64 15
# 62 91
# 14 11
# Berg_TZ_2_train_z_125.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_2_test.csv
# 36 32
# 45 41
# 64 46
# 69 65
# 57 53
# 64 15
# 62 91
# 14 11
# Berg_TZ_2_train_z_180.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_2_test.csv
# 36 32
# 45 41
# 64 46
# 69 65
# 57 53
# 64 15
# 62 91
# 14 11
# Berg_TZ_2_train_z_250.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_2_test.csv
# 36 32
# 45 41
# 64 46
# 69 65
# 57 53
# 64 15
# 62 91
# 14 11
# Berg_TZ_2_train_z_355.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_2_test.csv
# 36 32
# 45 41
# 64 46
# 69 65
# 57 53
# 64 15
# 62 91
# 14 11
# Berg_TZ_2_train_z_500.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_2_test.csv
# 36 32
# 45 41
# 64 46
# 69 65
# 57 53
# 64 15
# 62 91
# 14 11
# Berg_TZ_2_train_z_63.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_2_test.csv
# 36 32
# 45 41
# 64 46
# 69 65
# 57 53
# 64 15
# 62 91
# 14 11
# Berg_TZ_2_train_z_710.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_2_test.csv
# 36 32
# 45 41
# 64 46
# 69 65
# 57 53
# 64 15
# 62 91
# 14 11
# Berg_TZ_2_train_z_90.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_2_test.csv
# 36 32
# 45 41
# 64 46
# 69 65
# 57 53
# 64 15
# 62 91
# 14 11
# TZ
# Berg_TZ_3_train_z_0.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_3_test.csv
# 60 40
# 62 91
# 64 15
# 46 54
# 81 42
# 74 42
# 73 36
# 28 14
# Berg_TZ_3_train_z_1000.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_3_test.csv
# 60 40
# 62 91
# 64 15
# 46 54
# 81 42
# 74 42
# 73 36
# 28 14
# Berg_TZ_3_train_z_125.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_3_test.csv
# 60 40
# 62 91
# 64 15
# 46 54
# 81 42
# 74 42
# 73 36
# 28 14
# Berg_TZ_3_train_z_180.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_3_test.csv
# 60 40
# 62 91
# 64 15
# 46 54
# 81 42
# 74 42
# 73 36
# 28 14
# Berg_TZ_3_train_z_250.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_3_test.csv
# 60 40
# 62 91
# 64 15
# 46 54
# 81 42
# 74 42
# 73 36
# 28 14
# Berg_TZ_3_train_z_355.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_3_test.csv
# 60 40
# 62 91
# 64 15
# 46 54
# 81 42
# 74 42
# 73 36
# 28 14
# Berg_TZ_3_train_z_500.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_3_test.csv
# 60 40
# 62 91
# 64 15
# 46 54
# 81 42
# 74 42
# 73 36
# 28 14
# Berg_TZ_3_train_z_63.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_3_test.csv
# 60 40
# 62 91
# 64 15
# 46 54
# 81 42
# 74 42
# 73 36
# 28 14
# Berg_TZ_3_train_z_710.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_3_test.csv
# 60 40
# 62 91
# 64 15
# 46 54
# 81 42
# 74 42
# 73 36
# 28 14
# Berg_TZ_3_train_z_90.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_3_test.csv
# 60 40
# 62 91
# 64 15
# 46 54
# 81 42
# 74 42
# 73 36
# 28 14
# TZ
# Berg_TZ_4_train_z_0.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_4_test.csv
# 46 54
# 84 44
# 36 60
# 28 14
# 46 8
# 33 67
# 52 23
# 47 74
# Berg_TZ_4_train_z_1000.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_4_test.csv
# 46 54
# 84 44
# 36 60
# 28 14
# 46 8
# 33 67
# 52 23
# 47 74
# Berg_TZ_4_train_z_125.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_4_test.csv
# 46 54
# 84 44
# 36 60
# 28 14
# 46 8
# 33 67
# 52 23
# 47 74
# Berg_TZ_4_train_z_180.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_4_test.csv
# 46 54
# 84 44
# 36 60
# 28 14
# 46 8
# 33 67
# 52 23
# 47 74
# Berg_TZ_4_train_z_250.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_4_test.csv
# 46 54
# 84 44
# 36 60
# 28 14
# 46 8
# 33 67
# 52 23
# 47 74
# Berg_TZ_4_train_z_355.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_4_test.csv
# 46 54
# 84 44
# 36 60
# 28 14
# 46 8
# 33 67
# 52 23
# 47 74
# Berg_TZ_4_train_z_500.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_4_test.csv
# 46 54
# 84 44
# 36 60
# 28 14
# 46 8
# 33 67
# 52 23
# 47 74
# Berg_TZ_4_train_z_63.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_4_test.csv
# 46 54
# 84 44
# 36 60
# 28 14
# 46 8
# 33 67
# 52 23
# 47 74
# Berg_TZ_4_train_z_710.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_4_test.csv
# 46 54
# 84 44
# 36 60
# 28 14
# 46 8
# 33 67
# 52 23
# 47 74
# Berg_TZ_4_train_z_90.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_4_test.csv
# 46 54
# 84 44
# 36 60
# 28 14
# 46 8
# 33 67
# 52 23
# 47 74
# TZ
# Berg_TZ_5_train_z_0.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_5_test.csv
# 10 44
# 58 9
# 49 81
# 51 57
# 59 99
# 44 61
# 46 54
# 1 27
# Berg_TZ_5_train_z_1000.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_5_test.csv
# 10 44
# 58 9
# 49 81
# 51 57
# 59 99
# 44 61
# 46 54
# 1 27
# Berg_TZ_5_train_z_125.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_5_test.csv
# 10 44
# 58 9
# 49 81
# 51 57
# 59 99
# 44 61
# 46 54
# 1 27
# Berg_TZ_5_train_z_180.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_5_test.csv
# 10 44
# 58 9
# 49 81
# 51 57
# 59 99
# 44 61
# 46 54
# 1 27
# Berg_TZ_5_train_z_250.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_5_test.csv
# 10 44
# 58 9
# 49 81
# 51 57
# 59 99
# 44 61
# 46 54
# 1 27
# Berg_TZ_5_train_z_355.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_5_test.csv
# 10 44
# 58 9
# 49 81
# 51 57
# 59 99
# 44 61
# 46 54
# 1 27
# Berg_TZ_5_train_z_500.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_5_test.csv
# 10 44
# 58 9
# 49 81
# 51 57
# 59 99
# 44 61
# 46 54
# 1 27
# Berg_TZ_5_train_z_63.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_5_test.csv
# 10 44
# 58 9
# 49 81
# 51 57
# 59 99
# 44 61
# 46 54
# 1 27
# Berg_TZ_5_train_z_710.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_5_test.csv
# 10 44
# 58 9
# 49 81
# 51 57
# 59 99
# 44 61
# 46 54
# 1 27
# Berg_TZ_5_train_z_90.asc ../_CROSS_VALIDATION_CLR/Berg/TZ/Berg_TZ_5_test.csv
# 10 44
# 58 9
# 49 81
# 51 57
# 59 99
# 44 61
# 46 54
# 1 27
# Number of files processed: 50
# MHZ
# 	 GZ
# GZ
# GZ
# MHZ_GZ_1_train_z_0.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_1_test.csv
# 41 99
# 1 8
# 15 42
# 9 58
# 24 33
# 15 33
# 25 4
# 59 34
# 37 46
# 30 40
# 28 41
# 29 1
# MHZ_GZ_1_train_z_1000.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_1_test.csv
# 41 99
# 1 8
# 15 42
# 9 58
# 24 33
# 15 33
# 25 4
# 59 34
# 37 46
# 30 40
# 28 41
# 29 1
# MHZ_GZ_1_train_z_125.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_1_test.csv
# 41 99
# 1 8
# 15 42
# 9 58
# 24 33
# 15 33
# 25 4
# 59 34
# 37 46
# 30 40
# 28 41
# 29 1
# MHZ_GZ_1_train_z_180.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_1_test.csv
# 41 99
# 1 8
# 15 42
# 9 58
# 24 33
# 15 33
# 25 4
# 59 34
# 37 46
# 30 40
# 28 41
# 29 1
# MHZ_GZ_1_train_z_250.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_1_test.csv
# 41 99
# 1 8
# 15 42
# 9 58
# 24 33
# 15 33
# 25 4
# 59 34
# 37 46
# 30 40
# 28 41
# 29 1
# MHZ_GZ_1_train_z_355.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_1_test.csv
# 41 99
# 1 8
# 15 42
# 9 58
# 24 33
# 15 33
# 25 4
# 59 34
# 37 46
# 30 40
# 28 41
# 29 1
# MHZ_GZ_1_train_z_500.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_1_test.csv
# 41 99
# 1 8
# 15 42
# 9 58
# 24 33
# 15 33
# 25 4
# 59 34
# 37 46
# 30 40
# 28 41
# 29 1
# MHZ_GZ_1_train_z_63.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_1_test.csv
# 41 99
# 1 8
# 15 42
# 9 58
# 24 33
# 15 33
# 25 4
# 59 34
# 37 46
# 30 40
# 28 41
# 29 1
# MHZ_GZ_1_train_z_710.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_1_test.csv
# 41 99
# 1 8
# 15 42
# 9 58
# 24 33
# 15 33
# 25 4
# 59 34
# 37 46
# 30 40
# 28 41
# 29 1
# MHZ_GZ_1_train_z_90.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_1_test.csv
# 41 99
# 1 8
# 15 42
# 9 58
# 24 33
# 15 33
# 25 4
# 59 34
# 37 46
# 30 40
# 28 41
# 29 1
# GZ
# MHZ_GZ_2_train_z_0.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_2_test.csv
# 46 66
# 34 75
# 15 42
# 28 41
# 25 52
# 24 86
# 28 69
# 22 62
# 44 86
# 17 13
# 33 66
# 67 22
# MHZ_GZ_2_train_z_1000.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_2_test.csv
# 46 66
# 34 75
# 15 42
# 28 41
# 25 52
# 24 86
# 28 69
# 22 62
# 44 86
# 17 13
# 33 66
# 67 22
# MHZ_GZ_2_train_z_125.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_2_test.csv
# 46 66
# 34 75
# 15 42
# 28 41
# 25 52
# 24 86
# 28 69
# 22 62
# 44 86
# 17 13
# 33 66
# 67 22
# MHZ_GZ_2_train_z_180.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_2_test.csv
# 46 66
# 34 75
# 15 42
# 28 41
# 25 52
# 24 86
# 28 69
# 22 62
# 44 86
# 17 13
# 33 66
# 67 22
# MHZ_GZ_2_train_z_250.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_2_test.csv
# 46 66
# 34 75
# 15 42
# 28 41
# 25 52
# 24 86
# 28 69
# 22 62
# 44 86
# 17 13
# 33 66
# 67 22
# MHZ_GZ_2_train_z_355.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_2_test.csv
# 46 66
# 34 75
# 15 42
# 28 41
# 25 52
# 24 86
# 28 69
# 22 62
# 44 86
# 17 13
# 33 66
# 67 22
# MHZ_GZ_2_train_z_500.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_2_test.csv
# 46 66
# 34 75
# 15 42
# 28 41
# 25 52
# 24 86
# 28 69
# 22 62
# 44 86
# 17 13
# 33 66
# 67 22
# MHZ_GZ_2_train_z_63.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_2_test.csv
# 46 66
# 34 75
# 15 42
# 28 41
# 25 52
# 24 86
# 28 69
# 22 62
# 44 86
# 17 13
# 33 66
# 67 22
# MHZ_GZ_2_train_z_710.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_2_test.csv
# 46 66
# 34 75
# 15 42
# 28 41
# 25 52
# 24 86
# 28 69
# 22 62
# 44 86
# 17 13
# 33 66
# 67 22
# MHZ_GZ_2_train_z_90.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_2_test.csv
# 46 66
# 34 75
# 15 42
# 28 41
# 25 52
# 24 86
# 28 69
# 22 62
# 44 86
# 17 13
# 33 66
# 67 22
# GZ
# MHZ_GZ_3_train_z_0.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_3_test.csv
# 9 58
# 74 19
# 46 66
# 60 17
# 60 3
# 66 13
# 51 36
# 25 52
# 36 63
# 49 75
# 44 86
# 30 40
# MHZ_GZ_3_train_z_1000.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_3_test.csv
# 9 58
# 74 19
# 46 66
# 60 17
# 60 3
# 66 13
# 51 36
# 25 52
# 36 63
# 49 75
# 44 86
# 30 40
# MHZ_GZ_3_train_z_125.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_3_test.csv
# 9 58
# 74 19
# 46 66
# 60 17
# 60 3
# 66 13
# 51 36
# 25 52
# 36 63
# 49 75
# 44 86
# 30 40
# MHZ_GZ_3_train_z_180.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_3_test.csv
# 9 58
# 74 19
# 46 66
# 60 17
# 60 3
# 66 13
# 51 36
# 25 52
# 36 63
# 49 75
# 44 86
# 30 40
# MHZ_GZ_3_train_z_250.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_3_test.csv
# 9 58
# 74 19
# 46 66
# 60 17
# 60 3
# 66 13
# 51 36
# 25 52
# 36 63
# 49 75
# 44 86
# 30 40
# MHZ_GZ_3_train_z_355.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_3_test.csv
# 9 58
# 74 19
# 46 66
# 60 17
# 60 3
# 66 13
# 51 36
# 25 52
# 36 63
# 49 75
# 44 86
# 30 40
# MHZ_GZ_3_train_z_500.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_3_test.csv
# 9 58
# 74 19
# 46 66
# 60 17
# 60 3
# 66 13
# 51 36
# 25 52
# 36 63
# 49 75
# 44 86
# 30 40
# MHZ_GZ_3_train_z_63.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_3_test.csv
# 9 58
# 74 19
# 46 66
# 60 17
# 60 3
# 66 13
# 51 36
# 25 52
# 36 63
# 49 75
# 44 86
# 30 40
# MHZ_GZ_3_train_z_710.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_3_test.csv
# 9 58
# 74 19
# 46 66
# 60 17
# 60 3
# 66 13
# 51 36
# 25 52
# 36 63
# 49 75
# 44 86
# 30 40
# MHZ_GZ_3_train_z_90.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_3_test.csv
# 9 58
# 74 19
# 46 66
# 60 17
# 60 3
# 66 13
# 51 36
# 25 52
# 36 63
# 49 75
# 44 86
# 30 40
# GZ
# MHZ_GZ_4_train_z_0.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_4_test.csv
# 39 0
# 67 36
# 52 79
# 58 55
# 60 17
# 28 69
# 15 42
# 49 90
# 60 3
# 72 58
# 70 5
# 36 63
# MHZ_GZ_4_train_z_1000.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_4_test.csv
# 39 0
# 67 36
# 52 79
# 58 55
# 60 17
# 28 69
# 15 42
# 49 90
# 60 3
# 72 58
# 70 5
# 36 63
# MHZ_GZ_4_train_z_125.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_4_test.csv
# 39 0
# 67 36
# 52 79
# 58 55
# 60 17
# 28 69
# 15 42
# 49 90
# 60 3
# 72 58
# 70 5
# 36 63
# MHZ_GZ_4_train_z_180.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_4_test.csv
# 39 0
# 67 36
# 52 79
# 58 55
# 60 17
# 28 69
# 15 42
# 49 90
# 60 3
# 72 58
# 70 5
# 36 63
# MHZ_GZ_4_train_z_250.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_4_test.csv
# 39 0
# 67 36
# 52 79
# 58 55
# 60 17
# 28 69
# 15 42
# 49 90
# 60 3
# 72 58
# 70 5
# 36 63
# MHZ_GZ_4_train_z_355.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_4_test.csv
# 39 0
# 67 36
# 52 79
# 58 55
# 60 17
# 28 69
# 15 42
# 49 90
# 60 3
# 72 58
# 70 5
# 36 63
# MHZ_GZ_4_train_z_500.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_4_test.csv
# 39 0
# 67 36
# 52 79
# 58 55
# 60 17
# 28 69
# 15 42
# 49 90
# 60 3
# 72 58
# 70 5
# 36 63
# MHZ_GZ_4_train_z_63.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_4_test.csv
# 39 0
# 67 36
# 52 79
# 58 55
# 60 17
# 28 69
# 15 42
# 49 90
# 60 3
# 72 58
# 70 5
# 36 63
# MHZ_GZ_4_train_z_710.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_4_test.csv
# 39 0
# 67 36
# 52 79
# 58 55
# 60 17
# 28 69
# 15 42
# 49 90
# 60 3
# 72 58
# 70 5
# 36 63
# MHZ_GZ_4_train_z_90.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_4_test.csv
# 39 0
# 67 36
# 52 79
# 58 55
# 60 17
# 28 69
# 15 42
# 49 90
# 60 3
# 72 58
# 70 5
# 36 63
# GZ
# MHZ_GZ_5_train_z_0.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_5_test.csv
# 58 75
# 67 22
# 15 33
# 30 40
# 40 66
# 59 34
# 72 58
# 51 60
# 25 52
# 28 69
# 37 46
# 28 41
# MHZ_GZ_5_train_z_1000.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_5_test.csv
# 58 75
# 67 22
# 15 33
# 30 40
# 40 66
# 59 34
# 72 58
# 51 60
# 25 52
# 28 69
# 37 46
# 28 41
# MHZ_GZ_5_train_z_125.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_5_test.csv
# 58 75
# 67 22
# 15 33
# 30 40
# 40 66
# 59 34
# 72 58
# 51 60
# 25 52
# 28 69
# 37 46
# 28 41
# MHZ_GZ_5_train_z_180.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_5_test.csv
# 58 75
# 67 22
# 15 33
# 30 40
# 40 66
# 59 34
# 72 58
# 51 60
# 25 52
# 28 69
# 37 46
# 28 41
# MHZ_GZ_5_train_z_250.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_5_test.csv
# 58 75
# 67 22
# 15 33
# 30 40
# 40 66
# 59 34
# 72 58
# 51 60
# 25 52
# 28 69
# 37 46
# 28 41
# MHZ_GZ_5_train_z_355.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_5_test.csv
# 58 75
# 67 22
# 15 33
# 30 40
# 40 66
# 59 34
# 72 58
# 51 60
# 25 52
# 28 69
# 37 46
# 28 41
# MHZ_GZ_5_train_z_500.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_5_test.csv
# 58 75
# 67 22
# 15 33
# 30 40
# 40 66
# 59 34
# 72 58
# 51 60
# 25 52
# 28 69
# 37 46
# 28 41
# MHZ_GZ_5_train_z_63.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_5_test.csv
# 58 75
# 67 22
# 15 33
# 30 40
# 40 66
# 59 34
# 72 58
# 51 60
# 25 52
# 28 69
# 37 46
# 28 41
# MHZ_GZ_5_train_z_710.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_5_test.csv
# 58 75
# 67 22
# 15 33
# 30 40
# 40 66
# 59 34
# 72 58
# 51 60
# 25 52
# 28 69
# 37 46
# 28 41
# MHZ_GZ_5_train_z_90.asc ../_CROSS_VALIDATION_CLR/MHZ/GZ/MHZ_GZ_5_test.csv
# 58 75
# 67 22
# 15 33
# 30 40
# 40 66
# 59 34
# 72 58
# 51 60
# 25 52
# 28 69
# 37 46
# 28 41
# Number of files processed: 50
# 	 IZ
# IZ
# IZ
# MHZ_IZ_1_train_z_0.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_1_test.csv
# 27 5
# 48 47
# 62 50
# 9 79
# 61 93
# 64 60
# 54 99
# 16 36
# 26 36
# 50 11
# 54 56
# 33 44
# 30 45
# MHZ_IZ_1_train_z_1000.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_1_test.csv
# 27 5
# 48 47
# 62 50
# 9 79
# 61 93
# 64 60
# 54 99
# 16 36
# 26 36
# 50 11
# 54 56
# 33 44
# 30 45
# MHZ_IZ_1_train_z_125.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_1_test.csv
# 27 5
# 48 47
# 62 50
# 9 79
# 61 93
# 64 60
# 54 99
# 16 36
# 26 36
# 50 11
# 54 56
# 33 44
# 30 45
# MHZ_IZ_1_train_z_180.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_1_test.csv
# 27 5
# 48 47
# 62 50
# 9 79
# 61 93
# 64 60
# 54 99
# 16 36
# 26 36
# 50 11
# 54 56
# 33 44
# 30 45
# MHZ_IZ_1_train_z_250.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_1_test.csv
# 27 5
# 48 47
# 62 50
# 9 79
# 61 93
# 64 60
# 54 99
# 16 36
# 26 36
# 50 11
# 54 56
# 33 44
# 30 45
# MHZ_IZ_1_train_z_355.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_1_test.csv
# 27 5
# 48 47
# 62 50
# 9 79
# 61 93
# 64 60
# 54 99
# 16 36
# 26 36
# 50 11
# 54 56
# 33 44
# 30 45
# MHZ_IZ_1_train_z_500.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_1_test.csv
# 27 5
# 48 47
# 62 50
# 9 79
# 61 93
# 64 60
# 54 99
# 16 36
# 26 36
# 50 11
# 54 56
# 33 44
# 30 45
# MHZ_IZ_1_train_z_63.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_1_test.csv
# 27 5
# 48 47
# 62 50
# 9 79
# 61 93
# 64 60
# 54 99
# 16 36
# 26 36
# 50 11
# 54 56
# 33 44
# 30 45
# MHZ_IZ_1_train_z_710.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_1_test.csv
# 27 5
# 48 47
# 62 50
# 9 79
# 61 93
# 64 60
# 54 99
# 16 36
# 26 36
# 50 11
# 54 56
# 33 44
# 30 45
# MHZ_IZ_1_train_z_90.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_1_test.csv
# 27 5
# 48 47
# 62 50
# 9 79
# 61 93
# 64 60
# 54 99
# 16 36
# 26 36
# 50 11
# 54 56
# 33 44
# 30 45
# IZ
# MHZ_IZ_2_train_z_0.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_2_test.csv
# 16 36
# 24 68
# 40 25
# 36 72
# 40 50
# 30 45
# 14 31
# 55 66
# 45 80
# 48 95
# 47 64
# 30 76
# 73 24
# MHZ_IZ_2_train_z_1000.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_2_test.csv
# 16 36
# 24 68
# 40 25
# 36 72
# 40 50
# 30 45
# 14 31
# 55 66
# 45 80
# 48 95
# 47 64
# 30 76
# 73 24
# MHZ_IZ_2_train_z_125.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_2_test.csv
# 16 36
# 24 68
# 40 25
# 36 72
# 40 50
# 30 45
# 14 31
# 55 66
# 45 80
# 48 95
# 47 64
# 30 76
# 73 24
# MHZ_IZ_2_train_z_180.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_2_test.csv
# 16 36
# 24 68
# 40 25
# 36 72
# 40 50
# 30 45
# 14 31
# 55 66
# 45 80
# 48 95
# 47 64
# 30 76
# 73 24
# MHZ_IZ_2_train_z_250.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_2_test.csv
# 16 36
# 24 68
# 40 25
# 36 72
# 40 50
# 30 45
# 14 31
# 55 66
# 45 80
# 48 95
# 47 64
# 30 76
# 73 24
# MHZ_IZ_2_train_z_355.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_2_test.csv
# 16 36
# 24 68
# 40 25
# 36 72
# 40 50
# 30 45
# 14 31
# 55 66
# 45 80
# 48 95
# 47 64
# 30 76
# 73 24
# MHZ_IZ_2_train_z_500.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_2_test.csv
# 16 36
# 24 68
# 40 25
# 36 72
# 40 50
# 30 45
# 14 31
# 55 66
# 45 80
# 48 95
# 47 64
# 30 76
# 73 24
# MHZ_IZ_2_train_z_63.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_2_test.csv
# 16 36
# 24 68
# 40 25
# 36 72
# 40 50
# 30 45
# 14 31
# 55 66
# 45 80
# 48 95
# 47 64
# 30 76
# 73 24
# MHZ_IZ_2_train_z_710.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_2_test.csv
# 16 36
# 24 68
# 40 25
# 36 72
# 40 50
# 30 45
# 14 31
# 55 66
# 45 80
# 48 95
# 47 64
# 30 76
# 73 24
# MHZ_IZ_2_train_z_90.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_2_test.csv
# 16 36
# 24 68
# 40 25
# 36 72
# 40 50
# 30 45
# 14 31
# 55 66
# 45 80
# 48 95
# 47 64
# 30 76
# 73 24
# IZ
# MHZ_IZ_3_train_z_0.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_3_test.csv
# 40 25
# 33 31
# 50 72
# 56 19
# 16 46
# 40 50
# 42 0
# 55 66
# 45 18
# 64 82
# 27 57
# 37 82
# 73 24
# MHZ_IZ_3_train_z_1000.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_3_test.csv
# 40 25
# 33 31
# 50 72
# 56 19
# 16 46
# 40 50
# 42 0
# 55 66
# 45 18
# 64 82
# 27 57
# 37 82
# 73 24
# MHZ_IZ_3_train_z_125.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_3_test.csv
# 40 25
# 33 31
# 50 72
# 56 19
# 16 46
# 40 50
# 42 0
# 55 66
# 45 18
# 64 82
# 27 57
# 37 82
# 73 24
# MHZ_IZ_3_train_z_180.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_3_test.csv
# 40 25
# 33 31
# 50 72
# 56 19
# 16 46
# 40 50
# 42 0
# 55 66
# 45 18
# 64 82
# 27 57
# 37 82
# 73 24
# MHZ_IZ_3_train_z_250.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_3_test.csv
# 40 25
# 33 31
# 50 72
# 56 19
# 16 46
# 40 50
# 42 0
# 55 66
# 45 18
# 64 82
# 27 57
# 37 82
# 73 24
# MHZ_IZ_3_train_z_355.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_3_test.csv
# 40 25
# 33 31
# 50 72
# 56 19
# 16 46
# 40 50
# 42 0
# 55 66
# 45 18
# 64 82
# 27 57
# 37 82
# 73 24
# MHZ_IZ_3_train_z_500.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_3_test.csv
# 40 25
# 33 31
# 50 72
# 56 19
# 16 46
# 40 50
# 42 0
# 55 66
# 45 18
# 64 82
# 27 57
# 37 82
# 73 24
# MHZ_IZ_3_train_z_63.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_3_test.csv
# 40 25
# 33 31
# 50 72
# 56 19
# 16 46
# 40 50
# 42 0
# 55 66
# 45 18
# 64 82
# 27 57
# 37 82
# 73 24
# MHZ_IZ_3_train_z_710.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_3_test.csv
# 40 25
# 33 31
# 50 72
# 56 19
# 16 46
# 40 50
# 42 0
# 55 66
# 45 18
# 64 82
# 27 57
# 37 82
# 73 24
# MHZ_IZ_3_train_z_90.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_3_test.csv
# 40 25
# 33 31
# 50 72
# 56 19
# 16 46
# 40 50
# 42 0
# 55 66
# 45 18
# 64 82
# 27 57
# 37 82
# 73 24
# IZ
# MHZ_IZ_4_train_z_0.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_4_test.csv
# 1 8
# 37 82
# 39 69
# 74 40
# 53 82
# 44 72
# 25 64
# 65 19
# 27 57
# 54 56
# 42 0
# 56 39
# 53 3
# MHZ_IZ_4_train_z_1000.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_4_test.csv
# 1 8
# 37 82
# 39 69
# 74 40
# 53 82
# 44 72
# 25 64
# 65 19
# 27 57
# 54 56
# 42 0
# 56 39
# 53 3
# MHZ_IZ_4_train_z_125.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_4_test.csv
# 1 8
# 37 82
# 39 69
# 74 40
# 53 82
# 44 72
# 25 64
# 65 19
# 27 57
# 54 56
# 42 0
# 56 39
# 53 3
# MHZ_IZ_4_train_z_180.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_4_test.csv
# 1 8
# 37 82
# 39 69
# 74 40
# 53 82
# 44 72
# 25 64
# 65 19
# 27 57
# 54 56
# 42 0
# 56 39
# 53 3
# MHZ_IZ_4_train_z_250.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_4_test.csv
# 1 8
# 37 82
# 39 69
# 74 40
# 53 82
# 44 72
# 25 64
# 65 19
# 27 57
# 54 56
# 42 0
# 56 39
# 53 3
# MHZ_IZ_4_train_z_355.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_4_test.csv
# 1 8
# 37 82
# 39 69
# 74 40
# 53 82
# 44 72
# 25 64
# 65 19
# 27 57
# 54 56
# 42 0
# 56 39
# 53 3
# MHZ_IZ_4_train_z_500.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_4_test.csv
# 1 8
# 37 82
# 39 69
# 74 40
# 53 82
# 44 72
# 25 64
# 65 19
# 27 57
# 54 56
# 42 0
# 56 39
# 53 3
# MHZ_IZ_4_train_z_63.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_4_test.csv
# 1 8
# 37 82
# 39 69
# 74 40
# 53 82
# 44 72
# 25 64
# 65 19
# 27 57
# 54 56
# 42 0
# 56 39
# 53 3
# MHZ_IZ_4_train_z_710.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_4_test.csv
# 1 8
# 37 82
# 39 69
# 74 40
# 53 82
# 44 72
# 25 64
# 65 19
# 27 57
# 54 56
# 42 0
# 56 39
# 53 3
# MHZ_IZ_4_train_z_90.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_4_test.csv
# 1 8
# 37 82
# 39 69
# 74 40
# 53 82
# 44 72
# 25 64
# 65 19
# 27 57
# 54 56
# 42 0
# 56 39
# 53 3
# IZ
# MHZ_IZ_5_train_z_0.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_5_test.csv
# 79 63
# 71 54
# 27 57
# 73 24
# 54 56
# 27 5
# 38 9
# 29 54
# 50 27
# 16 46
# 26 36
# 48 95
# 37 82
# MHZ_IZ_5_train_z_1000.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_5_test.csv
# 79 63
# 71 54
# 27 57
# 73 24
# 54 56
# 27 5
# 38 9
# 29 54
# 50 27
# 16 46
# 26 36
# 48 95
# 37 82
# MHZ_IZ_5_train_z_125.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_5_test.csv
# 79 63
# 71 54
# 27 57
# 73 24
# 54 56
# 27 5
# 38 9
# 29 54
# 50 27
# 16 46
# 26 36
# 48 95
# 37 82
# MHZ_IZ_5_train_z_180.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_5_test.csv
# 79 63
# 71 54
# 27 57
# 73 24
# 54 56
# 27 5
# 38 9
# 29 54
# 50 27
# 16 46
# 26 36
# 48 95
# 37 82
# MHZ_IZ_5_train_z_250.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_5_test.csv
# 79 63
# 71 54
# 27 57
# 73 24
# 54 56
# 27 5
# 38 9
# 29 54
# 50 27
# 16 46
# 26 36
# 48 95
# 37 82
# MHZ_IZ_5_train_z_355.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_5_test.csv
# 79 63
# 71 54
# 27 57
# 73 24
# 54 56
# 27 5
# 38 9
# 29 54
# 50 27
# 16 46
# 26 36
# 48 95
# 37 82
# MHZ_IZ_5_train_z_500.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_5_test.csv
# 79 63
# 71 54
# 27 57
# 73 24
# 54 56
# 27 5
# 38 9
# 29 54
# 50 27
# 16 46
# 26 36
# 48 95
# 37 82
# MHZ_IZ_5_train_z_63.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_5_test.csv
# 79 63
# 71 54
# 27 57
# 73 24
# 54 56
# 27 5
# 38 9
# 29 54
# 50 27
# 16 46
# 26 36
# 48 95
# 37 82
# MHZ_IZ_5_train_z_710.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_5_test.csv
# 79 63
# 71 54
# 27 57
# 73 24
# 54 56
# 27 5
# 38 9
# 29 54
# 50 27
# 16 46
# 26 36
# 48 95
# 37 82
# MHZ_IZ_5_train_z_90.asc ../_CROSS_VALIDATION_CLR/MHZ/IZ/MHZ_IZ_5_test.csv
# 79 63
# 71 54
# 27 57
# 73 24
# 54 56
# 27 5
# 38 9
# 29 54
# 50 27
# 16 46
# 26 36
# 48 95
# 37 82
# Number of files processed: 50
# 	 TZ
# TZ
# TZ
# MHZ_TZ_1_train_z_0.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_1_train_z_1000.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_1_train_z_125.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_1_train_z_180.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_1_train_z_250.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_1_train_z_355.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_1_train_z_500.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_1_train_z_63.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_1_train_z_710.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_1_train_z_90.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# TZ
# MHZ_TZ_2_train_z_0.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_2_train_z_1000.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_2_train_z_125.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_2_train_z_180.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_2_train_z_250.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_2_train_z_355.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_2_train_z_500.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_2_train_z_63.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_2_train_z_710.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_2_train_z_90.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# TZ
# MHZ_TZ_3_train_z_0.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_3_train_z_1000.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_3_train_z_125.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_3_train_z_180.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_3_train_z_250.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_3_train_z_355.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_3_train_z_500.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_3_train_z_63.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_3_train_z_710.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_3_train_z_90.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# TZ
# MHZ_TZ_4_train_z_0.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_4_train_z_1000.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_4_train_z_125.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_4_train_z_180.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_4_train_z_250.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_4_train_z_355.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_4_train_z_500.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_4_train_z_63.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_4_train_z_710.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_4_train_z_90.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# TZ
# MHZ_TZ_5_train_z_0.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_5_train_z_1000.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_5_train_z_125.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_5_train_z_180.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_5_train_z_250.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_5_train_z_355.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_5_train_z_500.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_5_train_z_63.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_5_train_z_710.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_5_train_z_90.asc ../_CROSS_VALIDATION_CLR/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# Number of files processed: 50
# Wall time: 22.3 s

# %% [markdown]
# ### MSE calculation

# %%
mse_results_classic = cv.calculate_mse_classic(results_quarry_classic)

# %%
averaged_mse_quarry_classic= {}

for quarry in ["Berg", "MHZ"]:
    averaged_mse_geol_classic = {}
    
    for geol in ["GZ", "IZ", "TZ"]:
            averaged_mse_geol_classic[geol] = cv.average_mse_results_CVfolds_classic(mse_results_classic, 
                                                                                     quarry, 
                                                                                     geol)
        
    averaged_mse_quarry_classic[quarry] = averaged_mse_geol_classic

# %%
averaged_mse_quarry_n_comp_classic = {}

for quarry, geol_data in averaged_mse_quarry_classic.items():
    for geol, data in geol_data.items():
        averaged_mse_quarry_n_comp_classic[quarry, geol] = cv.average_mse_results_n_comp(data)

# %%
MSE_results_classic = pd.DataFrame.from_dict(averaged_mse_quarry_n_comp_classic, orient='index')
index_multi3 = pd.MultiIndex.from_tuples(MSE_results_classic.index)
MSE_results_classic = MSE_results_classic.reindex(index=index_multi3)
MSE_results_classic.columns = ["MSE classic"]
# Uncomment following line to save dataframe
#MSE_results_classic.to_excel("../_RESULTS/MSE_RESULTS/MSE_classic_clr.xlsx")
MSE_results_classic
# Out:
#          MSE classic
# Berg GZ    12.239965
#      IZ     7.239879
#      TZ    11.654975
# MHZ  GZ     8.144558
#      IZ    13.881520
#      TZ     2.378134

# %%
# Classical approach - average MSE results per grain size class
gsd_info_quarry = {}

for quarry, geol_data in mse_results_classic.items():
    gsd_info_geol = {}
    
    for geol, train_data in geol_data.items():
        gsd_info = {}
        for train, grain_size_data in train_data.items():
            
            for grain_size, data in grain_size_data.items():
                
                if grain_size not in gsd_info:
                    gsd_info[grain_size] = [data]
                else:
                    gsd_info[grain_size].append(data)
                
                    
        gsd_info_geol[geol] = gsd_info
        
    gsd_info_quarry[quarry] = gsd_info_geol

# %%
gsd_info_quarry_mean = {}

for quarry, geol_data in gsd_info_quarry.items():
    for geol, train_data in geol_data.items():
        for grain_size, data in train_data.items():
            gsd_info_quarry_mean[quarry, geol, grain_size] = np.mean(data)

# %%
MSE_results_classic_gsd = pd.DataFrame.from_dict(gsd_info_quarry_mean, orient='index')
index_multi4 = pd.MultiIndex.from_tuples(MSE_results_classic_gsd.index)
MSE_results_classic_gsd = MSE_results_classic_gsd.reindex(index_multi4)
MSE_results_classic_gsd.columns = ["MSE classic"]
# Uncomment following line to save dataframe
#MSE_results_classic_gsd.to_excel("../_RESULTS/MSE_classic_gsd_clr.xlsx")
MSE_results_classic_gsd
# Out:
#                 MSE classic
# Berg GZ z_0       16.927932
#         z_1000    17.250467
#         z_125      8.087712
#         z_180      7.698691
#         z_250      7.283632
#         z_355      6.590959
#         z_500     10.914274
#         z_63      26.635892
#         z_710     15.956950
#         z_90       5.053142
#      IZ z_0        6.998150
#         z_1000    28.493655
#         z_125      2.173674
#         z_180      2.592517
#         z_250      2.858130
#         z_355      2.666618
#         z_500      4.726105
#         z_63      10.202060
#         z_710      9.770562
#         z_90       1.917316
#      TZ z_0       33.563596
#         z_1000    33.905264
#         z_125      6.215575
#         z_180      4.780589
#         z_250      3.205396
#         z_355      6.287201
#         z_500     10.476400
#         z_63       7.636196
#         z_710      6.110113
#         z_90       4.369420
# MHZ  GZ z_0       19.351804
#         z_1000    23.214710
#         z_125      1.753983
#         z_180      2.042278
#         z_250      2.509092
#         z_355      2.077532
#         z_500      1.661359
#         z_63       7.854269
#         z_710     19.203858
#         z_90       1.776691
#      IZ z_0       46.068421
#         z_1000    34.248040
#         z_125      3.237496
#         z_180      3.709739
#         z_250      3.888701
#         z_355      3.648537
#         z_500      2.940894
#         z_63       5.433678
#         z_710     31.981444
#         z_90       3.658253
#      TZ z_0        4.101305
#         z_1000     7.664706
#         z_125      0.579545
#         z_180      1.032797
#         z_250      0.824897
#         z_355      0.527091
#         z_500      0.443406
#         z_63       2.165650
#         z_710      5.424623
#         z_90       1.017317

# %% [markdown]
# ___

# %% [markdown]
# ## Cross validation - archive

# %% [raw]
# rootDir = "../_RESULTS/POSTPROCESSED/"
# n_files = 0
#
# results_quarry = {}
# results_geol = {}
#
# for dirName, subdirList, fileList in os.walk(rootDir):
#
#     if "Berg" in dirName:
#         print(dirName)
#         inputfile = "../_DATA/Berg_usable_data.xlsx"
#         quarry = "Berg"
#     elif "MHZ" in dirName:
#         print(dirName)
#         inputfile = "../_DATA/MHZ_usable_data.xlsx"
#         quarry = "MHZ"
#         results_geol = {}
#     else:
#         quarry = None
#
#     if "TZ" in dirName:
#         code_geol = "TZ"
#         print(code_geol)
#     elif "IZ" in dirName:
#         code_geol = "IZ"
#         print(code_geol)
#     elif "GZ" in dirName:
#         code_geol="GZ"
#         print(code_geol)
#     else:
#         code_geol = None
#
#     if code_geol != None:
#         boreholes = list(pd.read_excel(inputfile, sheet_name=code_geol).set_index("hole_id").index)
#
#     results_temp = {}
#
#     # Change code to incorporate all number of components
#     # TO DO: Change to list [5comp, 9comp]
#     if dirName.endswith("9comp"):
#         for file in fileList:
#             # TO DO: Change to list with all grain size classes
#             if file.endswith("z_180_kriged_reverse_9comp_spherical.asc"):
#                 n_files +=1
#                 print(dirName + "\\" + file)
#                 gridfile = dirName + "\\" + file
#
#                 regex = "z_\d+"
#                 grain_size = re.search(regex, file).group()
#
#
#                 lookup_results = {}
#
#                 for borehole in boreholes:
#                     lookup_results[borehole] = cv.lookup_value(gridfile, inputfile, borehole, code_geol, average=False)
#                 lookup_df = pd.DataFrame.from_dict(lookup_results, orient='index')
#                 lookup_df.columns = ["Grid", "Actual"]
#                 lookup_df["Diff"] = lookup_df["Grid"] - lookup_df["Actual"]
#
#                 results_temp[grain_size] = lookup_df
#         results_geol[code_geol] = results_temp
#     results_quarry[quarry] = results_geol
#
# print(n_files)

# %% [raw]
# %%time
# # Classical approach - Look up values
# rootDir_grid = "../_KRIGING/CROSS_VALIDATION_CLASSIC_CLR//"
# rootDir_input = "../_CROSS_VALIDATION/"
# n_files = 0
#
# results_quarry = {}
# results_geol = {}
#
# for dirName, subdirList, fileList in os.walk(rootDir_grid):
#     print(dirName)
#     if dirName.endswith("Berg"):
#         print(dirName)
#         quarry = "Berg"
#     elif dirName.endswith("MHZ"):
#         print(dirName)
#         quarry = "MHZ"
#         results_geol = {}
#     else:
#         quarry = None
#
#     if dirName.endswith("TZ"):
#         code_geol = "TZ"
#         print(code_geol)
#     elif dirName.endswith("IZ"):
#         code_geol = "IZ"
#         print(code_geol)
#     elif dirName.endswith("GZ"):
#         code_geol="GZ"
#         print(code_geol)
#     else:
#         pass
#
#
#     results_temp = {}
#     for file in fileList:
#         print(file)
#         if file[-6] in [1, 2, 3, 4, 5]:
#             print(file[-6])
#             n_train = file[-6]
#
#             inputfile = f"../_CROSS_VALIDATION/{quarry}/{code_geol}/{quarry}_{code_geol}_{n_train}_test"
#             boreholes = list(pd.read_excel(inputfile, sheet_name=code_geol).set_index("hole_id").index)
#
#
#             n_files +=1
#             print(dirName + "\\" + file)
#             gridfile = dirName + "\\" + file
#
#             regex = "z_\d+"
#             grain_size = re.search(regex, file).group()
#
#             lookup_results = {}
#
#             for borehole in boreholes:
#                 lookup_results[borehole] = lookup_value(gridfile, inputfile, borehole, code_geol, average=False)
#             lookup_df = pd.DataFrame.from_dict(lookup_results, orient='index')
#             lookup_df.columns = ["Grid", "Actual"]
#             lookup_df["Diff"] = lookup_df["Grid"] - lookup_df["Actual"]
#
#             results_temp[grain_size, n_train] = lookup_df
#
#             results_geol[code_geol] = results_temp
#
#
#     if quarry != None:
#         results_quarry[quarry] = results_geol
#
# print(n_files)

# %% [raw]
# mse = {}
# for quarry, value in results_quarry.items():
#     mse_temp = {}
#     for geol, value2 in value.items():
#         for grain_size, data in value2.items():
#             print(quarry)
#             mse_result = ((data["Actual"] - data["Grid"]) ** 2).mean(axis=0)
#             print(mse_result)
#             mse_temp[geol] = mse_result
#             print(mse_temp)
#     mse[quarry] = mse_temp

# %% [raw]
# mse

# %% [raw]
# results[("Berg", "GZ")]

# %% [raw]
# gridfile = "../_RESULTS/POSTPROCESSED/Berg/GZ/9comp/Berg_GZ_z_1000_kriged_reverse_9comp_test_spherical.asc"
# inputfile = "../_DATA/Berg_usable_data.xlsx"
# boreholes = list(pd.read_excel(inputfile, sheet_name="GZ").set_index("hole_id").index)
#
# lookup_results = {}
#
# for borehole in boreholes:
#     lookup_results[borehole] = cv.lookup_value(gridfile, inputfile, borehole, average=False)

# %% [raw]
# lookup_df = pd.DataFrame.from_dict(lookup_results, orient='index')
# lookup_df.columns = ["Grid", "Actual"]
# lookup_df["Diff"] = lookup_df["Grid"] - lookup_df["Actual"]

# %% [raw]
# lookup_df.style

# %% [raw]
# # Cross validation pre-processing Berg
# rootDir = "../_CROSS_VALIDATION_80-20/Berg/"
#
# cross_validation_pre_processing_Berg = {}
#
# for dirName, subdirList, fileList in os.walk(rootDir):
#
#     if dirName.endswith("TZ"):
#         code_geol = "TZ"
#         print(code_geol)
#     elif dirName.endswith("IZ"):
#         code_geol = "IZ"
#         print(code_geol)
#     elif dirName.endswith("GZ"):
#         code_geol="GZ"
#         print(code_geol)
#     else:
#         code_geol = None
#
#     i = 1
#
#     layer_pre_processing = {}
#
#     for file in fileList:
#         if file.endswith("train.xlsx"):
#             layer_pre_processing[f"train_{str(i)}"] = ppp.pre_processing(f"{rootDir}/{code_geol}/{file}",
#                                                            save_data=True,
#                                                            save_name=f"../_RESULTS/CROSS_VALIDATION_PREPROCESSED_80-20/Berg/{code_geol}/{code_geol}_{str(i)}_train_pca")
#             i += 1
#     if code_geol != None:
#         cross_validation_pre_processing_Berg[code_geol] = layer_pre_processing

# %% [raw]
# # Cross validation pre-processing MHZ
# rootDir = "../_CROSS_VALIDATION_80-20/MHZ/"
#
# cross_validation_pre_processing_MHZ = {}
#
# for dirName, subdirList, fileList in os.walk(rootDir):
#
#     if dirName.endswith("TZ"):
#         code_geol = "TZ"
#         print(code_geol)
#     elif dirName.endswith("IZ"):
#         code_geol = "IZ"
#         print(code_geol)
#     elif dirName.endswith("GZ"):
#         code_geol="GZ"
#         print(code_geol)
#     else:
#         code_geol = None
#
#     i = 1
#
#     layer_pre_processing = {}
#
#     for file in fileList:
#         if file.endswith("train.xlsx"):
#             layer_pre_processing[f"train_{str(i)}"] = ppp.pre_processing(f"{rootDir}/{code_geol}/{file}",
#                                                            save_data=True,
#                                                            save_name=f"../_RESULTS/CROSS_VALIDATION_PREPROCESSED_80-20/MHZ/{code_geol}/{code_geol}_{str(i)}_train_pca")
#             i += 1
#     if code_geol != None:
#         cross_validation_pre_processing_MHZ[code_geol] = layer_pre_processing

# %% [raw]
# %%time
# # Post_processing cross-validation: CHANGE PARAMETERS IN FUNCTION FOR DIFFERENT QUARRIES/LAYERS!
# for j in range(1,6):
#     for i in range(1,10):
#         ppp.post_processing(f"../_KRIGING/CROSS_VALIDATION_PREPROCESSED_80-20/data_MHZ/TZ/train_{str(j)}/",
#                         cross_validation_pre_processing_MHZ["TZ"][f"train_{str(j)}"][0],
#                         cross_validation_pre_processing_MHZ["TZ"][f"train_{str(j)}"][1],
#                         grid_data=dict_grid_info["MHZ_IZ_TZ"],
#                         n_components=i,
#                         save_data=True);
#
# # TO DO: create folder structure to save files in and change code in post-processing script

# %% [raw]
# # Convert test xslsx files to csv
# rootDir = "../_CROSS_VALIDATION/"
#
# n_files = 0
#
# for dirName, subdirList, fileList in os.walk(rootDir):
#     for file in fileList:
#         if file.endswith("test.xlsx"):
#             temp = pd.read_excel(dirName+"/"+file)
#             temp.to_csv(dirName+"/"+file[:-5]+".csv", sep=";")

# %% [markdown]
# ## Cross validation

# %%
# %%time

results_quarry = {}

for quarry in ["Berg", "MHZ"]:
    print(quarry)
    results_geol = {}
    
    for code_geol in ["GZ", "IZ", "TZ"]:
        print("\t", code_geol)
        results_n_comp = {}

        for i in range(1,10):
            print(f"\t\t{i}comp")
            results_n_comp[f"{i}comp"] = cv.cross_validation(f"../_RESULTS/CROSS_VALIDATION_POSTPROCESSED_clr/{quarry}/{code_geol}/{str(i)}comp")
            
        results_geol[code_geol] = results_n_comp
        
    results_quarry[quarry] = results_geol
# Out:
# Berg
# 	 GZ
# 		1comp
# GZ
# GZ
# Berg_GZ_z_0_kriged_reverse_1comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_1000_kriged_reverse_1comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_125_kriged_reverse_1comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_180_kriged_reverse_1comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_250_kriged_reverse_1comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_355_kriged_reverse_1comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_500_kriged_reverse_1comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_63_kriged_reverse_1comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_710_kriged_reverse_1comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_90_kriged_reverse_1comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# GZ
# Berg_GZ_z_0_kriged_reverse_1comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_1000_kriged_reverse_1comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_125_kriged_reverse_1comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_180_kriged_reverse_1comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_250_kriged_reverse_1comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_355_kriged_reverse_1comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_500_kriged_reverse_1comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_63_kriged_reverse_1comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_710_kriged_reverse_1comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_90_kriged_reverse_1comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# GZ
# Berg_GZ_z_0_kriged_reverse_1comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_1000_kriged_reverse_1comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_125_kriged_reverse_1comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_180_kriged_reverse_1comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_250_kriged_reverse_1comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_355_kriged_reverse_1comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_500_kriged_reverse_1comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_63_kriged_reverse_1comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_710_kriged_reverse_1comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_90_kriged_reverse_1comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# GZ
# Berg_GZ_z_0_kriged_reverse_1comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_1000_kriged_reverse_1comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_125_kriged_reverse_1comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_180_kriged_reverse_1comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_250_kriged_reverse_1comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_355_kriged_reverse_1comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_500_kriged_reverse_1comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_63_kriged_reverse_1comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_710_kriged_reverse_1comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_90_kriged_reverse_1comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# GZ
# Berg_GZ_z_0_kriged_reverse_1comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_1000_kriged_reverse_1comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_125_kriged_reverse_1comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_180_kriged_reverse_1comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_250_kriged_reverse_1comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_355_kriged_reverse_1comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_500_kriged_reverse_1comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_63_kriged_reverse_1comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_710_kriged_reverse_1comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_90_kriged_reverse_1comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Number of files processed: 50
# 		2comp
# GZ
# GZ
# Berg_GZ_z_0_kriged_reverse_2comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_1000_kriged_reverse_2comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_125_kriged_reverse_2comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_180_kriged_reverse_2comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_250_kriged_reverse_2comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_355_kriged_reverse_2comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_500_kriged_reverse_2comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_63_kriged_reverse_2comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_710_kriged_reverse_2comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_90_kriged_reverse_2comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# GZ
# Berg_GZ_z_0_kriged_reverse_2comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_1000_kriged_reverse_2comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_125_kriged_reverse_2comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_180_kriged_reverse_2comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_250_kriged_reverse_2comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_355_kriged_reverse_2comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_500_kriged_reverse_2comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_63_kriged_reverse_2comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_710_kriged_reverse_2comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_90_kriged_reverse_2comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# GZ
# Berg_GZ_z_0_kriged_reverse_2comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_1000_kriged_reverse_2comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_125_kriged_reverse_2comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_180_kriged_reverse_2comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_250_kriged_reverse_2comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_355_kriged_reverse_2comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_500_kriged_reverse_2comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_63_kriged_reverse_2comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_710_kriged_reverse_2comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_90_kriged_reverse_2comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# GZ
# Berg_GZ_z_0_kriged_reverse_2comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_1000_kriged_reverse_2comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_125_kriged_reverse_2comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_180_kriged_reverse_2comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_250_kriged_reverse_2comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_355_kriged_reverse_2comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_500_kriged_reverse_2comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_63_kriged_reverse_2comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_710_kriged_reverse_2comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_90_kriged_reverse_2comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# GZ
# Berg_GZ_z_0_kriged_reverse_2comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_1000_kriged_reverse_2comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_125_kriged_reverse_2comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_180_kriged_reverse_2comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_250_kriged_reverse_2comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_355_kriged_reverse_2comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_500_kriged_reverse_2comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_63_kriged_reverse_2comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_710_kriged_reverse_2comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_90_kriged_reverse_2comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Number of files processed: 50
# 		3comp
# GZ
# GZ
# Berg_GZ_z_0_kriged_reverse_3comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_1000_kriged_reverse_3comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_125_kriged_reverse_3comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_180_kriged_reverse_3comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_250_kriged_reverse_3comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_355_kriged_reverse_3comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_500_kriged_reverse_3comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_63_kriged_reverse_3comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_710_kriged_reverse_3comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_90_kriged_reverse_3comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# GZ
# Berg_GZ_z_0_kriged_reverse_3comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_1000_kriged_reverse_3comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_125_kriged_reverse_3comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_180_kriged_reverse_3comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_250_kriged_reverse_3comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_355_kriged_reverse_3comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_500_kriged_reverse_3comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_63_kriged_reverse_3comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_710_kriged_reverse_3comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_90_kriged_reverse_3comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# GZ
# Berg_GZ_z_0_kriged_reverse_3comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_1000_kriged_reverse_3comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_125_kriged_reverse_3comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_180_kriged_reverse_3comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_250_kriged_reverse_3comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_355_kriged_reverse_3comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_500_kriged_reverse_3comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_63_kriged_reverse_3comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_710_kriged_reverse_3comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_90_kriged_reverse_3comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# GZ
# Berg_GZ_z_0_kriged_reverse_3comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_1000_kriged_reverse_3comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_125_kriged_reverse_3comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_180_kriged_reverse_3comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_250_kriged_reverse_3comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_355_kriged_reverse_3comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_500_kriged_reverse_3comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_63_kriged_reverse_3comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_710_kriged_reverse_3comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_90_kriged_reverse_3comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# GZ
# Berg_GZ_z_0_kriged_reverse_3comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_1000_kriged_reverse_3comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_125_kriged_reverse_3comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_180_kriged_reverse_3comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_250_kriged_reverse_3comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_355_kriged_reverse_3comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_500_kriged_reverse_3comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_63_kriged_reverse_3comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_710_kriged_reverse_3comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_90_kriged_reverse_3comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Number of files processed: 50
# 		4comp
# GZ
# GZ
# Berg_GZ_z_0_kriged_reverse_4comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_1000_kriged_reverse_4comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_125_kriged_reverse_4comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_180_kriged_reverse_4comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_250_kriged_reverse_4comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_355_kriged_reverse_4comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_500_kriged_reverse_4comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_63_kriged_reverse_4comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_710_kriged_reverse_4comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_90_kriged_reverse_4comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# GZ
# Berg_GZ_z_0_kriged_reverse_4comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_1000_kriged_reverse_4comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_125_kriged_reverse_4comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_180_kriged_reverse_4comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_250_kriged_reverse_4comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_355_kriged_reverse_4comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_500_kriged_reverse_4comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_63_kriged_reverse_4comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_710_kriged_reverse_4comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_90_kriged_reverse_4comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# GZ
# Berg_GZ_z_0_kriged_reverse_4comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_1000_kriged_reverse_4comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_125_kriged_reverse_4comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_180_kriged_reverse_4comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_250_kriged_reverse_4comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_355_kriged_reverse_4comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_500_kriged_reverse_4comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_63_kriged_reverse_4comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_710_kriged_reverse_4comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_90_kriged_reverse_4comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# GZ
# Berg_GZ_z_0_kriged_reverse_4comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_1000_kriged_reverse_4comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_125_kriged_reverse_4comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_180_kriged_reverse_4comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_250_kriged_reverse_4comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_355_kriged_reverse_4comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_500_kriged_reverse_4comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_63_kriged_reverse_4comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_710_kriged_reverse_4comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_90_kriged_reverse_4comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# GZ
# Berg_GZ_z_0_kriged_reverse_4comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_1000_kriged_reverse_4comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_125_kriged_reverse_4comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_180_kriged_reverse_4comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_250_kriged_reverse_4comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_355_kriged_reverse_4comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_500_kriged_reverse_4comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_63_kriged_reverse_4comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_710_kriged_reverse_4comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_90_kriged_reverse_4comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Number of files processed: 50
# 		5comp
# GZ
# GZ
# Berg_GZ_z_0_kriged_reverse_5comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_1000_kriged_reverse_5comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_125_kriged_reverse_5comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_180_kriged_reverse_5comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_250_kriged_reverse_5comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_355_kriged_reverse_5comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_500_kriged_reverse_5comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_63_kriged_reverse_5comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_710_kriged_reverse_5comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_90_kriged_reverse_5comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# GZ
# Berg_GZ_z_0_kriged_reverse_5comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_1000_kriged_reverse_5comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_125_kriged_reverse_5comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_180_kriged_reverse_5comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_250_kriged_reverse_5comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_355_kriged_reverse_5comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_500_kriged_reverse_5comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_63_kriged_reverse_5comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_710_kriged_reverse_5comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_90_kriged_reverse_5comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# GZ
# Berg_GZ_z_0_kriged_reverse_5comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_1000_kriged_reverse_5comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_125_kriged_reverse_5comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_180_kriged_reverse_5comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_250_kriged_reverse_5comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_355_kriged_reverse_5comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_500_kriged_reverse_5comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_63_kriged_reverse_5comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_710_kriged_reverse_5comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_90_kriged_reverse_5comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# GZ
# Berg_GZ_z_0_kriged_reverse_5comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_1000_kriged_reverse_5comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_125_kriged_reverse_5comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_180_kriged_reverse_5comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_250_kriged_reverse_5comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_355_kriged_reverse_5comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_500_kriged_reverse_5comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_63_kriged_reverse_5comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_710_kriged_reverse_5comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_90_kriged_reverse_5comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# GZ
# Berg_GZ_z_0_kriged_reverse_5comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_1000_kriged_reverse_5comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_125_kriged_reverse_5comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_180_kriged_reverse_5comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_250_kriged_reverse_5comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_355_kriged_reverse_5comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_500_kriged_reverse_5comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_63_kriged_reverse_5comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_710_kriged_reverse_5comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_90_kriged_reverse_5comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Number of files processed: 50
# 		6comp
# GZ
# GZ
# Berg_GZ_z_0_kriged_reverse_6comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_1000_kriged_reverse_6comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_125_kriged_reverse_6comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_180_kriged_reverse_6comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_250_kriged_reverse_6comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_355_kriged_reverse_6comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_500_kriged_reverse_6comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_63_kriged_reverse_6comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_710_kriged_reverse_6comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_90_kriged_reverse_6comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# GZ
# Berg_GZ_z_0_kriged_reverse_6comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_1000_kriged_reverse_6comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_125_kriged_reverse_6comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_180_kriged_reverse_6comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_250_kriged_reverse_6comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_355_kriged_reverse_6comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_500_kriged_reverse_6comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_63_kriged_reverse_6comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_710_kriged_reverse_6comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_90_kriged_reverse_6comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# GZ
# Berg_GZ_z_0_kriged_reverse_6comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_1000_kriged_reverse_6comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_125_kriged_reverse_6comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_180_kriged_reverse_6comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_250_kriged_reverse_6comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_355_kriged_reverse_6comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_500_kriged_reverse_6comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_63_kriged_reverse_6comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_710_kriged_reverse_6comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# Berg_GZ_z_90_kriged_reverse_6comp_spherical_3.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_3_test.csv
# 46 54
# 58 9
# 52 93
# 59 99
# 74 64
# 49 81
# 73 36
# 45 27
# GZ
# Berg_GZ_z_0_kriged_reverse_6comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_1000_kriged_reverse_6comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_125_kriged_reverse_6comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_180_kriged_reverse_6comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_250_kriged_reverse_6comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_355_kriged_reverse_6comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_500_kriged_reverse_6comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_63_kriged_reverse_6comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_710_kriged_reverse_6comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# Berg_GZ_z_90_kriged_reverse_6comp_spherical_4.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_4_test.csv
# 73 36
# 59 99
# 74 64
# 32 61
# 10 44
# 84 44
# 74 42
# 90 49
# GZ
# Berg_GZ_z_0_kriged_reverse_6comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_1000_kriged_reverse_6comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_125_kriged_reverse_6comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_180_kriged_reverse_6comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_250_kriged_reverse_6comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_355_kriged_reverse_6comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_500_kriged_reverse_6comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_63_kriged_reverse_6comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_710_kriged_reverse_6comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Berg_GZ_z_90_kriged_reverse_6comp_spherical_5.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_5_test.csv
# 60 40
# 59 99
# 51 57
# 52 93
# 32 61
# 49 64
# 69 65
# 36 32
# Number of files processed: 50
# 		7comp
# GZ
# GZ
# Berg_GZ_z_0_kriged_reverse_7comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_1000_kriged_reverse_7comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_125_kriged_reverse_7comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_180_kriged_reverse_7comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_250_kriged_reverse_7comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_355_kriged_reverse_7comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_500_kriged_reverse_7comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_63_kriged_reverse_7comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_710_kriged_reverse_7comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# Berg_GZ_z_90_kriged_reverse_7comp_spherical_1.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_1_test.csv
# 67 42
# 10 44
# 64 15
# 51 57
# 36 32
# 74 64
# 90 49
# 49 81
# GZ
# Berg_GZ_z_0_kriged_reverse_7comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_1000_kriged_reverse_7comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_125_kriged_reverse_7comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_180_kriged_reverse_7comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_250_kriged_reverse_7comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_355_kriged_reverse_7comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# 45 27
# 69 65
# Berg_GZ_z_500_kriged_reverse_7comp_spherical_2.asc ../_CROSS_VALIDATION_clr/Berg/GZ/Berg_GZ_2_test.csv
# 33 67
# 62 91
# 64 15
# 67 42
# 41 0
# 45 41
# ...
# 		8comp
# TZ
# TZ
# MHZ_TZ_z_0_kriged_reverse_8comp_spherical_1.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_1000_kriged_reverse_8comp_spherical_1.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_125_kriged_reverse_8comp_spherical_1.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_180_kriged_reverse_8comp_spherical_1.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_250_kriged_reverse_8comp_spherical_1.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_355_kriged_reverse_8comp_spherical_1.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_500_kriged_reverse_8comp_spherical_1.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_63_kriged_reverse_8comp_spherical_1.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_710_kriged_reverse_8comp_spherical_1.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_90_kriged_reverse_8comp_spherical_1.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# TZ
# MHZ_TZ_z_0_kriged_reverse_8comp_spherical_2.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_1000_kriged_reverse_8comp_spherical_2.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_125_kriged_reverse_8comp_spherical_2.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_180_kriged_reverse_8comp_spherical_2.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_250_kriged_reverse_8comp_spherical_2.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_355_kriged_reverse_8comp_spherical_2.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_500_kriged_reverse_8comp_spherical_2.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_63_kriged_reverse_8comp_spherical_2.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_710_kriged_reverse_8comp_spherical_2.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_90_kriged_reverse_8comp_spherical_2.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# TZ
# MHZ_TZ_z_0_kriged_reverse_8comp_spherical_3.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_1000_kriged_reverse_8comp_spherical_3.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_125_kriged_reverse_8comp_spherical_3.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_180_kriged_reverse_8comp_spherical_3.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_250_kriged_reverse_8comp_spherical_3.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_355_kriged_reverse_8comp_spherical_3.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_500_kriged_reverse_8comp_spherical_3.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_63_kriged_reverse_8comp_spherical_3.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_710_kriged_reverse_8comp_spherical_3.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_90_kriged_reverse_8comp_spherical_3.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# TZ
# MHZ_TZ_z_0_kriged_reverse_8comp_spherical_4.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_1000_kriged_reverse_8comp_spherical_4.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_125_kriged_reverse_8comp_spherical_4.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_180_kriged_reverse_8comp_spherical_4.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_250_kriged_reverse_8comp_spherical_4.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_355_kriged_reverse_8comp_spherical_4.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_500_kriged_reverse_8comp_spherical_4.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_63_kriged_reverse_8comp_spherical_4.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_710_kriged_reverse_8comp_spherical_4.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_90_kriged_reverse_8comp_spherical_4.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# TZ
# MHZ_TZ_z_0_kriged_reverse_8comp_spherical_5.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_1000_kriged_reverse_8comp_spherical_5.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_125_kriged_reverse_8comp_spherical_5.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_180_kriged_reverse_8comp_spherical_5.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_250_kriged_reverse_8comp_spherical_5.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_355_kriged_reverse_8comp_spherical_5.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_500_kriged_reverse_8comp_spherical_5.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_63_kriged_reverse_8comp_spherical_5.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_710_kriged_reverse_8comp_spherical_5.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_90_kriged_reverse_8comp_spherical_5.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# Number of files processed: 50
# 		9comp
# TZ
# TZ
# MHZ_TZ_z_0_kriged_reverse_9comp_spherical_1.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_1000_kriged_reverse_9comp_spherical_1.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_125_kriged_reverse_9comp_spherical_1.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_180_kriged_reverse_9comp_spherical_1.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_250_kriged_reverse_9comp_spherical_1.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_355_kriged_reverse_9comp_spherical_1.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_500_kriged_reverse_9comp_spherical_1.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_63_kriged_reverse_9comp_spherical_1.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_710_kriged_reverse_9comp_spherical_1.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# MHZ_TZ_z_90_kriged_reverse_9comp_spherical_1.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_1_test.csv
# 54 56
# 74 40
# 29 54
# 14 31
# 62 50
# 18 14
# 53 82
# 48 95
# 57 87
# 64 60
# TZ
# MHZ_TZ_z_0_kriged_reverse_9comp_spherical_2.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_1000_kriged_reverse_9comp_spherical_2.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_125_kriged_reverse_9comp_spherical_2.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_180_kriged_reverse_9comp_spherical_2.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_250_kriged_reverse_9comp_spherical_2.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_355_kriged_reverse_9comp_spherical_2.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_500_kriged_reverse_9comp_spherical_2.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_63_kriged_reverse_9comp_spherical_2.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_710_kriged_reverse_9comp_spherical_2.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# MHZ_TZ_z_90_kriged_reverse_9comp_spherical_2.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_2_test.csv
# 40 50
# 45 18
# 36 72
# 25 24
# 14 31
# 44 72
# 57 87
# 56 19
# 65 19
# 24 68
# TZ
# MHZ_TZ_z_0_kriged_reverse_9comp_spherical_3.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_1000_kriged_reverse_9comp_spherical_3.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_125_kriged_reverse_9comp_spherical_3.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_180_kriged_reverse_9comp_spherical_3.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_250_kriged_reverse_9comp_spherical_3.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_355_kriged_reverse_9comp_spherical_3.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_500_kriged_reverse_9comp_spherical_3.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_63_kriged_reverse_9comp_spherical_3.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_710_kriged_reverse_9comp_spherical_3.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# MHZ_TZ_z_90_kriged_reverse_9comp_spherical_3.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_3_test.csv
# 14 31
# 50 72
# 33 31
# 40 50
# 39 69
# 45 18
# 77 5
# 25 24
# 42 0
# 27 57
# TZ
# MHZ_TZ_z_0_kriged_reverse_9comp_spherical_4.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_1000_kriged_reverse_9comp_spherical_4.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_125_kriged_reverse_9comp_spherical_4.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_180_kriged_reverse_9comp_spherical_4.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_250_kriged_reverse_9comp_spherical_4.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_355_kriged_reverse_9comp_spherical_4.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_500_kriged_reverse_9comp_spherical_4.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_63_kriged_reverse_9comp_spherical_4.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_710_kriged_reverse_9comp_spherical_4.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# MHZ_TZ_z_90_kriged_reverse_9comp_spherical_4.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_4_test.csv
# 48 95
# 57 87
# 1 8
# 81 20
# 25 64
# 56 39
# 25 24
# 53 3
# 33 31
# 32 18
# TZ
# MHZ_TZ_z_0_kriged_reverse_9comp_spherical_5.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_1000_kriged_reverse_9comp_spherical_5.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_125_kriged_reverse_9comp_spherical_5.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_180_kriged_reverse_9comp_spherical_5.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_250_kriged_reverse_9comp_spherical_5.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_355_kriged_reverse_9comp_spherical_5.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_500_kriged_reverse_9comp_spherical_5.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_63_kriged_reverse_9comp_spherical_5.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_710_kriged_reverse_9comp_spherical_5.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# MHZ_TZ_z_90_kriged_reverse_9comp_spherical_5.asc ../_CROSS_VALIDATION_clr/MHZ/TZ/MHZ_TZ_5_test.csv
# 55 66
# 64 60
# 42 0
# 50 27
# 40 50
# 44 34
# 62 50
# 34 56
# 18 14
# 53 82
# Number of files processed: 50
# Wall time: 7min 56s

# %%
#Debug: profile function to see where performance can be improved
# %lprun -f cv.lookup_value cv.lookup_value("../_RESULTS/CROSS_VALIDATION_POSTPROCESSED/Berg/GZ/1comp/1/Berg_GZ_z_0_kriged_reverse_1comp_spherical_1.asc", inputfile, borehole, average=False)
# Out:
# Timer unit: 3.00469e-07 s
#
# Total time: 0.00996446 s
# File: D:\Onedrive\Documenten\Programming\Python\Jupyter_Notebooks\PROJECTS\Compositional_data_kriging\_ANALYSIS\compositional_data_kriging\cross_validation.py
# Function: lookup_value at line 14
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     14                                           def lookup_value(grid_file, input_file, sample, code_geol=None, average=True):
#     15                                               """Lookup value of borehole value in grid file based
#     16                                               on coordinates of requested borehole sample in input file"""
#     17                                               # Open file
#     18         1        496.0    496.0      1.5      f = open(grid_file)
#     19         1       2462.0   2462.0      7.4      grid = f.readlines()
#     20
#     21                                               # Allocate grid info (Surfer grid info) and grid data (actual values)
#     22         1          5.0      5.0      0.0      grid_info = grid[0:6]
#     23         1          5.0      5.0      0.0      grid_data = grid[6:]
#     24
#     25                                               # Put grid_info in dictionary
#     26         1          3.0      3.0      0.0      grid_info_dict = {}
#     27
#     28         7         17.0      2.4      0.1      for line in grid_info:
#     29         6         22.0      3.7      0.1          key, value = line.split()
#     30         6         41.0      6.8      0.1          grid_info_dict[key] = float(value)
#     31
#     32                                               # Put grid_data in numpy matrix
#     33         1          3.0      3.0      0.0      data = []
#     34
#     35        91        204.0      2.2      0.6      for line in grid_data:
#     36        90       2580.0     28.7      7.8          data.append(line.split())
#     37
#     38         1      11850.0  11850.0     35.7      data_array = np.array(data, dtype='float')
#     39
#     40                                               # Get grain size class from grid_file name
#     41         1         22.0     22.0      0.1      regex = re.compile("z_\d+")
#     42         1         16.0     16.0      0.0      grain_size_class = regex.search(grid_file).group()
#     43
#     44                                               # TO DO: select sheet_name based on grid_file's name string
#     45         1       9709.0   9709.0     29.3      lookup_values = pd.read_csv(input_file, sep=";", index_col="hole_id")
#     46
#     47         1       5005.0   5005.0     15.1      lon, lat = list(lookup_values.loc[sample, ["lat", "lon"]])
#     48         1        357.0    357.0      1.1      grain_size = lookup_values.loc[sample, grain_size_class]
#     49
#     50                                               # Adjust starting coordinates for the fact that Surfer uses
#     51                                               # half a cellsize offset in the xllcorner and yllcorner values
#     52         1         14.0     14.0      0.0      start_lon = grid_info_dict["yllcorner"] + (grid_info_dict["cellsize"] / 2)
#     53         1          4.0      4.0      0.0      start_lat = grid_info_dict["xllcorner"] + (grid_info_dict["cellsize"] / 2)
#     54
#     55                                               # Used formula :
#     56                                               # (requested coordinate - corrected starting coordinate) / cellsize = n
#     57                                               # n  can be translated to the index in the grid data matrix
#     58         1         12.0     12.0      0.0      y_actual = (lon - start_lon) / grid_info_dict["cellsize"] + 1
#     59         1          4.0      4.0      0.0      x_actual = (lat - start_lat) / grid_info_dict["cellsize"]
#     60
#     61         1         77.0     77.0      0.2      y1 = int(np.floor(y_actual))
#     62         1          9.0      9.0      0.0      y2 = int(np.ceil(y_actual))
#     63
#     64         1          7.0      7.0      0.0      x1 = int(np.floor(x_actual))
#     65         1          6.0      6.0      0.0      x2 = int(np.ceil(x_actual))
#     66
#     67
#     68                                           #     y1 = int(np.floor((lon - start_lon) / grid_info_dict["cellsize"]) + 1)
#     69                                           #     y2 = int(np.ceil((lon - start_lon) / grid_info_dict["cellsize"]) + 1)
#     70                                           #     x1 = int(np.floor((lat - start_lat) / grid_info_dict["cellsize"]))
#     71                                           #     x2 = int(np.ceil((lat - start_lat) / grid_info_dict["cellsize"]))
#     72                                               # Correction for index out of bounds error
#     73         1          7.0      7.0      0.0      if x2 > grid_info_dict["ncols"] - 1:
#     74                                                   x2 -= 1
#     75
#     76                                               # Calculate closest distance from actual coordinates to grid point coordiantes
#     77                                               # Choose minimal or maximal coordinates if on edge of grid
#     78
#     79         1         11.0     11.0      0.0      y1_distance = np.abs(y1 - y_actual)
#     80         1          7.0      7.0      0.0      y2_distance = np.abs(y2 - y_actual)
#     81
#     82         1          6.0      6.0      0.0      x1_distance = np.abs(x1 - x_actual)
#     83         1         51.0     51.0      0.2      x2_distance = np.abs(x2 - x_actual)
#     84
#     85                                               # Get coordinates with minimal distance
#     86
#     87         1          3.0      3.0      0.0      if y1_distance < y2_distance:
#     88                                                   y_grid = y1
#     89                                               else:
#     90         1          2.0      2.0      0.0          y_grid = y2
#     91
#     92         1          3.0      3.0      0.0      if x1_distance < x2_distance:
#     93                                                   x_grid = x1
#     94                                               else:
#     95         1          2.0      2.0      0.0          x_grid = x2
#     96
#     97                                               # TO DO: Better to use closest point as coordinate to requested coordinate
#     98                                               # than taking the average of 4 nearest points
#     99
#    100
#    101                                               # Create coordinate pairs for four closest points in the grid file
#    102         1          2.0      2.0      0.0      if average == True:
#    103                                                   lookup_couples = []
#    104
#    105                                                   for x in [x1, x2]:
#    106                                                       for y in [y1, y2]:
#    107                                                           lookup_couples.append([int(grid_info_dict["nrows"]) - y, x])
#    108                                                   lookup_couples = np.array(lookup_couples)
#    109
#    110                                                   # Lookup values of the closest points in the grid file
#    111                                                   lookup_values_val = []
#    112
#    113                                                   for couple in lookup_couples:
#    114                                                       lookup_values_val.append(data_array[couple[0], couple[1]])
#    115
#    116                                                   # Take the mean of the found values
#    117                                                   mean_val = np.mean(lookup_values_val)
#    118                                               else:
#    119         1          7.0      7.0      0.0          mean_val = data_array[int(grid_info_dict["nrows"]) - y_grid, x_grid]
#    120
#    121         1        129.0    129.0      0.4      f.close()
#    122
#    123         1          3.0      3.0      0.0      return(mean_val, grain_size)

# %%
# Excel to Asci with grid_info
rootDir = "../_KRIGING\CROSS_VALIDATION_CLASSIC"

for dirName, subdirList, fileList in os.walk(rootDir):
    
    if "Berg" in dirName:
        print(dirName)
        quarry = "Berg"
        grid_info = dict_grid_info["Berg"]
    elif "MHZ" in dirName:
        print(dirName)
        quarry = "MHZ"
    else:
        quarry = None
    
    if "TZ" in dirName:
        code_geol = "TZ"
        if quarry == "MHZ":
            grid_info = dict_grid_info["MHZ_IZ_TZ"]
    elif "IZ" in dirName:
        code_geol = "IZ"
        if quarry == "MHZ":
            grid_info = dict_grid_info["MHZ_IZ_TZ"]
    elif "GZ" in dirName:
        code_geol="GZ"
        if quarry == "MHZ":
            grid_info = dict_grid_info["MHZ_GZ"]
    else:
        pass
    
    
    for file in fileList:
        if file.endswith(".xlsx"):
            f = file[:-5]
            print(f)
            if f.endswith("c"):
                with open(dirName+"/"+f, 'w+') as f:
                    f.write(grid_info)
                    pd.read_excel(dirName+"/"+file).to_csv(f, sep=" ", header=True, 
                                              index=False, mode='a')
# Out:
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\Berg
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\Berg\GZ
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\Berg\GZ\train_1
# Berg_GZ_1_train_z_0.asc
# Berg_GZ_1_train_z_1000.asc
# Berg_GZ_1_train_z_125.asc
# Berg_GZ_1_train_z_180.asc
# Berg_GZ_1_train_z_250.asc
# Berg_GZ_1_train_z_355.asc
# Berg_GZ_1_train_z_500.asc
# Berg_GZ_1_train_z_63.asc
# Berg_GZ_1_train_z_710.asc
# Berg_GZ_1_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\Berg\GZ\train_2
# Berg_GZ_2_train_z_0.asc
# Berg_GZ_2_train_z_1000.asc
# Berg_GZ_2_train_z_125.asc
# Berg_GZ_2_train_z_180.asc
# Berg_GZ_2_train_z_250.asc
# Berg_GZ_2_train_z_355.asc
# Berg_GZ_2_train_z_500.asc
# Berg_GZ_2_train_z_63.asc
# Berg_GZ_2_train_z_710.asc
# Berg_GZ_2_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\Berg\GZ\train_3
# Berg_GZ_3_train_z_0.asc
# Berg_GZ_3_train_z_1000.asc
# Berg_GZ_3_train_z_125.asc
# Berg_GZ_3_train_z_180.asc
# Berg_GZ_3_train_z_250.asc
# Berg_GZ_3_train_z_355.asc
# Berg_GZ_3_train_z_500.asc
# Berg_GZ_3_train_z_63.asc
# Berg_GZ_3_train_z_710.asc
# Berg_GZ_3_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\Berg\GZ\train_4
# Berg_GZ_4_train_z_0.asc
# Berg_GZ_4_train_z_1000.asc
# Berg_GZ_4_train_z_125.asc
# Berg_GZ_4_train_z_180.asc
# Berg_GZ_4_train_z_250.asc
# Berg_GZ_4_train_z_355.asc
# Berg_GZ_4_train_z_500.asc
# Berg_GZ_4_train_z_63.asc
# Berg_GZ_4_train_z_710.asc
# Berg_GZ_4_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\Berg\GZ\train_5
# Berg_GZ_5_train_z_0.asc
# Berg_GZ_5_train_z_1000.asc
# Berg_GZ_5_train_z_125.asc
# Berg_GZ_5_train_z_180.asc
# Berg_GZ_5_train_z_250.asc
# Berg_GZ_5_train_z_355.asc
# Berg_GZ_5_train_z_500.asc
# Berg_GZ_5_train_z_63.asc
# Berg_GZ_5_train_z_710.asc
# Berg_GZ_5_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\Berg\IZ
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\Berg\IZ\train_1
# Berg_IZ_1_train_z_0.asc
# Berg_IZ_1_train_z_1000.asc
# Berg_IZ_1_train_z_125.asc
# Berg_IZ_1_train_z_180.asc
# Berg_IZ_1_train_z_250.asc
# Berg_IZ_1_train_z_355.asc
# Berg_IZ_1_train_z_500.asc
# Berg_IZ_1_train_z_63.asc
# Berg_IZ_1_train_z_710.asc
# Berg_IZ_1_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\Berg\IZ\train_2
# Berg_IZ_2_train_z_0.asc
# Berg_IZ_2_train_z_1000.asc
# Berg_IZ_2_train_z_125.asc
# Berg_IZ_2_train_z_180.asc
# Berg_IZ_2_train_z_250.asc
# Berg_IZ_2_train_z_355.asc
# Berg_IZ_2_train_z_500.asc
# Berg_IZ_2_train_z_63.asc
# Berg_IZ_2_train_z_710.asc
# Berg_IZ_2_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\Berg\IZ\train_3
# Berg_IZ_3_train_z_0.asc
# Berg_IZ_3_train_z_1000.asc
# Berg_IZ_3_train_z_125.asc
# Berg_IZ_3_train_z_180.asc
# Berg_IZ_3_train_z_250.asc
# Berg_IZ_3_train_z_355.asc
# Berg_IZ_3_train_z_500.asc
# Berg_IZ_3_train_z_63.asc
# Berg_IZ_3_train_z_710.asc
# Berg_IZ_3_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\Berg\IZ\train_4
# Berg_IZ_4_train_z_0.asc
# Berg_IZ_4_train_z_1000.asc
# Berg_IZ_4_train_z_125.asc
# Berg_IZ_4_train_z_180.asc
# Berg_IZ_4_train_z_250.asc
# Berg_IZ_4_train_z_355.asc
# Berg_IZ_4_train_z_500.asc
# Berg_IZ_4_train_z_63.asc
# Berg_IZ_4_train_z_710.asc
# Berg_IZ_4_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\Berg\IZ\train_5
# Berg_IZ_5_train_z_0.asc
# Berg_IZ_5_train_z_1000.asc
# Berg_IZ_5_train_z_125.asc
# Berg_IZ_5_train_z_180.asc
# Berg_IZ_5_train_z_250.asc
# Berg_IZ_5_train_z_355.asc
# Berg_IZ_5_train_z_500.asc
# Berg_IZ_5_train_z_63.asc
# Berg_IZ_5_train_z_710.asc
# Berg_IZ_5_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\Berg\TZ
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\Berg\TZ\train_1
# Berg_TZ_1_train_z_0.asc
# Berg_TZ_1_train_z_1000.asc
# Berg_TZ_1_train_z_125.asc
# Berg_TZ_1_train_z_180.asc
# Berg_TZ_1_train_z_250.asc
# Berg_TZ_1_train_z_355.asc
# Berg_TZ_1_train_z_500.asc
# Berg_TZ_1_train_z_63.asc
# Berg_TZ_1_train_z_710.asc
# Berg_TZ_1_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\Berg\TZ\train_2
# Berg_TZ_2_train_z_0.asc
# Berg_TZ_2_train_z_1000.asc
# Berg_TZ_2_train_z_125.asc
# Berg_TZ_2_train_z_180.asc
# Berg_TZ_2_train_z_250.asc
# Berg_TZ_2_train_z_355.asc
# Berg_TZ_2_train_z_500.asc
# Berg_TZ_2_train_z_63.asc
# Berg_TZ_2_train_z_710.asc
# Berg_TZ_2_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\Berg\TZ\train_3
# Berg_TZ_3_train_z_0.asc
# Berg_TZ_3_train_z_1000.asc
# Berg_TZ_3_train_z_125.asc
# Berg_TZ_3_train_z_180.asc
# Berg_TZ_3_train_z_250.asc
# Berg_TZ_3_train_z_355.asc
# Berg_TZ_3_train_z_500.asc
# Berg_TZ_3_train_z_63.asc
# Berg_TZ_3_train_z_710.asc
# Berg_TZ_3_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\Berg\TZ\train_4
# Berg_TZ_4_train_z_0.asc
# Berg_TZ_4_train_z_1000.asc
# Berg_TZ_4_train_z_125.asc
# Berg_TZ_4_train_z_180.asc
# Berg_TZ_4_train_z_250.asc
# Berg_TZ_4_train_z_355.asc
# Berg_TZ_4_train_z_500.asc
# Berg_TZ_4_train_z_63.asc
# Berg_TZ_4_train_z_710.asc
# Berg_TZ_4_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\Berg\TZ\train_5
# Berg_TZ_5_train_z_0.asc
# Berg_TZ_5_train_z_1000.asc
# Berg_TZ_5_train_z_125.asc
# Berg_TZ_5_train_z_180.asc
# Berg_TZ_5_train_z_250.asc
# Berg_TZ_5_train_z_355.asc
# Berg_TZ_5_train_z_500.asc
# Berg_TZ_5_train_z_63.asc
# Berg_TZ_5_train_z_710.asc
# Berg_TZ_5_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\MHZ
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\MHZ\GZ
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\MHZ\GZ\train_1
# MHZ_GZ_1_train_z_0.asc
# MHZ_GZ_1_train_z_1000.asc
# MHZ_GZ_1_train_z_125.asc
# MHZ_GZ_1_train_z_180.asc
# MHZ_GZ_1_train_z_250.asc
# MHZ_GZ_1_train_z_355.asc
# MHZ_GZ_1_train_z_500.asc
# MHZ_GZ_1_train_z_63.asc
# MHZ_GZ_1_train_z_710.asc
# MHZ_GZ_1_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\MHZ\GZ\train_2
# MHZ_GZ_2_train_z_0.asc
# MHZ_GZ_2_train_z_1000.asc
# MHZ_GZ_2_train_z_125.asc
# MHZ_GZ_2_train_z_180.asc
# MHZ_GZ_2_train_z_250.asc
# MHZ_GZ_2_train_z_355.asc
# MHZ_GZ_2_train_z_500.asc
# MHZ_GZ_2_train_z_63.asc
# MHZ_GZ_2_train_z_710.asc
# MHZ_GZ_2_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\MHZ\GZ\train_3
# MHZ_GZ_3_train_z_0.asc
# MHZ_GZ_3_train_z_1000.asc
# MHZ_GZ_3_train_z_125.asc
# MHZ_GZ_3_train_z_180.asc
# MHZ_GZ_3_train_z_250.asc
# MHZ_GZ_3_train_z_355.asc
# MHZ_GZ_3_train_z_500.asc
# MHZ_GZ_3_train_z_63.asc
# MHZ_GZ_3_train_z_710.asc
# MHZ_GZ_3_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\MHZ\GZ\train_4
# MHZ_GZ_4_train_z_0.asc
# MHZ_GZ_4_train_z_1000.asc
# MHZ_GZ_4_train_z_125.asc
# MHZ_GZ_4_train_z_180.asc
# MHZ_GZ_4_train_z_250.asc
# MHZ_GZ_4_train_z_355.asc
# MHZ_GZ_4_train_z_500.asc
# MHZ_GZ_4_train_z_63.asc
# MHZ_GZ_4_train_z_710.asc
# MHZ_GZ_4_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\MHZ\GZ\train_5
# MHZ_GZ_5_train_z_0.asc
# MHZ_GZ_5_train_z_1000.asc
# MHZ_GZ_5_train_z_125.asc
# MHZ_GZ_5_train_z_180.asc
# MHZ_GZ_5_train_z_250.asc
# MHZ_GZ_5_train_z_355.asc
# MHZ_GZ_5_train_z_500.asc
# MHZ_GZ_5_train_z_63.asc
# MHZ_GZ_5_train_z_710.asc
# MHZ_GZ_5_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\MHZ\IZ
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\MHZ\IZ\train_1
# MHZ_IZ_1_train_z_0.asc
# MHZ_IZ_1_train_z_1000.asc
# MHZ_IZ_1_train_z_125.asc
# MHZ_IZ_1_train_z_180.asc
# MHZ_IZ_1_train_z_250.asc
# MHZ_IZ_1_train_z_355.asc
# MHZ_IZ_1_train_z_500.asc
# MHZ_IZ_1_train_z_63.asc
# MHZ_IZ_1_train_z_710.asc
# MHZ_IZ_1_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\MHZ\IZ\train_2
# MHZ_IZ_2_train_z_0.asc
# MHZ_IZ_2_train_z_1000.asc
# MHZ_IZ_2_train_z_125.asc
# MHZ_IZ_2_train_z_180.asc
# MHZ_IZ_2_train_z_250.asc
# MHZ_IZ_2_train_z_355.asc
# MHZ_IZ_2_train_z_500.asc
# MHZ_IZ_2_train_z_63.asc
# MHZ_IZ_2_train_z_710.asc
# MHZ_IZ_2_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\MHZ\IZ\train_3
# MHZ_IZ_3_train_z_0.asc
# MHZ_IZ_3_train_z_1000.asc
# MHZ_IZ_3_train_z_125.asc
# MHZ_IZ_3_train_z_180.asc
# MHZ_IZ_3_train_z_250.asc
# MHZ_IZ_3_train_z_355.asc
# MHZ_IZ_3_train_z_500.asc
# MHZ_IZ_3_train_z_63.asc
# MHZ_IZ_3_train_z_710.asc
# MHZ_IZ_3_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\MHZ\IZ\train_4
# MHZ_IZ_4_train_z_0.asc
# MHZ_IZ_4_train_z_1000.asc
# MHZ_IZ_4_train_z_125.asc
# MHZ_IZ_4_train_z_180.asc
# MHZ_IZ_4_train_z_250.asc
# MHZ_IZ_4_train_z_355.asc
# MHZ_IZ_4_train_z_500.asc
# MHZ_IZ_4_train_z_63.asc
# MHZ_IZ_4_train_z_710.asc
# MHZ_IZ_4_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\MHZ\IZ\train_5
# MHZ_IZ_5_train_z_0.asc
# MHZ_IZ_5_train_z_1000.asc
# MHZ_IZ_5_train_z_125.asc
# MHZ_IZ_5_train_z_180.asc
# MHZ_IZ_5_train_z_250.asc
# MHZ_IZ_5_train_z_355.asc
# MHZ_IZ_5_train_z_500.asc
# MHZ_IZ_5_train_z_63.asc
# MHZ_IZ_5_train_z_710.asc
# MHZ_IZ_5_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\MHZ\TZ
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\MHZ\TZ\train_1
# MHZ_TZ_1_train_z_0.asc
# MHZ_TZ_1_train_z_1000.asc
# MHZ_TZ_1_train_z_125.asc
# MHZ_TZ_1_train_z_180.asc
# MHZ_TZ_1_train_z_250.asc
# MHZ_TZ_1_train_z_355.asc
# MHZ_TZ_1_train_z_500.asc
# MHZ_TZ_1_train_z_63.asc
# MHZ_TZ_1_train_z_710.asc
# MHZ_TZ_1_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\MHZ\TZ\train_2
# MHZ_TZ_2_train_z_0.asc
# MHZ_TZ_2_train_z_1000.asc
# MHZ_TZ_2_train_z_125.asc
# MHZ_TZ_2_train_z_180.asc
# MHZ_TZ_2_train_z_250.asc
# MHZ_TZ_2_train_z_355.asc
# MHZ_TZ_2_train_z_500.asc
# MHZ_TZ_2_train_z_63.asc
# MHZ_TZ_2_train_z_710.asc
# MHZ_TZ_2_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\MHZ\TZ\train_3
# MHZ_TZ_3_train_z_0.asc
# MHZ_TZ_3_train_z_1000.asc
# MHZ_TZ_3_train_z_125.asc
# MHZ_TZ_3_train_z_180.asc
# MHZ_TZ_3_train_z_250.asc
# MHZ_TZ_3_train_z_355.asc
# MHZ_TZ_3_train_z_500.asc
# MHZ_TZ_3_train_z_63.asc
# MHZ_TZ_3_train_z_710.asc
# MHZ_TZ_3_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\MHZ\TZ\train_4
# MHZ_TZ_4_train_z_0.asc
# MHZ_TZ_4_train_z_1000.asc
# MHZ_TZ_4_train_z_125.asc
# MHZ_TZ_4_train_z_180.asc
# MHZ_TZ_4_train_z_250.asc
# MHZ_TZ_4_train_z_355.asc
# MHZ_TZ_4_train_z_500.asc
# MHZ_TZ_4_train_z_63.asc
# MHZ_TZ_4_train_z_710.asc
# MHZ_TZ_4_train_z_90.asc
# ../_KRIGING\CROSS_VALIDATION_CLASSIC\MHZ\TZ\train_5
# MHZ_TZ_5_train_z_0.asc
# MHZ_TZ_5_train_z_1000.asc
# MHZ_TZ_5_train_z_125.asc
# MHZ_TZ_5_train_z_180.asc
# MHZ_TZ_5_train_z_250.asc
# MHZ_TZ_5_train_z_355.asc
# MHZ_TZ_5_train_z_500.asc
# MHZ_TZ_5_train_z_63.asc
# MHZ_TZ_5_train_z_710.asc
# MHZ_TZ_5_train_z_90.asc
